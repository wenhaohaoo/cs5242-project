# %%
import os
import torch
import torchvision
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
from tqdm import tqdm

import time
import utils

# %%
# Looking into the directory
data_dir = './dataset'
print(os.listdir(data_dir))
classes_train = os.listdir(data_dir + "/train")
classes_valid = os.listdir(data_dir + "/validation")
print(f'Train Classes - {classes_train}')
print(f'Validation Classes - {classes_valid}')
# Out:
# ['train', 'validation']
# Train Classes - ['disgusted', 'surprised']
# Validation Classes - ['angry', 'disgusted', 'happy', 'neutral', 'sad', 'scared', 'surprised']

# %%
# Data transforms (Gray Scaling & data augmentation)
train_tfms = tt.Compose([tt.Grayscale(num_output_channels=1),
                         tt.RandomHorizontalFlip(),
                         tt.RandomRotation(30),
#                          tt.Resize((48,48)),
                         tt.ToTensor()])

valid_tfms = tt.Compose([tt.Grayscale(num_output_channels=1), tt.ToTensor()])

# %%
# Emotion Detection datasets
train_ds = ImageFolder(data_dir + '/train', train_tfms)
valid_ds = ImageFolder(data_dir + '/validation', valid_tfms)

# %%
batch_size = 200

# %%
# PyTorch data loaders
train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=2, pin_memory=True)
valid_dl = DataLoader(valid_ds, batch_size, num_workers=2, pin_memory=True)

# %%
def mean_std(loader):
  images, lebels = next(iter(loader))
  # shape of images = [b,c,w,h]
  mean, std = images.mean([0,2,3]), images.std([0,2,3])
  return mean, std

mean, std = mean_std(train_dl)
print("mean and std: \n", mean, std)
# Out:
# mean and std:
#  tensor([0.5285]) tensor([0.2837])

# %%
# Display image and label.
train_features, train_labels = next(iter(train_dl))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze()
label = train_labels[0]
plt.imshow(img, cmap="gray")
plt.show()
print(f"Label: {label}")
# Out:
# Feature batch shape: torch.Size([200, 1, 128, 128])
# Labels batch shape: torch.Size([200])
# Label: 0

# %%
def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 12))
        ax.set_xticks([]); ax.set_yticks([])
        print(images[0].shape)
        ax.imshow(make_grid(images[:64], nrow=8).permute(1, 2, 0))
        break

# %%
show_batch(train_dl)
# Out:
# torch.Size([1, 128, 128])

# %% [markdown]
# ### Make a LeNet5 convnet class.

# %%
class LeNet5_convnet(nn.Module):

    def __init__(self):

        super(LeNet5_convnet, self).__init__()

        # CL1:   128 x 128  -->    50 x 128 x 128 
        self.conv1 = nn.Conv2d(1,   50,  kernel_size=3,  padding=1 )
        
        # MP1: 50 x 128 x 128 -->    50 x 32 x 32
        self.pool1  = nn.MaxPool2d(4,4)
        
        # CL2:   50 x 32 x 32  -->    100 x 32 x 32 
        self.conv2 = nn.Conv2d(50,  100,  kernel_size=3,  padding=1 )
        
        # MP2: 100 x 32 x 32 -->    100 x 8 x 8
        self.pool2 = nn.MaxPool2d(4,4)
        
        # LL1:   100 x 32 x 32 = 6400 -->  1000 
        self.linear1 = nn.Linear(6400, 100)
        
        self.linear2 = nn.Linear(100, 7)


    def forward(self, x):

        # CL1:   28 x 28  -->    50 x 28 x 28 
        x = self.conv1(x)
        x = torch.relu(x)
        
        # MP1: 50 x 28 x 28 -->    50 x 14 x 14
        x = self.pool1(x)
        
        # CL2:   50 x 14 x 14  -->    100 x 14 x 14
        x = self.conv2(x)
        x = torch.relu(x)
        
        # MP2: 100 x 14 x 14 -->    100 x 7 x 7
        x = self.pool2(x)

        # LL1:   100 x 7 x 7 = 4900  -->  100 
        x = x.view(-1, 6400)
        x = self.linear1(x)
        x = torch.relu(x)
        
        
        # LL2:   4900  -->  10 
        x = self.linear2(x)
    
        return x

# %% [markdown]
# ### Build the net. How many parameters in total?

# %%
net=LeNet5_convnet()
print(net)
utils.display_num_param(net)
# Out:
# LeNet5_convnet(
#   (conv1): Conv2d(1, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(50, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (linear1): Linear(in_features=6400, out_features=100, bias=True)
#   (linear2): Linear(in_features=100, out_features=7, bias=True)
# )
# There are 686407 (0.69 million) parameters in this neural network

# %% [markdown]
# ### Send the weights of the networks to the GPU (as well as the mean and std)

# %%
device='cpu'
net = net.to(device)

mean=mean.to(device)

std=std.to(device)

# %% [markdown]
# ### Choose the criterion, learning rate, and batch size.

# %%
criterion = nn.CrossEntropyLoss()

my_lr=0.01

# %% [markdown]
# ### Function to evaluate the network on the test set

# %%
def eval_on_test_set():

    running_error=0
    num_batches=0

    for minibatch_data, minibatch_label in valid_dl:
    # for i in range(0,10000,bs):

        # minibatch_data =  test_data[i:i+bs].unsqueeze(dim=1)
        # minibatch_label= test_label[i:i+bs]

        minibatch_data=minibatch_data.to(device)
        minibatch_label=minibatch_label.to(device)
        
        inputs = (minibatch_data - mean)/std    # ONLY CHANGE IS HERE!

        scores=net( inputs ) 

        error = utils.get_error( scores , minibatch_label)

        running_error += error.item()

        num_batches+=1


    total_error = running_error/num_batches
    print( 'error rate on test set =', total_error*100 ,'percent')

# %% [markdown]
# ### Do 30 passes through the training set. Divide the learning rate by 2 every 5 epochs.

# %%
start=time.time()

for epoch in range(1,200):
    
    if not epoch%10:
        my_lr = my_lr / 1.5
        
    optimizer=torch.optim.SGD( net.parameters() , lr=my_lr )
        
    running_loss=0
    running_error=0
    num_batches=0
    
    # shuffled_indices=torch.randperm(60000)
 
    # for count in range(0,60000,bs):
    for minibatch_data, minibatch_label in train_dl:
        
        # FORWARD AND BACKWARD PASS
    
        optimizer.zero_grad()
             
        # indices=shuffled_indices[count:count+bs]
        # minibatch_data =  train_data[indices].unsqueeze(dim=1)
        # minibatch_label=  train_label[indices]
        
        minibatch_data=minibatch_data.to(device)
        minibatch_label=minibatch_label.to(device)
        
        inputs = (minibatch_data - mean)/std      # ONLY CHANGE IS HERE!
        
        inputs.requires_grad_()

        scores=net( inputs ) 

        loss =  criterion( scores , minibatch_label) 
          
        loss.backward()
        
        optimizer.step()
        

        # COMPUTE STATS
        
        running_loss += loss.detach().item()
        
        error = utils.get_error( scores.detach() , minibatch_label)
        running_error += error.item()
        
        num_batches+=1        
    
    
    # AVERAGE STATS THEN DISPLAY
    total_loss = running_loss/num_batches
    total_error = running_error/num_batches
    elapsed = (time.time()-start)/60
    
    print('epoch=',epoch, '\t time=', elapsed,'min', '\t lr=', my_lr  ,'\t loss=', total_loss , '\t error=', total_error*100 ,'percent')
    eval_on_test_set() 
    print(' ')
# Out:
# epoch= 1 	 time= 0.6768474300702413 min 	 lr= 0.01 	 loss= 1.463407889008522 	 error= 56.07888326048851 percent
# error rate on test set = 89.33333357175192 percent
#
# epoch= 2 	 time= 1.5348675807317098 min 	 lr= 0.01 	 loss= 0.8080482855439186 	 error= 46.14502415060997 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 3 	 time= 2.3405340552330016 min 	 lr= 0.01 	 loss= 0.7205223739147186 	 error= 45.387741178274155 percent
# error rate on test set = 85.83333293596903 percent
#
# epoch= 4 	 time= 3.1316251118977863 min 	 lr= 0.01 	 loss= 0.689455009996891 	 error= 38.90594691038132 percent
# error rate on test set = 88.33333253860474 percent
#
# epoch= 5 	 time= 3.9102416237195334 min 	 lr= 0.01 	 loss= 0.7073360085487366 	 error= 50.92475712299347 percent
# error rate on test set = 88.16666603088379 percent
#
# epoch= 6 	 time= 4.676847473780314 min 	 lr= 0.01 	 loss= 0.7005644589662552 	 error= 47.0351941883564 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 7 	 time= 5.463869150479635 min 	 lr= 0.01 	 loss= 0.6774688437581062 	 error= 39.88046050071716 percent
# error rate on test set = 88.99999856948853 percent
#
# epoch= 8 	 time= 6.215115336577098 min 	 lr= 0.01 	 loss= 0.6960166543722153 	 error= 43.19296106696129 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 9 	 time= 6.974365083376567 min 	 lr= 0.01 	 loss= 0.7501490414142609 	 error= 48.72208759188652 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 10 	 time= 7.744120927651723 min 	 lr= 0.006666666666666667 	 loss= 0.6604353114962578 	 error= 37.4168686568737 percent
# error rate on test set = 89.50000007947287 percent
#
# epoch= 11 	 time= 8.545857524871826 min 	 lr= 0.006666666666666667 	 loss= 0.638052262365818 	 error= 32.47148096561432 percent
# error rate on test set = 89.66666658719382 percent
#
# epoch= 12 	 time= 9.312980957825978 min 	 lr= 0.006666666666666667 	 loss= 0.6382469534873962 	 error= 32.45024234056473 percent
# error rate on test set = 87.5 percent
#
# epoch= 13 	 time= 10.072350831826528 min 	 lr= 0.006666666666666667 	 loss= 0.6429196521639824 	 error= 35.64866557717323 percent
# error rate on test set = 83.49999984105429 percent
#
# epoch= 14 	 time= 10.837492255369822 min 	 lr= 0.006666666666666667 	 loss= 0.6180472299456596 	 error= 30.453883856534958 percent
# error rate on test set = 89.83333309491476 percent
#
# epoch= 15 	 time= 11.605308393637339 min 	 lr= 0.006666666666666667 	 loss= 0.6229016557335854 	 error= 34.81007367372513 percent
# error rate on test set = 85.66666642824808 percent
#
# epoch= 16 	 time= 12.35977493127187 min 	 lr= 0.006666666666666667 	 loss= 0.6037578508257866 	 error= 28.795509785413742 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 17 	 time= 13.127635129292806 min 	 lr= 0.006666666666666667 	 loss= 0.6291271597146988 	 error= 35.306431353092194 percent
# error rate on test set = 83.99999936421713 percent
#
# epoch= 18 	 time= 13.894071741898854 min 	 lr= 0.006666666666666667 	 loss= 0.6280563473701477 	 error= 37.435680627822876 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 19 	 time= 14.660077504316966 min 	 lr= 0.006666666666666667 	 loss= 0.6079396307468414 	 error= 32.08555802702904 percent
# error rate on test set = 86.66666746139526 percent
#
# epoch= 20 	 time= 15.430009158452352 min 	 lr= 0.0044444444444444444 	 loss= 0.5810906514525414 	 error= 27.217839658260345 percent
# error rate on test set = 85.49999992052713 percent
#
# epoch= 21 	 time= 16.196389532089235 min 	 lr= 0.0044444444444444444 	 loss= 0.5751320719718933 	 error= 26.864684373140335 percent
# error rate on test set = 85.49999992052713 percent
#
# epoch= 22 	 time= 16.961048130194346 min 	 lr= 0.0044444444444444444 	 loss= 0.5683876425027847 	 error= 25.460558384656906 percent
# error rate on test set = 88.83333206176758 percent
#
# epoch= 23 	 time= 17.72786967754364 min 	 lr= 0.0044444444444444444 	 loss= 0.5677095726132393 	 error= 26.89441740512848 percent
# error rate on test set = 85.33333341280618 percent
#
# epoch= 24 	 time= 18.483681392669677 min 	 lr= 0.0044444444444444444 	 loss= 0.5614486709237099 	 error= 26.291261613368988 percent
# error rate on test set = 86.33333444595337 percent
#
# epoch= 25 	 time= 19.238938689231873 min 	 lr= 0.0044444444444444444 	 loss= 0.5510233789682388 	 error= 24.65898096561432 percent
# error rate on test set = 86.50000095367432 percent
#
# epoch= 26 	 time= 19.998406068483987 min 	 lr= 0.0044444444444444444 	 loss= 0.5482234582304955 	 error= 25.83191692829132 percent
# error rate on test set = 86.50000095367432 percent
#
# epoch= 27 	 time= 20.754773445924123 min 	 lr= 0.0044444444444444444 	 loss= 0.5493889451026917 	 error= 25.394417345523834 percent
# error rate on test set = 89.33333357175192 percent
#
# epoch= 28 	 time= 21.518316129843395 min 	 lr= 0.0044444444444444444 	 loss= 0.5469056218862534 	 error= 27.08555832505226 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 29 	 time= 22.278701376914977 min 	 lr= 0.0044444444444444444 	 loss= 0.536193385720253 	 error= 25.02305880188942 percent
# error rate on test set = 86.16666793823242 percent
#
# epoch= 30 	 time= 23.02900460958481 min 	 lr= 0.002962962962962963 	 loss= 0.5327203795313835 	 error= 24.732402712106705 percent
# error rate on test set = 86.83333396911621 percent
#
# epoch= 31 	 time= 23.789640458424888 min 	 lr= 0.002962962962962963 	 loss= 0.5395258143544197 	 error= 25.920510292053223 percent
# error rate on test set = 86.16666793823242 percent
#
# epoch= 32 	 time= 24.548182316621144 min 	 lr= 0.002962962962962963 	 loss= 0.5366422235965729 	 error= 25.526699423789978 percent
# error rate on test set = 85.66666642824808 percent
#
# epoch= 33 	 time= 25.310069759686787 min 	 lr= 0.002962962962962963 	 loss= 0.5328937843441963 	 error= 24.824634939432144 percent
# error rate on test set = 85.83333293596903 percent
#
# epoch= 34 	 time= 26.078075949350993 min 	 lr= 0.002962962962962963 	 loss= 0.5413793548941612 	 error= 26.29854381084442 percent
# error rate on test set = 86.33333444595337 percent
#
# epoch= 35 	 time= 26.842688484986624 min 	 lr= 0.002962962962962963 	 loss= 0.5308353677392006 	 error= 25.100121647119522 percent
# error rate on test set = 88.49999904632568 percent
#
# epoch= 36 	 time= 27.601691619555154 min 	 lr= 0.002962962962962963 	 loss= 0.52471923828125 	 error= 24.655339866876602 percent
# error rate on test set = 88.99999856948853 percent
#
# epoch= 37 	 time= 28.36621419588725 min 	 lr= 0.002962962962962963 	 loss= 0.5233060568571091 	 error= 25.210559368133545 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 38 	 time= 29.119063595930736 min 	 lr= 0.002962962962962963 	 loss= 0.5152317062020302 	 error= 23.537620902061462 percent
# error rate on test set = 86.50000095367432 percent
#
# epoch= 39 	 time= 29.875636259714764 min 	 lr= 0.002962962962962963 	 loss= 0.517211489379406 	 error= 25.34283921122551 percent
# error rate on test set = 86.50000095367432 percent
#
# epoch= 40 	 time= 30.6615171790123 min 	 lr= 0.0019753086419753087 	 loss= 0.5157519914209843 	 error= 24.283980578184128 percent
# error rate on test set = 87.00000047683716 percent
#
# epoch= 41 	 time= 31.451340687274932 min 	 lr= 0.0019753086419753087 	 loss= 0.5092301592230797 	 error= 23.408980667591095 percent
# error rate on test set = 89.16666706403097 percent
#
# epoch= 42 	 time= 32.206753460566205 min 	 lr= 0.0019753086419753087 	 loss= 0.5137685500085354 	 error= 24.092839658260345 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 43 	 time= 32.97326414982478 min 	 lr= 0.0019753086419753087 	 loss= 0.5124341733753681 	 error= 23.486043512821198 percent
# error rate on test set = 87.1666669845581 percent
#
# epoch= 44 	 time= 33.743916285038 min 	 lr= 0.0019753086419753087 	 loss= 0.5150982216000557 	 error= 24.427183717489243 percent
# error rate on test set = 87.1666669845581 percent
#
# epoch= 45 	 time= 34.50667014122009 min 	 lr= 0.0019753086419753087 	 loss= 0.5083157867193222 	 error= 23.309466242790222 percent
# error rate on test set = 86.16666793823242 percent
# epoch= 46 	 time= 35.26482487916947 min 	 lr= 0.0019753086419753087 	 loss= 0.5099396891891956 	 error= 24.2141991853714 percent
# error rate on test set = 87.66666650772095 percent
#
# epoch= 47 	 time= 36.023573708534244 min 	 lr= 0.0019753086419753087 	 loss= 0.5047816336154938 	 error= 22.850121557712555 percent
# error rate on test set = 87.1666669845581 percent
#
# epoch= 48 	 time= 36.78444098234176 min 	 lr= 0.0019753086419753087 	 loss= 0.5124637559056282 	 error= 24.655339121818542 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 49 	 time= 37.543913932641345 min 	 lr= 0.0019753086419753087 	 loss= 0.513026736676693 	 error= 25.210559368133545 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 50 	 time= 38.29445315202077 min 	 lr= 0.0013168724279835392 	 loss= 0.499525748193264 	 error= 22.923544049263 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 51 	 time= 39.054518866539 min 	 lr= 0.0013168724279835392 	 loss= 0.5036757960915565 	 error= 23.74332621693611 percent
# error rate on test set = 86.33333444595337 percent
#
# epoch= 52 	 time= 39.82146009206772 min 	 lr= 0.0013168724279835392 	 loss= 0.5110909380018711 	 error= 23.91626238822937 percent
# error rate on test set = 87.5 percent
#
# epoch= 53 	 time= 40.58487680355708 min 	 lr= 0.0013168724279835392 	 loss= 0.4982539899647236 	 error= 23.57402890920639 percent
# error rate on test set = 87.5 percent
#
# epoch= 54 	 time= 41.355698601404825 min 	 lr= 0.0013168724279835392 	 loss= 0.49835895001888275 	 error= 22.40898087620735 percent
# error rate on test set = 86.83333396911621 percent
#
# epoch= 55 	 time= 42.10542635917663 min 	 lr= 0.0013168724279835392 	 loss= 0.4973159171640873 	 error= 22.6735420525074 percent
# error rate on test set = 87.5 percent
#
# epoch= 56 	 time= 42.86165414651235 min 	 lr= 0.0013168724279835392 	 loss= 0.5049622915685177 	 error= 23.717839270830154 percent
# error rate on test set = 86.83333396911621 percent
#
# epoch= 57 	 time= 43.61448835134506 min 	 lr= 0.0013168724279835392 	 loss= 0.4927636608481407 	 error= 21.699029207229614 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 58 	 time= 44.38220276037852 min 	 lr= 0.0013168724279835392 	 loss= 0.5005675032734871 	 error= 24.228762835264206 percent
# error rate on test set = 88.83333206176758 percent
#
# epoch= 59 	 time= 45.139250961939496 min 	 lr= 0.0013168724279835392 	 loss= 0.5013196729123592 	 error= 22.596480697393417 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 60 	 time= 45.90927594900131 min 	 lr= 0.0008779149519890262 	 loss= 0.5024749301373959 	 error= 23.86104390025139 percent
# error rate on test set = 87.66666650772095 percent
#
# epoch= 61 	 time= 46.67245852947235 min 	 lr= 0.0008779149519890262 	 loss= 0.5014688372612 	 error= 24.523058533668518 percent
# error rate on test set = 87.66666650772095 percent
#
# epoch= 62 	 time= 47.42603781223297 min 	 lr= 0.0008779149519890262 	 loss= 0.5084235444664955 	 error= 24.023059010505676 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 63 	 time= 48.18233539660772 min 	 lr= 0.0008779149519890262 	 loss= 0.5006147399544716 	 error= 23.305825144052505 percent
# error rate on test set = 87.5 percent
#
# epoch= 64 	 time= 48.93339922030767 min 	 lr= 0.0008779149519890262 	 loss= 0.5000733286142349 	 error= 23.648058623075485 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 65 	 time= 49.68319789568583 min 	 lr= 0.0008779149519890262 	 loss= 0.49377302825450897 	 error= 23.51941615343094 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 66 	 time= 50.447257256507875 min 	 lr= 0.0008779149519890262 	 loss= 0.4968882389366627 	 error= 23.64077791571617 percent
# error rate on test set = 87.66666650772095 percent
#
# epoch= 67 	 time= 51.19386769135793 min 	 lr= 0.0008779149519890262 	 loss= 0.4974348694086075 	 error= 24.21419844031334 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 68 	 time= 51.94048949082693 min 	 lr= 0.0008779149519890262 	 loss= 0.4978330731391907 	 error= 23.794902861118317 percent
# error rate on test set = 87.5 percent
#
# epoch= 69 	 time= 52.68098023335139 min 	 lr= 0.0008779149519890262 	 loss= 0.5005582831799984 	 error= 24.08555895090103 percent
# error rate on test set = 87.66666650772095 percent
#
# epoch= 70 	 time= 53.42537709871928 min 	 lr= 0.0005852766346593508 	 loss= 0.48977426439523697 	 error= 22.864685207605362 percent
# error rate on test set = 87.1666669845581 percent
#
# epoch= 71 	 time= 54.161729244391125 min 	 lr= 0.0005852766346593508 	 loss= 0.49269911274313927 	 error= 23.84648099541664 percent
# error rate on test set = 87.5 percent
#
# epoch= 72 	 time= 54.90185967683792 min 	 lr= 0.0005852766346593508 	 loss= 0.4938790649175644 	 error= 22.648058831691742 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 73 	 time= 55.64603523015976 min 	 lr= 0.0005852766346593508 	 loss= 0.49699612334370613 	 error= 24.08919855952263 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 74 	 time= 56.38314061164856 min 	 lr= 0.0005852766346593508 	 loss= 0.49323785677552223 	 error= 22.60376363992691 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 75 	 time= 57.130414219697315 min 	 lr= 0.0005852766346593508 	 loss= 0.4975390397012234 	 error= 22.861043363809586 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 76 	 time= 57.863784988721214 min 	 lr= 0.0005852766346593508 	 loss= 0.49816229566931725 	 error= 24.22512099146843 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 77 	 time= 58.60043219327927 min 	 lr= 0.0005852766346593508 	 loss= 0.5023360922932625 	 error= 23.81371483206749 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 78 	 time= 59.346948595841724 min 	 lr= 0.0005852766346593508 	 loss= 0.5016557164490223 	 error= 23.464199155569077 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 79 	 time= 60.08897198438645 min 	 lr= 0.0005852766346593508 	 loss= 0.49416742846369743 	 error= 22.908980399370193 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 80 	 time= 60.82379666169484 min 	 lr= 0.0003901844231062339 	 loss= 0.492298923432827 	 error= 22.42354303598404 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 81 	 time= 61.56627351442973 min 	 lr= 0.0003901844231062339 	 loss= 0.48640165850520134 	 error= 22.111042588949203 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 82 	 time= 62.31322888930639 min 	 lr= 0.0003901844231062339 	 loss= 0.501643531024456 	 error= 23.706916719675064 percent
# error rate on test set = 87.66666650772095 percent
#
# epoch= 83 	 time= 63.05487308899561 min 	 lr= 0.0003901844231062339 	 loss= 0.4958515129983425 	 error= 23.030339181423187 percent
# error rate on test set = 87.33333349227905 percent
#
# epoch= 84 	 time= 63.82268963654836 min 	 lr= 0.0003901844231062339 	 loss= 0.4872601069509983 	 error= 22.71783947944641 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 85 	 time= 64.57301986217499 min 	 lr= 0.0003901844231062339 	 loss= 0.4862038157880306 	 error= 22.666262090206146 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 86 	 time= 65.32012639840444 min 	 lr= 0.0003901844231062339 	 loss= 0.4921732433140278 	 error= 23.04854318499565 percent
# error rate on test set = 87.66666650772095 percent
#
# epoch= 87 	 time= 66.0629084189733 min 	 lr= 0.0003901844231062339 	 loss= 0.4971703812479973 	 error= 22.794903814792633 percent
# error rate on test set = 87.5 percent
#
# epoch= 88 	 time= 66.80763732592264 min 	 lr= 0.0003901844231062339 	 loss= 0.49801550433039665 	 error= 23.850121349096298 percent
# error rate on test set = 87.66666650772095 percent
#
# epoch= 89 	 time= 67.55322155952453 min 	 lr= 0.0003901844231062339 	 loss= 0.49445589259266853 	 error= 24.04126226902008 percent
# error rate on test set = 87.66666650772095 percent
#
# epoch= 90 	 time= 68.28630681832631 min 	 lr= 0.00026012294873748923 	 loss= 0.49741047248244286 	 error= 24.45327714085579 percent
# error rate on test set = 87.8333330154419 percent
# epoch= 91 	 time= 69.02682926654816 min 	 lr= 0.00026012294873748923 	 loss= 0.49274150654673576 	 error= 22.746966034173965 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 92 	 time= 69.76638580560684 min 	 lr= 0.00026012294873748923 	 loss= 0.5002145543694496 	 error= 23.570995032787323 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 93 	 time= 70.5089347799619 min 	 lr= 0.00026012294873748923 	 loss= 0.49655503407120705 	 error= 23.898059129714966 percent
# error rate on test set = 88.33333253860474 percent
#
# epoch= 94 	 time= 71.25212657054266 min 	 lr= 0.00026012294873748923 	 loss= 0.4915398322045803 	 error= 22.54854440689087 percent
# error rate on test set = 88.33333253860474 percent
#
# epoch= 95 	 time= 71.98827739953995 min 	 lr= 0.00026012294873748923 	 loss= 0.4891611151397228 	 error= 22.552184760570526 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 96 	 time= 72.72786149581273 min 	 lr= 0.00026012294873748923 	 loss= 0.49536826834082603 	 error= 23.47147986292839 percent
# error rate on test set = 87.66666650772095 percent
#
# epoch= 97 	 time= 73.47611061731975 min 	 lr= 0.00026012294873748923 	 loss= 0.5005102045834064 	 error= 24.574635177850723 percent
# error rate on test set = 87.66666650772095 percent
#
# epoch= 98 	 time= 74.22265454133351 min 	 lr= 0.00026012294873748923 	 loss= 0.487160075455904 	 error= 21.4199036359787 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 99 	 time= 74.96287726163864 min 	 lr= 0.00026012294873748923 	 loss= 0.49909307435154915 	 error= 23.408981412649155 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 100 	 time= 75.70438803037008 min 	 lr= 0.00017341529915832616 	 loss= 0.48768969997763634 	 error= 22.930824756622314 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 101 	 time= 76.48975601593654 min 	 lr= 0.00017341529915832616 	 loss= 0.4835030063986778 	 error= 22.29854390025139 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 102 	 time= 77.2380978624026 min 	 lr= 0.00017341529915832616 	 loss= 0.4871026501059532 	 error= 22.794903814792633 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 103 	 time= 78.0327747186025 min 	 lr= 0.00017341529915832616 	 loss= 0.4906800463795662 	 error= 22.86832556128502 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 104 	 time= 78.77900613943736 min 	 lr= 0.00017341529915832616 	 loss= 0.4876009300351143 	 error= 23.166263103485107 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 105 	 time= 79.51872631708781 min 	 lr= 0.00017341529915832616 	 loss= 0.4893640726804733 	 error= 23.5631063580513 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 106 	 time= 80.25143704017003 min 	 lr= 0.00017341529915832616 	 loss= 0.48800840228796005 	 error= 22.496967017650604 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 107 	 time= 80.99098787705104 min 	 lr= 0.00017341529915832616 	 loss= 0.49687639623880386 	 error= 23.052185028791428 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 108 	 time= 81.72801028092702 min 	 lr= 0.00017341529915832616 	 loss= 0.4835677854716778 	 error= 22.041262686252594 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 109 	 time= 82.46519970496496 min 	 lr= 0.00017341529915832616 	 loss= 0.49822841957211494 	 error= 23.155339807271957 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 110 	 time= 83.21528738737106 min 	 lr= 0.00011561019943888411 	 loss= 0.4826490879058838 	 error= 22.783979773521423 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 111 	 time= 83.94618453979493 min 	 lr= 0.00011561019943888411 	 loss= 0.485242772847414 	 error= 22.92354255914688 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 112 	 time= 84.68864264090855 min 	 lr= 0.00011561019943888411 	 loss= 0.4847050830721855 	 error= 22.739684581756592 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 113 	 time= 85.43788316249848 min 	 lr= 0.00011561019943888411 	 loss= 0.49310141801834106 	 error= 22.62985333800316 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 114 	 time= 86.17756853898366 min 	 lr= 0.00011561019943888411 	 loss= 0.4896070063114166 	 error= 23.27669858932495 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 115 	 time= 86.9135516524315 min 	 lr= 0.00011561019943888411 	 loss= 0.4924837574362755 	 error= 23.692356050014496 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 116 	 time= 87.64858214060466 min 	 lr= 0.00011561019943888411 	 loss= 0.4860678054392338 	 error= 23.23240265250206 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 117 	 time= 88.39105441172917 min 	 lr= 0.00011561019943888411 	 loss= 0.48241183534264565 	 error= 22.75424748659134 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 118 	 time= 89.13133137623468 min 	 lr= 0.00011561019943888411 	 loss= 0.49228639155626297 	 error= 22.846481204032898 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 119 	 time= 89.86520059506098 min 	 lr= 0.00011561019943888411 	 loss= 0.49086837098002434 	 error= 22.721480578184128 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 120 	 time= 90.59427465597788 min 	 lr= 7.70734662925894e-05 	 loss= 0.49378518760204315 	 error= 22.54854366183281 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 121 	 time= 91.3629605571429 min 	 lr= 7.70734662925894e-05 	 loss= 0.4870895743370056 	 error= 21.846480667591095 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 122 	 time= 92.0956531047821 min 	 lr= 7.70734662925894e-05 	 loss= 0.49212419241666794 	 error= 21.791262179613113 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 123 	 time= 92.83071333567301 min 	 lr= 7.70734662925894e-05 	 loss= 0.4937865249812603 	 error= 22.97147959470749 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 124 	 time= 93.57724016904831 min 	 lr= 7.70734662925894e-05 	 loss= 0.4975161626935005 	 error= 23.695995658636093 percent
# error rate on test set = 87.8333330154419 percent
#
# epoch= 125 	 time= 94.32424509525299 min 	 lr= 7.70734662925894e-05 	 loss= 0.5038513243198395 	 error= 23.967839777469635 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 126 	 time= 95.0558542172114 min 	 lr= 7.70734662925894e-05 	 loss= 0.49055881425738335 	 error= 22.669902443885803 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 127 	 time= 95.7856087009112 min 	 lr= 7.70734662925894e-05 	 loss= 0.47918107360601425 	 error= 21.8276709318161 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 128 	 time= 96.52138786315918 min 	 lr= 7.70734662925894e-05 	 loss= 0.4869448207318783 	 error= 22.430825233459473 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 129 	 time= 97.25633381207784 min 	 lr= 7.70734662925894e-05 	 loss= 0.4926290214061737 	 error= 22.596480697393417 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 130 	 time= 97.98939593235652 min 	 lr= 5.138231086172627e-05 	 loss= 0.49002282693982124 	 error= 23.019418120384216 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 131 	 time= 98.72757114569346 min 	 lr= 5.138231086172627e-05 	 loss= 0.49751053377985954 	 error= 23.714199662208557 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 132 	 time= 99.46698919932048 min 	 lr= 5.138231086172627e-05 	 loss= 0.4883967563509941 	 error= 22.361043095588684 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 133 	 time= 100.20563416878382 min 	 lr= 5.138231086172627e-05 	 loss= 0.48852046579122543 	 error= 22.29854315519333 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 134 	 time= 100.94097928206126 min 	 lr= 5.138231086172627e-05 	 loss= 0.48558608442544937 	 error= 22.978762537240982 percent
# error rate on test set = 87.99999952316284 percent
# epoch= 135 	 time= 101.68068429629008 min 	 lr= 5.138231086172627e-05 	 loss= 0.49227002263069153 	 error= 23.294902592897415 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 136 	 time= 102.41878634293874 min 	 lr= 5.138231086172627e-05 	 loss= 0.48185790702700615 	 error= 22.732403129339218 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 137 	 time= 103.15773596763611 min 	 lr= 5.138231086172627e-05 	 loss= 0.4845939986407757 	 error= 23.35740253329277 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 138 	 time= 103.89546343485515 min 	 lr= 5.138231086172627e-05 	 loss= 0.4795708432793617 	 error= 20.629246532917023 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 139 	 time= 104.63981517950694 min 	 lr= 5.138231086172627e-05 	 loss= 0.4891054667532444 	 error= 23.850121349096298 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 140 	 time= 105.3749019185702 min 	 lr= 3.425487390781751e-05 	 loss= 0.48928187415003777 	 error= 22.791261970996857 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 141 	 time= 106.11088716189066 min 	 lr= 3.425487390781751e-05 	 loss= 0.48701583966612816 	 error= 22.607403248548508 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 142 	 time= 106.84430815378825 min 	 lr= 3.425487390781751e-05 	 loss= 0.49172060936689377 	 error= 22.905340045690536 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 143 	 time= 107.58072731494903 min 	 lr= 3.425487390781751e-05 	 loss= 0.4938198998570442 	 error= 22.46783971786499 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 144 	 time= 108.31431998809178 min 	 lr= 3.425487390781751e-05 	 loss= 0.4930488280951977 	 error= 23.33555892109871 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 145 	 time= 109.046615087986 min 	 lr= 3.425487390781751e-05 	 loss= 0.49660781025886536 	 error= 23.456916958093643 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 146 	 time= 109.79235402345657 min 	 lr= 3.425487390781751e-05 	 loss= 0.4928305149078369 	 error= 23.283981531858444 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 147 	 time= 110.52597930034001 min 	 lr= 3.425487390781751e-05 	 loss= 0.48636995255947113 	 error= 22.28762060403824 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 148 	 time= 111.27409396966299 min 	 lr= 3.425487390781751e-05 	 loss= 0.4882723391056061 	 error= 23.030339181423187 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 149 	 time= 112.00489661296209 min 	 lr= 3.425487390781751e-05 	 loss= 0.48975345864892006 	 error= 22.658980637788773 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 150 	 time= 112.74981027046839 min 	 lr= 2.2836582605211673e-05 	 loss= 0.4876294247806072 	 error= 22.427184134721756 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 151 	 time= 113.48471215963363 min 	 lr= 2.2836582605211673e-05 	 loss= 0.4931175895035267 	 error= 22.835557907819748 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 152 	 time= 114.22334843476614 min 	 lr= 2.2836582605211673e-05 	 loss= 0.48814065754413605 	 error= 23.475121706724167 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 153 	 time= 114.96412223974863 min 	 lr= 2.2836582605211673e-05 	 loss= 0.493537113070488 	 error= 23.22148084640503 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 154 	 time= 115.70681929985682 min 	 lr= 2.2836582605211673e-05 	 loss= 0.4809909202158451 	 error= 21.98968455195427 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 155 	 time= 116.44409534931182 min 	 lr= 2.2836582605211673e-05 	 loss= 0.4842687323689461 	 error= 22.894417494535446 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 156 	 time= 117.18739550113678 min 	 lr= 2.2836582605211673e-05 	 loss= 0.4862734340131283 	 error= 22.666262090206146 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 157 	 time= 117.92122690677643 min 	 lr= 2.2836582605211673e-05 	 loss= 0.49077480658888817 	 error= 23.228763043880463 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 158 	 time= 118.66978893677394 min 	 lr= 2.2836582605211673e-05 	 loss= 0.4930006228387356 	 error= 22.898058593273163 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 159 	 time= 119.40872401793798 min 	 lr= 2.2836582605211673e-05 	 loss= 0.5001611784100533 	 error= 24.081917107105255 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 160 	 time= 120.1497478167216 min 	 lr= 1.522438840347445e-05 	 loss= 0.4857926703989506 	 error= 22.530339658260345 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 161 	 time= 120.88281775712967 min 	 lr= 1.522438840347445e-05 	 loss= 0.48909859731793404 	 error= 22.04854264855385 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 162 	 time= 121.62785851160685 min 	 lr= 1.522438840347445e-05 	 loss= 0.4896504767239094 	 error= 23.467840254306793 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 163 	 time= 122.36500559647878 min 	 lr= 1.522438840347445e-05 	 loss= 0.4874409921467304 	 error= 22.294902056455612 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 164 	 time= 123.096202202638 min 	 lr= 1.522438840347445e-05 	 loss= 0.4839659333229065 	 error= 21.820388734340668 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 165 	 time= 123.83797533512116 min 	 lr= 1.522438840347445e-05 	 loss= 0.49691177159547806 	 error= 23.148058354854584 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 166 	 time= 124.5832165757815 min 	 lr= 1.522438840347445e-05 	 loss= 0.48871373385190964 	 error= 22.78762236237526 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 167 	 time= 125.31341969966888 min 	 lr= 1.522438840347445e-05 	 loss= 0.49331072717905045 	 error= 23.703277856111526 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 168 	 time= 126.05284930467606 min 	 lr= 1.522438840347445e-05 	 loss= 0.493268147110939 	 error= 23.669902235269547 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 169 	 time= 126.79388322035472 min 	 lr= 1.522438840347445e-05 	 loss= 0.49049994349479675 	 error= 22.621966153383255 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 170 	 time= 127.5261071006457 min 	 lr= 1.0149592268982966e-05 	 loss= 0.48764631524682045 	 error= 23.35740327835083 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 171 	 time= 128.26642948389053 min 	 lr= 1.0149592268982966e-05 	 loss= 0.4921496696770191 	 error= 23.28762114048004 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 172 	 time= 128.99746998548508 min 	 lr= 1.0149592268982966e-05 	 loss= 0.4913741499185562 	 error= 22.871966660022736 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 173 	 time= 129.7303593158722 min 	 lr= 1.0149592268982966e-05 	 loss= 0.49129699543118477 	 error= 23.24332520365715 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 174 	 time= 130.4691297451655 min 	 lr= 1.0149592268982966e-05 	 loss= 0.49454910308122635 	 error= 22.533980011940002 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 175 	 time= 131.20668727954228 min 	 lr= 1.0149592268982966e-05 	 loss= 0.4880870170891285 	 error= 24.151699244976044 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 176 	 time= 131.9417625149091 min 	 lr= 1.0149592268982966e-05 	 loss= 0.4838675297796726 	 error= 22.555825114250183 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 177 	 time= 132.67294465700786 min 	 lr= 1.0149592268982966e-05 	 loss= 0.49120109900832176 	 error= 22.191747277975082 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 178 	 time= 133.40421620607376 min 	 lr= 1.0149592268982966e-05 	 loss= 0.4896392971277237 	 error= 23.217839002609253 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 179 	 time= 134.1420689900716 min 	 lr= 1.0149592268982966e-05 	 loss= 0.48788223043084145 	 error= 22.276698052883148 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 180 	 time= 134.8731065193812 min 	 lr= 6.766394845988644e-06 	 loss= 0.4906458556652069 	 error= 23.04854393005371 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 181 	 time= 135.6079937140147 min 	 lr= 6.766394845988644e-06 	 loss= 0.48524659872055054 	 error= 21.8058243393898 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 182 	 time= 136.3521115263303 min 	 lr= 6.766394845988644e-06 	 loss= 0.49538281559944153 	 error= 23.092839866876602 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 183 	 time= 137.09403882026672 min 	 lr= 6.766394845988644e-06 	 loss= 0.48326653614640236 	 error= 22.791261970996857 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 184 	 time= 137.82882699171702 min 	 lr= 6.766394845988644e-06 	 loss= 0.4884684644639492 	 error= 22.41262048482895 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 185 	 time= 138.56300876537958 min 	 lr= 6.766394845988644e-06 	 loss= 0.48205262795090675 	 error= 22.725120186805725 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 186 	 time= 139.30157155195872 min 	 lr= 6.766394845988644e-06 	 loss= 0.488246139138937 	 error= 23.16262051463127 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 187 	 time= 140.03289654652278 min 	 lr= 6.766394845988644e-06 	 loss= 0.49379631504416466 	 error= 23.225121200084686 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 188 	 time= 140.77520643075306 min 	 lr= 6.766394845988644e-06 	 loss= 0.486642025411129 	 error= 23.000606149435043 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 189 	 time= 141.52683951059979 min 	 lr= 6.766394845988644e-06 	 loss= 0.48459916934370995 	 error= 22.191747277975082 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 190 	 time= 142.2599781950315 min 	 lr= 4.510929897325763e-06 	 loss= 0.4887132979929447 	 error= 22.42354303598404 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 191 	 time= 143.0034491300583 min 	 lr= 4.510929897325763e-06 	 loss= 0.4891556315124035 	 error= 22.416263073682785 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 192 	 time= 143.7489573597908 min 	 lr= 4.510929897325763e-06 	 loss= 0.49662575125694275 	 error= 23.42718541622162 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 193 	 time= 144.49446629285814 min 	 lr= 4.510929897325763e-06 	 loss= 0.4873158037662506 	 error= 22.39805832505226 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 194 	 time= 145.24517914056779 min 	 lr= 4.510929897325763e-06 	 loss= 0.48493776842951775 	 error= 22.908981889486313 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 195 	 time= 145.980109167099 min 	 lr= 4.510929897325763e-06 	 loss= 0.4901558943092823 	 error= 23.1183260679245 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 196 	 time= 146.72195820411045 min 	 lr= 4.510929897325763e-06 	 loss= 0.48689578101038933 	 error= 22.232403606176376 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 197 	 time= 147.45727261304856 min 	 lr= 4.510929897325763e-06 	 loss= 0.4895184561610222 	 error= 23.44963550567627 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 198 	 time= 148.1976834376653 min 	 lr= 4.510929897325763e-06 	 loss= 0.4871573969721794 	 error= 22.427184134721756 percent
# error rate on test set = 87.99999952316284 percent
#
# epoch= 199 	 time= 148.93511601289114 min 	 lr= 4.510929897325763e-06 	 loss= 0.49186256900429726 	 error= 23.019418120384216 percent
# error rate on test set = 87.99999952316284 percent
