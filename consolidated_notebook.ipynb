# %% [markdown]
# # Importing dependencies and setting device

# %%
import os
import time

import numpy as np
import torch
import torchvision
import torch.nn as nn
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as tt
from torchvision.utils import make_grid
from torchsummary import summary
import matplotlib.pyplot as plt

import utils

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %% [markdown]
# # Dataset Collection
#
# ## Assignee:
# + Wen Hao: Build scraper module to gather images of faces
# + Gin, Xiaoxin: Data cleaning. Remove images with inaccuracy label manually.
#
# ## Description:
#
# We have chosen to gather our images from Google Image search, by searching for faces with the specified emotion, e.g. `"happy man face"`. For example, the raw images obtained using the search keyword "happy man face" would have the true labels `"happy"` and `"man"`. Adding the word `"face"` to the search term was to reduce the amount of images that might not have any face. This would form the raw dataset of our project.
#
# Collection of data was done via Selenium, a powerful tool for performing browser automation. It is used to automate the scraping from Google Images using the chromedriver.
#
# The steps for scraping the images are as follows:
# 1. Open a **headless** browser and navigate to "https://www.google.com/search?q={search_term}&tbm=isch&ijn=0"
#   - The parameter `tbm=isch` specifies that this is an image search
#   - The parameter `q={search_term}` is the term to search for
# 2. Keep scrolling down until all results are loaded in page
# 3. Loop through each image result to get its URL with full resolution (not thumbnail)
# 4. Save the URL into a json file to be used by another job to download later
#
# The above steps were repeated for all 14 search terms (7 emotions and 2 genders). There is also about a 3 seconds wait between each image in the loop as there is a need to wait for the UI to load to get the full resolution image. Hence, the challenge that we've met while trying to run this locally (on our Macbooks) is that this takes quite a significant amount of time if we run this sequentially one by one on our own laptop.
#
# The next approach to speed this up was to distribute this image search, to run all 14 searches in parallel. To do this, we build a docker container with the scraper and its dependencies built in and build an Airflow DAG (directed acyclic graph) run this on an instance of Airflow, with the search term as a parameter.
#
# However, the next challenge we found was that Selenium WebDriver/Chromedriver works very differently when running on a Linux based container, oftenly throwing the cryptic error `Selenium::WebDriver::Error::InvalidSessionIdError: invalid session id`. In Linux operating systems there is a shared memory space called `/dev/shm`. Any Linux process can create a partition within `/dev/shm` if the process wants to share memory with another process. This is often done to improve performance of similar processes. The shared memory space is often used by web browsers such as chrome when they’re being orchestrated by a selenium web driver. However, this shared memory space does not scale with device/server memory by default. The solution we used was to mount memory to the path `/dev/shm`. But there is a limitation where the shared memory is limited to half of the system's memory.
#
# While trying to run a single search, I also realised that the WebDriver session seems to only be active for about 30 minutes and beyond that, most containers will start having session timeout errors whie trying to retrieve the image elements.
#
# Hence, we implemented a way to save progress at periodic checkpoints and resume the search from the index that it failed. With this, the overall solution was a brute force solution where we just increase the CPU and memory limit to the maximum possible and keep running it until we have saved all our results. The only caveat is that the image result is not static and the number of results we get is always changing, hence resuming from where we fail from a different search might end up having a slightly different set of results but it not very significant in this case.
#
# <br>
#
# ## Airflow Screenshots
#
# Below are the records of the total runs we have from the Airflow UI.
#
# ![scrape-man](images/scrape-man.png)
#
# ![scrape-woman](images/scrape-woman.png)
#
#
# <br>
#
# ## Resource Monitoring
#
# We have also setup grafana to monitor the resource usage:
#
# ![monitor](images/monitor.png)
#
# ## Conclusion
#
# From the above chart, we can see that the amount of resources used was linearly increasing as times go on until a point and drops back down to 0. This suggest that there is a possible memory leakage somewhere within the implementation of Selenium WebDriver/Chromedriver. As time was limited, we kind of resolve this by adding checkpoints and brute forcing it by providing more compute resources for it to run to completion.
#
# Selenium might not have been the best tool for this scraping and we can explore other tools in the future.

# %% [markdown]
# ### Scraper Demo
#
# The next cell we will run this scraper in dev mode which will only scrape the first 20 images to show how it works.

# %%
# !python scraper.py -h
# Out:
# usage: scraper.py [-h] [-s S] [-o O] [-r R] [-d D]
#
# optional arguments:
#   -h, --help  show this help message and exit
#   -s S        search term to scrape images from
#   -o O        output root directory
#   -r R        index to resume from
#   -d D        whether to run in dev mode

# %%
# !python scraper.py -s "sad man face" -d true
# Out:
# [2021-11-18 00:38:33,055] [INFO] - Search term: sad man face
# [2021-11-18 00:38:34,587] [INFO] - Scrolling down ..
# [2021-11-18 00:38:57,003] [INFO] - Reached the end ..
# [2021-11-18 00:38:57,269] [INFO] - Total results found: 731
# [2021-11-18 00:38:57,269] [INFO] - is_retry: False
# [2021-11-18 00:38:57,269] [INFO] - dev: True
# search_term=sad man face | is_retry=False : 100%|█| 20/20 [01:08<00:00,  3.41s/i
# [2021-11-18 00:40:05,501] [INFO] - Total image URLs extracted in first pass: 20

# %% [markdown]
# # Data Pre-processing
#
# ## Assignee: Wen Hao
#
# ## Description:
#
# This is to pre-process the images gathered. The gathered images from the Google Image search comes in all shape and sizes hence it is necessary to process them before they are reading to be used as inputs to train the neural network.
#
# Below are the preprocessing steps applied to all images in order:
# 1. Convert image to grayscale
# 2. Use OpenCV python library to detect faces in the image using Haar feature-based cascade classifier
# 3. Crop the detected faces along the guiding box coordinates
# 4. Resize image to 128x128 pixels
# 5. Save the final output
#
# Similarly, we built the preprocessor into a container with a script callable from the terminal and takes arguments and ran this in an Airflow together with the download job.
#
# ![scrape-man](images/download-preprocess.png)

# %%
# !python download.py -s "sad man face"
# !python preprocessor.py -s "sad man face"
# Out:
# [2021-11-18 00:57:38,131] [INFO] - Search term: sad man face
# search_term=sad man face : 100%|████████████████| 20/20 [00:05<00:00,  3.40it/s]
# [2021-11-18 00:57:44,576] [INFO] - Search term: sad man face
# search_term=sad man face: 100%|█████████████████| 20/20 [00:02<00:00,  8.80it/s]

# %% [markdown]
# # Data Exploration
# Assignee: Gin, Xiaoxin

# %%
IMAGE_FOLDER = # replace it with your own path

totalImages = {}
for subfolder in os.listdir(IMAGE_FOLDER):
    dir = IMAGE_FOLDER + '/' + subfolder
    if os.path.isdir(dir):
        totalImages[subfolder] = len(os.listdir(dir))

pd.DataFrame(totalImages.items(), columns = ['category', '# of sample'])
# Out:
#                 category  # of sample
# 0       neutral man face          241
# 1         sad woman face          848
# 2       angry woman face          753
# 3   disgusted woman face          746
# 4         happy man face          192
# 5   surprised woman face          851
# 6           sad man face          359
# 7        scared man face          394
# 8         angry man face          331
# 9     disgusted man face          514
# 10     scared woman face          825
# 11      happy woman face          921
# 12    neutral woman face          628
# 13    surprised man face          378

# %%
print(sum(totalImages.values()), "files in total.")
# Out:
# 7981 files in total.

# %% [markdown]
# # Dataset Augmentation and Preparation
#
# In this step, we will prepare the collected data as a dataset that is ready to be used for training with some augmentation (random rotation, random horizontal flip, resizing and output as tensor).

# %%
# Looking into the directory
data_dir = './dataset'
print(os.listdir(data_dir))
classes_train = os.listdir(data_dir + "/train")
classes_valid = os.listdir(data_dir + "/validation")
print(f'Train Classes - {classes_train}')
print(f'Validation Classes - {classes_valid}')
# Out:
# ['train', 'validation']
# Train Classes - ['happy', 'scared', 'surprised', 'neutral', 'angry', 'disgusted', 'sad']
# Validation Classes - ['happy', 'scared', 'surprised', 'neutral', 'angry', 'disgusted', 'sad']

# %%
# Data transforms (Gray Scaling & data augmentation)
train_tfms = tt.Compose([tt.Grayscale(num_output_channels=1),
                         tt.RandomHorizontalFlip(),
                         tt.RandomRotation(30),
                         tt.Resize((128,128)),
                         tt.ToTensor()])

valid_tfms = tt.Compose([tt.Grayscale(num_output_channels=1), tt.ToTensor()])

# %%
# Emotion Detection datasets
train_ds = ImageFolder(data_dir + '/train', train_tfms)
valid_ds = ImageFolder(data_dir + '/validation', train_tfms)

# %%
# PyTorch data loaders
batch_size = 100
train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=2, pin_memory=True)
valid_dl = DataLoader(valid_ds, batch_size, num_workers=2, pin_memory=True)

# %%
# Display image and label.
train_features, train_labels = next(iter(train_dl))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze()
label = train_labels[0]
plt.imshow(img, cmap="gray")
plt.show()
print(f"Label: {label}")
# Out:
# Feature batch shape: torch.Size([100, 1, 128, 128])
# Labels batch shape: torch.Size([100])
# Label: 4

# %%
def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 12))
        ax.set_xticks([]); ax.set_yticks([])
        print(images[0].shape)
        ax.imshow(make_grid(images[:64], nrow=8).permute(1, 2, 0))
        break

# %%
show_batch(train_dl)
# Out:
# torch.Size([1, 128, 128])

# %% [markdown]
# # Utilities for later steps
#
#  - Calculating the mean and std of the dataset for normalization
#  - Function to evaluate the network on input dataset

# %%
mean = 0.0
meansq = 0.0
count = 0

for index, (data, _) in enumerate(train_dl):
    mean = data.sum()
    meansq = meansq + (data**2).sum()
    count += np.prod(data.shape)

total_mean = mean/count
total_var = (meansq/count) - (total_mean**2)
total_std = torch.sqrt(total_var)
print("mean: " + str(total_mean))
print("std: " + str(total_std))
# Out:
# mean: tensor(0.0026)
# std: tensor(0.5862)

# %%
def eval_on_dataset_loader(model, dataset_loader):

    running_error=0
    num_batches=0

    for minibatch_data, minibatch_label in dataset_loader:
        # send them to the gpu
        minibatch_data=minibatch_data.to(device)
        minibatch_label=minibatch_label.to(device)

        # normalize the minibatch
        inputs = (minibatch_data - total_mean) / total_std
        
        if isinstance(model, three_layer_net):
            inputs = inputs.view(-1, 128*128)

        # feed it to the network
        scores=model(inputs) 

        # compute the error made on this batch
        error = utils.get_error(scores, minibatch_label)

        # add it to the running error
        running_error += error.item()

        num_batches+=1


    # compute error rate on the full test set
    total_error = running_error/num_batches

    print('error rate on dataset =', total_error*100 ,'percent')

# %% [markdown]
# # Model Development, Improvement & Evaluation
#
# # 1. Multi Layer Perceptron (MLP)
#
# The first attempt was to implement the MLP first as a baseline.

# %%
# PyTorch data loaders
batch_size = 200
train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=2, pin_memory=True)
valid_dl = DataLoader(valid_ds, batch_size, num_workers=2, pin_memory=True)

# %% [markdown]
# ## Define the three layer net class

# %%
class three_layer_net(nn.Module):

    def __init__(self, input_size, hidden_size1, hidden_size2,  output_size):
        super(three_layer_net , self).__init__()

        self.layer1 = nn.Linear(  input_size   , hidden_size1  , bias=True  )
        self.layer2 = nn.Linear(  hidden_size1 , hidden_size2  , bias=True  )
        self.layer3 = nn.Linear(  hidden_size2 , output_size   , bias=True  )        
        
    def forward(self, x):
        
        y       = self.layer1(x)
        y_hat   = torch.relu(y)
        z       = self.layer2(y_hat)
        z_hat   = torch.relu(z)
        scores  = self.layer3(z_hat)
        
        return scores

# %% [markdown]
# # Build the net with the following size:

# %%
mlp = three_layer_net(128*128, 500, 500, 7)
print(mlp)
utils.display_num_param(mlp)
# Out:
# three_layer_net(
#   (layer1): Linear(in_features=16384, out_features=500, bias=True)
#   (layer2): Linear(in_features=500, out_features=500, bias=True)
#   (layer3): Linear(in_features=500, out_features=7, bias=True)
# )
# There are 8446507 (8.45 million) parameters in this neural network

# %% [markdown]
# # Send the weights of the networks to the GPU

# %%
mlp = mlp.to(device)

# %% [markdown]
# # Choose the criterion and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer=torch.optim.SGD(mlp.parameters() , lr=0.01 )

# %% [markdown]
# # Do 200 passes through the training set

# %%
start=time.time()

for epoch in range(200):
    
    running_loss=0
    running_error=0
    num_batches=0
 
    for minibatch_data, minibatch_label in train_dl:
    
        # Set the gradients to zeros
        optimizer.zero_grad()
        # send them to the gpu
        minibatch_data=minibatch_data.to(device)
        minibatch_label=minibatch_label.to(device)
        
        # reshape the minibatch
        inputs = minibatch_data.view(-1, 128*128)

        # tell Pytorch to start tracking all operations that will be done on "inputs"
        inputs.requires_grad_()

        # forward the minibatch through the net 
        scores = mlp(inputs) 

        # Compute the average of the losses of the data points in the minibatch
        loss = criterion(scores , minibatch_label) 
        
        # backward pass to compute dL/dU, dL/dV and dL/dW   
        loss.backward()

        # do one step of stochastic gradient descent: U=U-lr(dL/dU), V=V-lr(dL/dU), ...
        optimizer.step()
        

        # START COMPUTING STATS
        
        # add the loss of this batch to the running loss
        running_loss += loss.detach().item()
        
        # compute the error made on this batch and add it to the running error       
        error = utils.get_error( scores.detach() , minibatch_label)
        running_error += error.item()
        
        num_batches+=1        
    
    
    # compute stats for the full training set
    total_loss = running_loss/num_batches
    total_error = running_error/num_batches
    elapsed = time.time()-start
    
    print('epoch=',epoch, '\t time=', elapsed,'min','\t lr=', 0.01  ,'\t loss=', total_loss , '\t error=', total_error*100 ,'percent')
    eval_on_dataset_loader(mlp, valid_dl)
    print(' ')
# Out:
# epoch= 0 	 time= 2.1031365394592285 min 	 lr= 0.01 	 loss= 1.8689881324768067 	 error= 75.36000061035156 percent
# error rate on dataset = 75.9646455446879 percent
#
# epoch= 1 	 time= 4.9138712882995605 min 	 lr= 0.01 	 loss= 1.8717430067062377 	 error= 74.94000101089478 percent
# error rate on dataset = 72.38888740539551 percent
#
# epoch= 2 	 time= 7.690876722335815 min 	 lr= 0.01 	 loss= 1.8630168914794922 	 error= 74.8800003528595 percent
# error rate on dataset = 72.31818040211996 percent
#
# epoch= 3 	 time= 10.392363548278809 min 	 lr= 0.01 	 loss= 1.8705710887908935 	 error= 75.84000039100647 percent
# error rate on dataset = 79.97979720433554 percent
#
# epoch= 4 	 time= 13.13011121749878 min 	 lr= 0.01 	 loss= 1.866063690185547 	 error= 75.42000079154968 percent
# error rate on dataset = 78.96464467048645 percent
#
# epoch= 5 	 time= 15.721792459487915 min 	 lr= 0.01 	 loss= 1.8589179134368896 	 error= 74.46000027656555 percent
# error rate on dataset = 82.23737279574075 percent
#
# epoch= 6 	 time= 18.41035485267639 min 	 lr= 0.01 	 loss= 1.8608173608779908 	 error= 74.28000068664551 percent
# error rate on dataset = 81.82323376337686 percent
#
# epoch= 7 	 time= 21.016531944274902 min 	 lr= 0.01 	 loss= 1.8578832292556762 	 error= 74.66000080108643 percent
# error rate on dataset = 71.17171684900919 percent
#
# epoch= 8 	 time= 23.777448177337646 min 	 lr= 0.01 	 loss= 1.853183445930481 	 error= 74.89999985694885 percent
# error rate on dataset = 72.22222089767456 percent
#
# epoch= 9 	 time= 26.32317090034485 min 	 lr= 0.01 	 loss= 1.8443893241882323 	 error= 74.06000065803528 percent
# error rate on dataset = 68.66161823272705 percent
#
# epoch= 10 	 time= 29.023706197738647 min 	 lr= 0.01 	 loss= 1.8393916416168212 	 error= 72.96000123023987 percent
# error rate on dataset = 73.71717095375061 percent
#
# epoch= 11 	 time= 31.67216444015503 min 	 lr= 0.01 	 loss= 1.8598190975189208 	 error= 74.30000066757202 percent
# error rate on dataset = 72.3737378915151 percent
#
# epoch= 12 	 time= 34.17861557006836 min 	 lr= 0.01 	 loss= 1.8419845008850098 	 error= 73.54000091552734 percent
# error rate on dataset = 73.55050643285117 percent
#
# epoch= 13 	 time= 36.79357314109802 min 	 lr= 0.01 	 loss= 1.838338141441345 	 error= 73.3200011253357 percent
# error rate on dataset = 81.23232324918112 percent
#
# epoch= 14 	 time= 39.48954200744629 min 	 lr= 0.01 	 loss= 1.8427608299255371 	 error= 73.24000120162964 percent
# error rate on dataset = 79.37373717625937 percent
#
# epoch= 15 	 time= 42.066776275634766 min 	 lr= 0.01 	 loss= 1.843532886505127 	 error= 72.92000126838684 percent
# error rate on dataset = 70.81818183263144 percent
#
# epoch= 16 	 time= 45.12890100479126 min 	 lr= 0.01 	 loss= 1.8346444320678712 	 error= 72.94000053405762 percent
# error rate on dataset = 76.18181506792703 percent
#
# epoch= 17 	 time= 47.78856110572815 min 	 lr= 0.01 	 loss= 1.8344604206085204 	 error= 72.74000072479248 percent
# error rate on dataset = 76.34848356246948 percent
#
# epoch= 18 	 time= 50.41730546951294 min 	 lr= 0.01 	 loss= 1.8272884893417358 	 error= 73.18000054359436 percent
# error rate on dataset = 70.6010083357493 percent
#
# epoch= 19 	 time= 53.28133273124695 min 	 lr= 0.01 	 loss= 1.8269314002990722 	 error= 73.54000186920166 percent
# error rate on dataset = 77.54040559132895 percent
#
# epoch= 20 	 time= 55.911001443862915 min 	 lr= 0.01 	 loss= 1.8206992721557618 	 error= 72.22000050544739 percent
# error rate on dataset = 76.0757585366567 percent
#
# epoch= 21 	 time= 58.45903444290161 min 	 lr= 0.01 	 loss= 1.8201247358322143 	 error= 72.660001039505 percent
# error rate on dataset = 70.6818183263143 percent
#
# epoch= 22 	 time= 61.03509330749512 min 	 lr= 0.01 	 loss= 1.8306405353546142 	 error= 73.10000085830688 percent
# error rate on dataset = 76.7727275689443 percent
#
# epoch= 23 	 time= 63.573890686035156 min 	 lr= 0.01 	 loss= 1.8259577131271363 	 error= 72.94000053405762 percent
# error rate on dataset = 71.82323137919107 percent
#
# epoch= 24 	 time= 66.36341691017151 min 	 lr= 0.01 	 loss= 1.8255131340026856 	 error= 72.88000154495239 percent
# error rate on dataset = 74.10101095835367 percent
#
# epoch= 25 	 time= 69.1717791557312 min 	 lr= 0.01 	 loss= 1.8133136510849 	 error= 71.94000124931335 percent
# error rate on dataset = 80.06565570831299 percent
#
# epoch= 26 	 time= 71.78508806228638 min 	 lr= 0.01 	 loss= 1.8232996606826781 	 error= 72.24000096321106 percent
# error rate on dataset = 75.43939550717673 percent
#
# epoch= 27 	 time= 74.60361337661743 min 	 lr= 0.01 	 loss= 1.8161492538452149 	 error= 72.82000136375427 percent
# error rate on dataset = 75.30808051427206 percent
#
# epoch= 28 	 time= 77.42225384712219 min 	 lr= 0.01 	 loss= 1.818124895095825 	 error= 72.96000123023987 percent
# error rate on dataset = 71.40404184659323 percent
#
# epoch= 29 	 time= 80.77724289894104 min 	 lr= 0.01 	 loss= 1.8127566623687743 	 error= 71.78000092506409 percent
# error rate on dataset = 74.53535397847494 percent
#
# epoch= 30 	 time= 83.54023241996765 min 	 lr= 0.01 	 loss= 1.816532039642334 	 error= 72.26000094413757 percent
# error rate on dataset = 72.39393989245096 percent
#
# epoch= 31 	 time= 86.09435081481934 min 	 lr= 0.01 	 loss= 1.7917705535888673 	 error= 70.32000136375427 percent
# error rate on dataset = 77.63131260871887 percent
#
# epoch= 32 	 time= 88.72059416770935 min 	 lr= 0.01 	 loss= 1.8046774244308472 	 error= 71.660001039505 percent
# error rate on dataset = 73.81818294525146 percent
#
# epoch= 33 	 time= 91.34617924690247 min 	 lr= 0.01 	 loss= 1.8063007164001466 	 error= 71.52000117301941 percent
# error rate on dataset = 78.45454613367716 percent
#
# epoch= 34 	 time= 94.11047148704529 min 	 lr= 0.01 	 loss= 1.8086424350738526 	 error= 72.46000123023987 percent
# error rate on dataset = 74.95454549789429 percent
#
# epoch= 35 	 time= 97.11918497085571 min 	 lr= 0.01 	 loss= 1.8083346033096312 	 error= 71.42000150680542 percent
# error rate on dataset = 75.39394100507101 percent
#
# epoch= 36 	 time= 99.81343007087708 min 	 lr= 0.01 	 loss= 1.7942071533203126 	 error= 71.16000080108643 percent
# error rate on dataset = 69.09595727920532 percent
#
# epoch= 37 	 time= 102.97814440727234 min 	 lr= 0.01 	 loss= 1.7803499174118043 	 error= 70.62000131607056 percent
# error rate on dataset = 76.23737454414368 percent
#
# epoch= 38 	 time= 105.71671080589294 min 	 lr= 0.01 	 loss= 1.7952764415740967 	 error= 70.76000094413757 percent
# error rate on dataset = 75.9646455446879 percent
#
# epoch= 39 	 time= 108.28006672859192 min 	 lr= 0.01 	 loss= 1.8049366617202758 	 error= 71.24000120162964 percent
# error rate on dataset = 79.30808266003928 percent
#
# epoch= 40 	 time= 110.85733842849731 min 	 lr= 0.01 	 loss= 1.7925662040710448 	 error= 71.3000009059906 percent
# error rate on dataset = 75.51515102386475 percent
#
# epoch= 41 	 time= 113.55512070655823 min 	 lr= 0.01 	 loss= 1.7852118635177612 	 error= 70.16000008583069 percent
# error rate on dataset = 70.19191980361938 percent
#
# epoch= 42 	 time= 116.16212320327759 min 	 lr= 0.01 	 loss= 1.805198040008545 	 error= 70.92000126838684 percent
# error rate on dataset = 78.72727314631143 percent
#
# epoch= 43 	 time= 118.90995216369629 min 	 lr= 0.01 	 loss= 1.7721895933151246 	 error= 70.24000072479248 percent
# error rate on dataset = 70.93939383824667 percent
#
# epoch= 44 	 time= 121.59407758712769 min 	 lr= 0.01 	 loss= 1.7847675704956054 	 error= 70.90000128746033 percent
# error rate on dataset = 66.58080816268921 percent
#
# epoch= 45 	 time= 124.30094695091248 min 	 lr= 0.01 	 loss= 1.7833307552337647 	 error= 70.3200011253357 percent
# error rate on dataset = 68.91414324442545 percent
#
# epoch= 46 	 time= 127.14454650878906 min 	 lr= 0.01 	 loss= 1.7772825479507446 	 error= 70.08000063896179 percent
# error rate on dataset = 83.04545283317566 percent
#
# epoch= 47 	 time= 130.0514907836914 min 	 lr= 0.01 	 loss= 1.7818340492248534 	 error= 69.5400013923645 percent
# error rate on dataset = 67.83838272094727 percent
#
# epoch= 48 	 time= 132.66568732261658 min 	 lr= 0.01 	 loss= 1.7785929536819458 	 error= 70.12000131607056 percent
# error rate on dataset = 76.12626353899637 percent
#
# epoch= 49 	 time= 135.29390716552734 min 	 lr= 0.01 	 loss= 1.7797724628448486 	 error= 70.20000100135803 percent
# error rate on dataset = 67.8636352221171 percent
#
# epoch= 50 	 time= 137.87947416305542 min 	 lr= 0.01 	 loss= 1.781428542137146 	 error= 70.00000047683716 percent
# error rate on dataset = 78.29798062642416 percent
#
# epoch= 51 	 time= 140.42640447616577 min 	 lr= 0.01 	 loss= 1.7727294540405274 	 error= 69.160001039505 percent
# error rate on dataset = 71.85353636741638 percent
#
# epoch= 52 	 time= 143.20968675613403 min 	 lr= 0.01 	 loss= 1.7790507650375367 	 error= 70.32000064849854 percent
# error rate on dataset = 73.00000190734863 percent
#
# epoch= 53 	 time= 145.82055115699768 min 	 lr= 0.01 	 loss= 1.7736243867874146 	 error= 69.36000061035156 percent
# error rate on dataset = 78.8939376672109 percent
#
# epoch= 54 	 time= 148.4618525505066 min 	 lr= 0.01 	 loss= 1.7778503370285035 	 error= 69.94000101089478 percent
# error rate on dataset = 70.43434182802835 percent
#
# epoch= 55 	 time= 150.96810364723206 min 	 lr= 0.01 	 loss= 1.7539547395706176 	 error= 68.78000116348267 percent
# error rate on dataset = 77.06565658251444 percent
#
# epoch= 56 	 time= 153.65238857269287 min 	 lr= 0.01 	 loss= 1.77567702293396 	 error= 69.82000088691711 percent
# error rate on dataset = 66.06060465176901 percent
#
# epoch= 57 	 time= 156.34663772583008 min 	 lr= 0.01 	 loss= 1.7653811168670654 	 error= 69.5600004196167 percent
# error rate on dataset = 81.32323424021402 percent
#
# epoch= 58 	 time= 159.01813507080078 min 	 lr= 0.01 	 loss= 1.7716319417953492 	 error= 68.64000058174133 percent
# error rate on dataset = 74.34848546981812 percent
#
# epoch= 59 	 time= 161.6537218093872 min 	 lr= 0.01 	 loss= 1.7682803678512573 	 error= 69.9400007724762 percent
# error rate on dataset = 70.47980030377707 percent
#
# epoch= 60 	 time= 164.22323536872864 min 	 lr= 0.01 	 loss= 1.7568780517578124 	 error= 68.80000066757202 percent
# error rate on dataset = 66.83838367462158 percent
#
# epoch= 61 	 time= 166.95753288269043 min 	 lr= 0.01 	 loss= 1.759428539276123 	 error= 69.20000100135803 percent
# error rate on dataset = 72.30807940165201 percent
#
# epoch= 62 	 time= 169.86789274215698 min 	 lr= 0.01 	 loss= 1.7663438463211059 	 error= 68.66000080108643 percent
# error rate on dataset = 73.4343429406484 percent
#
# epoch= 63 	 time= 172.47394180297852 min 	 lr= 0.01 	 loss= 1.7671138620376587 	 error= 70.08000087738037 percent
# error rate on dataset = 76.45959655443826 percent
#
# epoch= 64 	 time= 175.27068185806274 min 	 lr= 0.01 	 loss= 1.7550693511962892 	 error= 68.9200005531311 percent
# error rate on dataset = 70.2373743057251 percent
#
# epoch= 65 	 time= 177.91650128364563 min 	 lr= 0.01 	 loss= 1.7501319694519042 	 error= 68.4800009727478 percent
# error rate on dataset = 75.6969710191091 percent
#
# epoch= 66 	 time= 180.71025347709656 min 	 lr= 0.01 	 loss= 1.7620740032196045 	 error= 69.3400011062622 percent
# error rate on dataset = 74.84848300615946 percent
#
# epoch= 67 	 time= 183.31836771965027 min 	 lr= 0.01 	 loss= 1.7726293754577638 	 error= 70.88000082969666 percent
# error rate on dataset = 74.1010089715322 percent
#
# epoch= 68 	 time= 186.47162652015686 min 	 lr= 0.01 	 loss= 1.7449996948242188 	 error= 68.84000039100647 percent
# error rate on dataset = 67.6919182141622 percent
#
# epoch= 69 	 time= 189.86326003074646 min 	 lr= 0.01 	 loss= 1.7493220281600952 	 error= 68.74000120162964 percent
# error rate on dataset = 78.16666762034097 percent
#
# epoch= 70 	 time= 192.65562772750854 min 	 lr= 0.01 	 loss= 1.7497025156021118 	 error= 68.80000162124634 percent
# error rate on dataset = 78.14141710599264 percent
#
# epoch= 71 	 time= 195.19262599945068 min 	 lr= 0.01 	 loss= 1.7369486618041992 	 error= 67.56000018119812 percent
# error rate on dataset = 70.30807932217917 percent
#
# epoch= 72 	 time= 197.7775661945343 min 	 lr= 0.01 	 loss= 1.7667391443252562 	 error= 69.8800003528595 percent
# error rate on dataset = 77.80808011690775 percent
#
# epoch= 73 	 time= 200.3808937072754 min 	 lr= 0.01 	 loss= 1.7496174812316894 	 error= 68.18000030517578 percent
# error rate on dataset = 68.2424227396647 percent
#
# epoch= 74 	 time= 203.23979234695435 min 	 lr= 0.01 	 loss= 1.727336392402649 	 error= 67.92000079154968 percent
# error rate on dataset = 69.63131229082742 percent
#
# epoch= 75 	 time= 206.50565123558044 min 	 lr= 0.01 	 loss= 1.7325634288787841 	 error= 67.260000705719 percent
# error rate on dataset = 72.05050587654114 percent
#
# epoch= 76 	 time= 209.08621382713318 min 	 lr= 0.01 	 loss= 1.7571870326995849 	 error= 69.08000087738037 percent
# error rate on dataset = 79.21717166900635 percent
#
# epoch= 77 	 time= 211.71017718315125 min 	 lr= 0.01 	 loss= 1.7478171157836915 	 error= 68.30000162124634 percent
# error rate on dataset = 67.84343520800272 percent
#
# epoch= 78 	 time= 214.31999969482422 min 	 lr= 0.01 	 loss= 1.7407297134399413 	 error= 69.12000155448914 percent
# error rate on dataset = 73.63131244977316 percent
#
# epoch= 79 	 time= 217.0522015094757 min 	 lr= 0.01 	 loss= 1.7423047971725465 	 error= 68.88000059127808 percent
# error rate on dataset = 75.62626202901205 percent
#
# epoch= 80 	 time= 219.68287539482117 min 	 lr= 0.01 	 loss= 1.7527783727645874 	 error= 68.52000093460083 percent
# error rate on dataset = 76.33838256200156 percent
#
# epoch= 81 	 time= 222.26450490951538 min 	 lr= 0.01 	 loss= 1.7212387323379517 	 error= 67.16000056266785 percent
# error rate on dataset = 70.37878831227621 percent
#
# epoch= 82 	 time= 224.87237215042114 min 	 lr= 0.01 	 loss= 1.7451940822601317 	 error= 68.44000029563904 percent
# error rate on dataset = 73.26262593269348 percent
#
# epoch= 83 	 time= 228.17038369178772 min 	 lr= 0.01 	 loss= 1.738837857246399 	 error= 67.2000002861023 percent
# error rate on dataset = 77.21717357635498 percent
#
# epoch= 84 	 time= 230.69626998901367 min 	 lr= 0.01 	 loss= 1.735241913795471 	 error= 68.08000016212463 percent
# error rate on dataset = 70.11616428693137 percent
#
# epoch= 85 	 time= 233.35895991325378 min 	 lr= 0.01 	 loss= 1.7262994384765624 	 error= 67.52000093460083 percent
# error rate on dataset = 76.00505153338113 percent
#
# epoch= 86 	 time= 235.9769995212555 min 	 lr= 0.01 	 loss= 1.7515426063537598 	 error= 69.26000046730042 percent
# error rate on dataset = 74.95454549789429 percent
#
# epoch= 87 	 time= 238.5617425441742 min 	 lr= 0.01 	 loss= 1.7448038244247437 	 error= 68.98000121116638 percent
# error rate on dataset = 75.04545450210571 percent
#
# epoch= 88 	 time= 241.36324071884155 min 	 lr= 0.01 	 loss= 1.7400869846343994 	 error= 67.40000033378601 percent
# error rate on dataset = 72.33838438987732 percent
#
# epoch= 89 	 time= 243.94786739349365 min 	 lr= 0.01 	 loss= 1.7230752944946288 	 error= 67.48000025749207 percent
# error rate on dataset = 73.02020192146301 percent
#
# epoch= 90 	 time= 246.6003613471985 min 	 lr= 0.01 	 loss= 1.7209266090393067 	 error= 66.80000019073486 percent
# error rate on dataset = 73.03535342216492 percent
#
# epoch= 91 	 time= 249.31274104118347 min 	 lr= 0.01 	 loss= 1.7314242124557495 	 error= 66.65999984741211 percent
# error rate on dataset = 73.68181745211282 percent
#
# epoch= 92 	 time= 252.99161386489868 min 	 lr= 0.01 	 loss= 1.733506989479065 	 error= 67.96000099182129 percent
# error rate on dataset = 68.39393973350525 percent
#
# epoch= 93 	 time= 255.68269085884094 min 	 lr= 0.01 	 loss= 1.730564122200012 	 error= 67.72000098228455 percent
# error rate on dataset = 68.78787875175476 percent
#
# epoch= 94 	 time= 258.3156280517578 min 	 lr= 0.01 	 loss= 1.7313769102096557 	 error= 67.88000106811523 percent
# error rate on dataset = 76.35858654975891 percent
#
# epoch= 95 	 time= 260.9366307258606 min 	 lr= 0.01 	 loss= 1.7427297925949097 	 error= 67.70000076293945 percent
# error rate on dataset = 68.15656423568726 percent
#
# epoch= 96 	 time= 263.76150488853455 min 	 lr= 0.01 	 loss= 1.7298525667190552 	 error= 67.3800003528595 percent
# error rate on dataset = 67.95454819997153 percent
#
# epoch= 97 	 time= 267.30351877212524 min 	 lr= 0.01 	 loss= 1.7129114198684692 	 error= 66.51999974250793 percent
# error rate on dataset = 76.71212156613669 percent
#
# epoch= 98 	 time= 269.96168661117554 min 	 lr= 0.01 	 loss= 1.7280252647399903 	 error= 67.82000041007996 percent
# error rate on dataset = 70.11616230010986 percent
#
# epoch= 99 	 time= 272.5089168548584 min 	 lr= 0.01 	 loss= 1.7280586671829223 	 error= 67.76000022888184 percent
# error rate on dataset = 65.82828362782797 percent
#
# epoch= 100 	 time= 275.1999931335449 min 	 lr= 0.01 	 loss= 1.7119547939300537 	 error= 66.84000039100647 percent
# error rate on dataset = 70.58080832163492 percent
#
# epoch= 101 	 time= 278.19166469573975 min 	 lr= 0.01 	 loss= 1.710443606376648 	 error= 66.58000016212463 percent
# error rate on dataset = 67.49494870503744 percent
#
# epoch= 102 	 time= 280.8625223636627 min 	 lr= 0.01 	 loss= 1.7108787727355956 	 error= 65.72000002861023 percent
# error rate on dataset = 74.50505097707114 percent
#
# epoch= 103 	 time= 283.4057984352112 min 	 lr= 0.01 	 loss= 1.7209930276870729 	 error= 67.30000066757202 percent
# error rate on dataset = 74.53535397847494 percent
#
# epoch= 104 	 time= 285.98629212379456 min 	 lr= 0.01 	 loss= 1.7148900508880616 	 error= 67.02000021934509 percent
# error rate on dataset = 71.51515086491904 percent
#
# epoch= 105 	 time= 288.58362078666687 min 	 lr= 0.01 	 loss= 1.726475830078125 	 error= 68.36000037193298 percent
# error rate on dataset = 74.9848484992981 percent
#
# epoch= 106 	 time= 291.2646563053131 min 	 lr= 0.01 	 loss= 1.7191400194168092 	 error= 66.46000051498413 percent
# error rate on dataset = 74.7171719868978 percent
#
# epoch= 107 	 time= 293.80500864982605 min 	 lr= 0.01 	 loss= 1.721093077659607 	 error= 67.17999958992004 percent
# error rate on dataset = 69.64141329129538 percent
#
# epoch= 108 	 time= 296.3621892929077 min 	 lr= 0.01 	 loss= 1.6971794557571411 	 error= 66.1800000667572 percent
# error rate on dataset = 68.71717174847922 percent
#
# epoch= 109 	 time= 299.10277366638184 min 	 lr= 0.01 	 loss= 1.7187547922134399 	 error= 67.26000022888184 percent
# error rate on dataset = 71.47474686304727 percent
#
# epoch= 110 	 time= 301.8217282295227 min 	 lr= 0.01 	 loss= 1.7026641321182252 	 error= 65.66000032424927 percent
# error rate on dataset = 69.4747487703959 percent
#
# epoch= 111 	 time= 304.7738265991211 min 	 lr= 0.01 	 loss= 1.7078264713287354 	 error= 66.10000038146973 percent
# error rate on dataset = 76.13131205240884 percent
#
# epoch= 112 	 time= 307.3891272544861 min 	 lr= 0.01 	 loss= 1.717768063545227 	 error= 65.86000061035156 percent
# error rate on dataset = 73.91919096310934 percent
#
# epoch= 113 	 time= 310.0957474708557 min 	 lr= 0.01 	 loss= 1.709987726211548 	 error= 66.6199996471405 percent
# error rate on dataset = 70.6010083357493 percent
#
# epoch= 114 	 time= 312.91909670829773 min 	 lr= 0.01 	 loss= 1.7137059831619263 	 error= 66.84000158309937 percent
# error rate on dataset = 78.55050365130106 percent
#
# epoch= 115 	 time= 316.4327108860016 min 	 lr= 0.01 	 loss= 1.701376004219055 	 error= 65.30000114440918 percent
# error rate on dataset = 71.71717087427774 percent
#
# epoch= 116 	 time= 319.03621554374695 min 	 lr= 0.01 	 loss= 1.7121320247650147 	 error= 66.44000005722046 percent
# error rate on dataset = 72.25757439931235 percent
#
# epoch= 117 	 time= 321.6912696361542 min 	 lr= 0.01 	 loss= 1.6977591180801392 	 error= 66.40000057220459 percent
# error rate on dataset = 77.55555709203085 percent
#
# epoch= 118 	 time= 324.3831560611725 min 	 lr= 0.01 	 loss= 1.7132154130935668 	 error= 66.78000068664551 percent
# error rate on dataset = 69.86363728841147 percent
#
# epoch= 119 	 time= 327.7057580947876 min 	 lr= 0.01 	 loss= 1.7040587854385376 	 error= 66.88000082969666 percent
# error rate on dataset = 66.4545476436615 percent
#
# epoch= 120 	 time= 330.3639624118805 min 	 lr= 0.01 	 loss= 1.7074771785736085 	 error= 66.50000023841858 percent
# error rate on dataset = 66.5656546751658 percent
#
# epoch= 121 	 time= 332.9218144416809 min 	 lr= 0.01 	 loss= 1.7006232595443727 	 error= 65.2400004863739 percent
# error rate on dataset = 69.31313077608743 percent
#
# epoch= 122 	 time= 335.5645070075989 min 	 lr= 0.01 	 loss= 1.6952234125137329 	 error= 64.98000025749207 percent
# error rate on dataset = 65.87373812993368 percent
#
# epoch= 123 	 time= 338.33418440818787 min 	 lr= 0.01 	 loss= 1.6910037660598756 	 error= 64.94000029563904 percent
# error rate on dataset = 76.0454535484314 percent
#
# epoch= 124 	 time= 340.9002413749695 min 	 lr= 0.01 	 loss= 1.693750534057617 	 error= 65.96000099182129 percent
# error rate on dataset = 68.13131173451742 percent
#
# epoch= 125 	 time= 343.56252813339233 min 	 lr= 0.01 	 loss= 1.7000554895401 	 error= 66.84000015258789 percent
# error rate on dataset = 73.83838295936584 percent
#
# epoch= 126 	 time= 346.2078800201416 min 	 lr= 0.01 	 loss= 1.6858227825164795 	 error= 65.34000062942505 percent
# error rate on dataset = 69.2727267742157 percent
#
# epoch= 127 	 time= 348.7698996067047 min 	 lr= 0.01 	 loss= 1.6954700088500976 	 error= 66.06000089645386 percent
# error rate on dataset = 69.72222129503885 percent
#
# epoch= 128 	 time= 351.5206151008606 min 	 lr= 0.01 	 loss= 1.7078020286560058 	 error= 66.11999988555908 percent
# error rate on dataset = 73.61616293589273 percent
#
# epoch= 129 	 time= 354.2728135585785 min 	 lr= 0.01 	 loss= 1.699895100593567 	 error= 66.2000002861023 percent
# error rate on dataset = 74.1919199625651 percent
#
# epoch= 130 	 time= 356.779780626297 min 	 lr= 0.01 	 loss= 1.6990808391571044 	 error= 65.70000052452087 percent
# error rate on dataset = 78.0050496260325 percent
#
# epoch= 131 	 time= 359.51882314682007 min 	 lr= 0.01 	 loss= 1.7196418285369872 	 error= 67.10000085830688 percent
# error rate on dataset = 72.78788089752197 percent
#
# epoch= 132 	 time= 362.29499340057373 min 	 lr= 0.01 	 loss= 1.700472869873047 	 error= 65.28000044822693 percent
# error rate on dataset = 73.18181792894998 percent
#
# epoch= 133 	 time= 365.58143734931946 min 	 lr= 0.01 	 loss= 1.710135350227356 	 error= 67.54000067710876 percent
# error rate on dataset = 74.53030347824097 percent
#
# epoch= 134 	 time= 368.50218057632446 min 	 lr= 0.01 	 loss= 1.6984932708740235 	 error= 65.65999960899353 percent
# error rate on dataset = 68.21717222531638 percent
#
# epoch= 135 	 time= 371.23828959465027 min 	 lr= 0.01 	 loss= 1.6927046394348144 	 error= 66.57999992370605 percent
# error rate on dataset = 79.88383769989014 percent
#
# epoch= 136 	 time= 373.83077216148376 min 	 lr= 0.01 	 loss= 1.6786451196670533 	 error= 65.2000002861023 percent
# error rate on dataset = 70.39899031321207 percent
#
# epoch= 137 	 time= 376.53031373023987 min 	 lr= 0.01 	 loss= 1.6761403036117555 	 error= 64.10000038146973 percent
# error rate on dataset = 85.21717190742493 percent
#
# epoch= 138 	 time= 379.1756806373596 min 	 lr= 0.01 	 loss= 1.745634617805481 	 error= 67.58000016212463 percent
# error rate on dataset = 67.43434270222983 percent
#
# epoch= 139 	 time= 381.74135422706604 min 	 lr= 0.01 	 loss= 1.6755404996871948 	 error= 64.84000062942505 percent
# error rate on dataset = 69.2878782749176 percent
#
# epoch= 140 	 time= 384.36156034469604 min 	 lr= 0.01 	 loss= 1.7077211475372314 	 error= 66.60000085830688 percent
# error rate on dataset = 70.21717031796774 percent
#
# epoch= 141 	 time= 386.9442574977875 min 	 lr= 0.01 	 loss= 1.6943177795410156 	 error= 65.83999919891357 percent
# error rate on dataset = 76.80303057034811 percent
#
# epoch= 142 	 time= 389.6613612174988 min 	 lr= 0.01 	 loss= 1.702454833984375 	 error= 66.14000058174133 percent
# error rate on dataset = 75.53030649820963 percent
#
# epoch= 143 	 time= 392.2521553039551 min 	 lr= 0.01 	 loss= 1.6809764909744263 	 error= 65.59999966621399 percent
# error rate on dataset = 67.13131467501321 percent
#
# epoch= 144 	 time= 394.85524582862854 min 	 lr= 0.01 	 loss= 1.688598666191101 	 error= 66.08000087738037 percent
# error rate on dataset = 68.10606122016907 percent
#
# epoch= 145 	 time= 397.632773399353 min 	 lr= 0.01 	 loss= 1.6713690423965455 	 error= 63.679999828338616 percent
# error rate on dataset = 71.22727433840433 percent
#
# epoch= 146 	 time= 400.3355555534363 min 	 lr= 0.01 	 loss= 1.7004790496826172 	 error= 65.58000040054321 percent
# error rate on dataset = 79.01514967282614 percent
#
# epoch= 147 	 time= 403.21930480003357 min 	 lr= 0.01 	 loss= 1.6846701717376709 	 error= 64.87999963760376 percent
# error rate on dataset = 67.55050420761108 percent
#
# epoch= 148 	 time= 405.855801820755 min 	 lr= 0.01 	 loss= 1.674102602005005 	 error= 65.02000021934509 percent
# error rate on dataset = 66.43939415613809 percent
#
# epoch= 149 	 time= 408.32670497894287 min 	 lr= 0.01 	 loss= 1.6712966775894165 	 error= 65.10000014305115 percent
# error rate on dataset = 72.14646538098654 percent
#
# epoch= 150 	 time= 410.96015906333923 min 	 lr= 0.01 	 loss= 1.6779633235931397 	 error= 64.52000021934509 percent
# error rate on dataset = 72.69697189331055 percent
#
# epoch= 151 	 time= 413.7992355823517 min 	 lr= 0.01 	 loss= 1.673078589439392 	 error= 65.64000034332275 percent
# error rate on dataset = 75.69191853205362 percent
#
# epoch= 152 	 time= 416.8242378234863 min 	 lr= 0.01 	 loss= 1.6883755207061768 	 error= 64.82000017166138 percent
# error rate on dataset = 73.1363614400228 percent
#
# epoch= 153 	 time= 419.5032727718353 min 	 lr= 0.01 	 loss= 1.6972644901275635 	 error= 65.97999954223633 percent
# error rate on dataset = 70.90404033660889 percent
#
# epoch= 154 	 time= 422.09355759620667 min 	 lr= 0.01 	 loss= 1.6759338998794555 	 error= 65.23999977111816 percent
# error rate on dataset = 67.37373669942221 percent
#
# epoch= 155 	 time= 424.83411598205566 min 	 lr= 0.01 	 loss= 1.6699042701721192 	 error= 64.52000021934509 percent
# error rate on dataset = 68.45959822336832 percent
#
# epoch= 156 	 time= 427.5126700401306 min 	 lr= 0.01 	 loss= 1.6588311624526977 	 error= 63.6199996471405 percent
# error rate on dataset = 70.09595831235251 percent
#
# epoch= 157 	 time= 430.10196924209595 min 	 lr= 0.01 	 loss= 1.683741536140442 	 error= 66.38000082969666 percent
# error rate on dataset = 69.23737327257791 percent
#
# epoch= 158 	 time= 432.9053997993469 min 	 lr= 0.01 	 loss= 1.653552532196045 	 error= 64.22000002861023 percent
# error rate on dataset = 65.27777910232544 percent
#
# epoch= 159 	 time= 435.58994722366333 min 	 lr= 0.01 	 loss= 1.684040765762329 	 error= 65.57999992370605 percent
# error rate on dataset = 75.10606050491333 percent
#
# epoch= 160 	 time= 438.3601460456848 min 	 lr= 0.01 	 loss= 1.6720943927764893 	 error= 64.18000054359436 percent
# error rate on dataset = 72.6414144039154 percent
#
# epoch= 161 	 time= 440.9807686805725 min 	 lr= 0.01 	 loss= 1.6621934461593628 	 error= 63.860000133514404 percent
# error rate on dataset = 74.37373797098795 percent
#
# epoch= 162 	 time= 443.7653775215149 min 	 lr= 0.01 	 loss= 1.6800272130966187 	 error= 65.16000032424927 percent
# error rate on dataset = 73.10606042544046 percent
#
# epoch= 163 	 time= 446.29762172698975 min 	 lr= 0.01 	 loss= 1.6697034978866576 	 error= 64.48000049591064 percent
# error rate on dataset = 69.50505177179971 percent
#
# epoch= 164 	 time= 448.9045968055725 min 	 lr= 0.01 	 loss= 1.6530583477020264 	 error= 62.9000005722046 percent
# error rate on dataset = 70.5050508181254 percent
#
# epoch= 165 	 time= 451.6030650138855 min 	 lr= 0.01 	 loss= 1.660564136505127 	 error= 63.96000027656555 percent
# error rate on dataset = 69.03030276298523 percent
#
# epoch= 166 	 time= 454.5669069290161 min 	 lr= 0.01 	 loss= 1.6499466609954834 	 error= 63.64000058174133 percent
# error rate on dataset = 66.42929116884866 percent
#
# epoch= 167 	 time= 457.1636338233948 min 	 lr= 0.01 	 loss= 1.675690279006958 	 error= 64.60000133514404 percent
# error rate on dataset = 69.5707062880198 percent
#
# epoch= 168 	 time= 459.76772141456604 min 	 lr= 0.01 	 loss= 1.6599910259246826 	 error= 63.72000026702881 percent
# error rate on dataset = 70.09090979894003 percent
#
# epoch= 169 	 time= 462.5779914855957 min 	 lr= 0.01 	 loss= 1.6679402351379395 	 error= 64.72000074386597 percent
# error rate on dataset = 69.01010076204935 percent
#
# epoch= 170 	 time= 465.15828251838684 min 	 lr= 0.01 	 loss= 1.665417594909668 	 error= 62.9400007724762 percent
# error rate on dataset = 66.1060611406962 percent
#
# epoch= 171 	 time= 467.6602158546448 min 	 lr= 0.01 	 loss= 1.652001895904541 	 error= 63.980000257492065 percent
# error rate on dataset = 68.00504922866821 percent
#
# epoch= 172 	 time= 470.29118514060974 min 	 lr= 0.01 	 loss= 1.666637978553772 	 error= 65.00000095367432 percent
# error rate on dataset = 72.18686938285828 percent
#
# epoch= 173 	 time= 473.0494773387909 min 	 lr= 0.01 	 loss= 1.6585812282562256 	 error= 63.5600004196167 percent
# error rate on dataset = 66.81817968686423 percent
#
# epoch= 174 	 time= 475.869264125824 min 	 lr= 0.01 	 loss= 1.6572661733627319 	 error= 63.30000019073486 percent
# error rate on dataset = 71.13131284713745 percent
#
# epoch= 175 	 time= 478.4489152431488 min 	 lr= 0.01 	 loss= 1.6440917778015136 	 error= 63.480000257492065 percent
# error rate on dataset = 72.4494973818461 percent
#
# epoch= 176 	 time= 480.98658895492554 min 	 lr= 0.01 	 loss= 1.6752608108520508 	 error= 64.66000080108643 percent
# error rate on dataset = 70.79797784487405 percent
#
# epoch= 177 	 time= 483.7130084037781 min 	 lr= 0.01 	 loss= 1.6718252944946288 	 error= 64.74000072479248 percent
# error rate on dataset = 73.97474646568298 percent
#
# epoch= 178 	 time= 486.3122487068176 min 	 lr= 0.01 	 loss= 1.6572676849365235 	 error= 64.03999996185303 percent
# error rate on dataset = 70.60606082280478 percent
#
# epoch= 179 	 time= 489.10653591156006 min 	 lr= 0.01 	 loss= 1.6445715856552123 	 error= 63.46000075340271 percent
# error rate on dataset = 68.97474726041159 percent
#
# epoch= 180 	 time= 491.9032084941864 min 	 lr= 0.01 	 loss= 1.6722118854522705 	 error= 63.98000049591065 percent
# error rate on dataset = 70.54545283317566 percent
#
# epoch= 181 	 time= 494.62030124664307 min 	 lr= 0.01 	 loss= 1.6362287998199463 	 error= 62.700000286102295 percent
# error rate on dataset = 67.87374019622803 percent
#
# epoch= 182 	 time= 497.2358863353729 min 	 lr= 0.01 	 loss= 1.6346043872833251 	 error= 62.22000098228455 percent
# error rate on dataset = 67.80808170636496 percent
#
# epoch= 183 	 time= 500.4804651737213 min 	 lr= 0.01 	 loss= 1.6608039617538453 	 error= 64.40000057220459 percent
# error rate on dataset = 65.56060711542764 percent
#
# epoch= 184 	 time= 503.19427490234375 min 	 lr= 0.01 	 loss= 1.6388880443572997 	 error= 63.04000043869018 percent
# error rate on dataset = 67.28283166885376 percent
#
# epoch= 185 	 time= 505.87374567985535 min 	 lr= 0.01 	 loss= 1.638161425590515 	 error= 63.520001173019416 percent
# error rate on dataset = 69.8888878027598 percent
#
# epoch= 186 	 time= 508.3815402984619 min 	 lr= 0.01 	 loss= 1.665359253883362 	 error= 63.820000410079956 percent
# error rate on dataset = 66.27272566159567 percent
#
# epoch= 187 	 time= 511.02515864372253 min 	 lr= 0.01 	 loss= 1.6346747636795045 	 error= 62.959999799728394 percent
# error rate on dataset = 73.77777695655823 percent
#
# epoch= 188 	 time= 513.7548215389252 min 	 lr= 0.01 	 loss= 1.6468055486679076 	 error= 63.4200005531311 percent
# error rate on dataset = 65.05555510520935 percent
#
# epoch= 189 	 time= 516.8558294773102 min 	 lr= 0.01 	 loss= 1.6426177072525023 	 error= 62.460000038146966 percent
# error rate on dataset = 69.56060528755188 percent
#
# epoch= 190 	 time= 519.4657685756683 min 	 lr= 0.01 	 loss= 1.6514907264709473 	 error= 63.480000734329224 percent
# error rate on dataset = 63.520203034083046 percent
#
# epoch= 191 	 time= 522.0046966075897 min 	 lr= 0.01 	 loss= 1.641588773727417 	 error= 63.47999978065491 percent
# error rate on dataset = 70.28283079465231 percent
#
# epoch= 192 	 time= 525.0519711971283 min 	 lr= 0.01 	 loss= 1.6494049787521363 	 error= 63.700000524520874 percent
# error rate on dataset = 66.42424265543619 percent
#
# epoch= 193 	 time= 527.6608102321625 min 	 lr= 0.01 	 loss= 1.6408627700805665 	 error= 62.5800006389618 percent
# error rate on dataset = 70.09090979894003 percent
#
# epoch= 194 	 time= 530.3368811607361 min 	 lr= 0.01 	 loss= 1.6453456640243531 	 error= 62.77999997138976 percent
# error rate on dataset = 68.0555542310079 percent
#
# epoch= 195 	 time= 533.1034750938416 min 	 lr= 0.01 	 loss= 1.6365202140808106 	 error= 62.680000305175774 percent
# error rate on dataset = 75.16161600748697 percent
#
# epoch= 196 	 time= 535.6289563179016 min 	 lr= 0.01 	 loss= 1.6459420490264893 	 error= 63.30000066757202 percent
# error rate on dataset = 69.5707062880198 percent
#
# epoch= 197 	 time= 538.3832380771637 min 	 lr= 0.01 	 loss= 1.6412205600738525 	 error= 63.5600004196167 percent
# error rate on dataset = 71.42929236094156 percent
#
# epoch= 198 	 time= 540.9646511077881 min 	 lr= 0.01 	 loss= 1.6177439546585084 	 error= 61.600001096725464 percent
# error rate on dataset = 71.13131284713745 percent
#
# epoch= 199 	 time= 543.6008870601654 min 	 lr= 0.01 	 loss= 1.678004698753357 	 error= 65.08000135421753 percent
# error rate on dataset = 70.5707093079885 percent

# %% [markdown]
# # 2. VGG Neural Networks
#
# Over here, we train a simple VGG, a Very Deep Convolutional Networks for Large-Scale Image Recognition which was propsed by Visual Geometry Group in 2014.

# %%
class VGG_convnet(nn.Module):

    def __init__(self):

        super(VGG_convnet, self).__init__()

        # block 1:         1 x 32 x 32 --> 64 x 16 x 16        
        self.conv1a = nn.Conv2d(1,   64,  kernel_size=3, padding=1 )
        self.conv1b = nn.Conv2d(64,  64,  kernel_size=3, padding=1 )
        self.pool1  = nn.MaxPool2d(2,2)

        # block 2:         64 x 16 x 16 --> 128 x 8 x 8
        self.conv2a = nn.Conv2d(64,  128, kernel_size=3, padding=1 )
        self.conv2b = nn.Conv2d(128, 128, kernel_size=3, padding=1 )
        self.pool2  = nn.MaxPool2d(2,2)

        # block 3:         128 x 8 x 8 --> 256 x 4 x 4        
        self.conv3a = nn.Conv2d(128, 256, kernel_size=3, padding=1 )
        self.conv3b = nn.Conv2d(256, 256, kernel_size=3, padding=1 )
        self.pool3  = nn.MaxPool2d(2,2)
        
        #block 4:          256 x 4 x 4 --> 512 x 2 x 2
        self.conv4a = nn.Conv2d(256, 512, kernel_size=3, padding=1 )
        self.pool4  = nn.MaxPool2d(2,2)

        # linear layers:   512 x 2 x 2 --> 2048 --> 4096 --> 4096 --> 10
        self.linear1 = nn.Linear(2048, 4096)
        self.linear2 = nn.Linear(4096,4096)
        self.linear3 = nn.Linear(4096, 10)


    def forward(self, x):

        # block 1:         3 x 32 x 32 --> 64 x 16 x 16
        x = self.conv1a(x)
        x = F.relu(x)
        x = self.conv1b(x)
        x = F.relu(x)
        x = self.pool1(x)

        # block 2:         64 x 16 x 16 --> 128 x 8 x 8
        x = self.conv2a(x)
        x = F.relu(x)
        x = self.conv2b(x)
        x = F.relu(x)
        x = self.pool2(x)

        # block 3:         128 x 8 x 8 --> 256 x 4 x 4
        x = self.conv3a(x)
        x = F.relu(x)
        x = self.conv3b(x)
        x = F.relu(x)
        x = self.pool3(x)

        #block 4:          256 x 4 x 4 --> 512 x 2 x 2
        x = self.conv4a(x)
        x = F.relu(x)
        x = self.pool4(x)

        # linear layers:   512 x 2 x 2 --> 2048 --> 4096 --> 4096 --> 10
        x = x.view(-1, 2048)
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        x = self.linear3(x) 
        
        return x

# %%
vgg = VGG_convnet()
print(vgg)
utils.display_num_param(vgg)
# Out:
# VGG_convnet(
#   (conv1a): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2a): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2b): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3a): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3b): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4a): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (linear1): Linear(in_features=2048, out_features=4096, bias=True)
#   (linear2): Linear(in_features=4096, out_features=4096, bias=True)
#   (linear3): Linear(in_features=4096, out_features=10, bias=True)
# )
# There are 27539402 (27.54 million) parameters in this neural network

# %%
vgg = vgg.to(device)

# %%
criterion = nn.CrossEntropyLoss()
my_lr=0.25

# %%
start=time.time()

for epoch in range(1,200):
    
    # divide the learning rate by 2 at epoch 10, 14 and 18
    if epoch==10 or epoch == 14 or epoch==18:
        my_lr = my_lr / 2
    
    # create a new optimizer at the beginning of each epoch: give the current learning rate.   
    optimizer=torch.optim.SGD( net.parameters() , lr=my_lr )
        
    # set the running quatities to zero at the beginning of the epoch
    running_loss=0
    running_error=0
    num_batches=0
    
    for minibatch_data, minibatch_label in train_dl:
        # Set the gradients to zeros
        optimizer.zero_grad()
        
        # send them to the gpu
        minibatch_data=minibatch_data.to(device)
        minibatch_label=minibatch_label.to(device)
        
        # reshape the minibatch
        inputs = minibatch_data.view(-1, 1, 32, 32)

        # tell Pytorch to start tracking all operations that will be done on "inputs"
        inputs.requires_grad_()

        # forward the minibatch through the net 
        scores=net( inputs ) 

        # Compute the average of the losses of the data points in the minibatch
        loss =  criterion( scores , minibatch_label) 
        
        # backward pass to compute dL/dU, dL/dV and dL/dW   
        loss.backward()

        # do one step of stochastic gradient descent: U=U-lr(dL/dU), V=V-lr(dL/dU), ...
        optimizer.step()
        

        # START COMPUTING STATS
        
        # add the loss of this batch to the running loss
        running_loss += loss.detach().item()
        
        # compute the error made on this batch and add it to the running error       
        error = utils.get_error( scores.detach() , minibatch_label)
        running_error += error.item()
        
        num_batches+=1        
    
    
    # compute stats for the full training set
    total_loss = running_loss/num_batches
    total_error = running_error/num_batches
    elapsed = (time.time()-start)/60
    

    print('epoch=',epoch, '\t time=', elapsed,'min','\t lr=', my_lr  ,'\t loss=', total_loss , '\t error=', total_error*100 ,'percent')
    eval_on_dataset_loader(vgg, train_dl)
    print(' ')
# Out:
# epoch= 1 	 time= 0.16052822271982828 min 	 lr= 0.25 	 loss= 2.019545246645347 	 error= 82.12371173593186 percent
# error rate on test set = 81.45454525947571 percent
#
# epoch= 2 	 time= 0.33595306078592935 min 	 lr= 0.25 	 loss= 1.9555120480429267 	 error= 82.08247478475276 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 3 	 time= 0.5116730650266011 min 	 lr= 0.25 	 loss= 1.9491242944579763 	 error= 82.30927869216683 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 4 	 time= 0.6883858442306519 min 	 lr= 0.25 	 loss= 1.9464216392064833 	 error= 81.62886629399566 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 5 	 time= 0.8643346468607584 min 	 lr= 0.25 	 loss= 1.9442517732836537 	 error= 81.29896933270484 percent
# error rate on test set = 87.09090948104858 percent
#
# epoch= 6 	 time= 1.036573048432668 min 	 lr= 0.25 	 loss= 1.9432222646536286 	 error= 81.83505227885294 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 7 	 time= 1.2103716532389324 min 	 lr= 0.25 	 loss= 1.9440146930438955 	 error= 81.56701074433082 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 8 	 time= 1.380284357070923 min 	 lr= 0.25 	 loss= 1.9418596520866316 	 error= 81.85567063154635 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 9 	 time= 1.5512093901634216 min 	 lr= 0.25 	 loss= 1.9423316237852746 	 error= 81.2783507342191 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 10 	 time= 1.7207258065541586 min 	 lr= 0.125 	 loss= 1.9383834674186313 	 error= 80.9072171904377 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 11 	 time= 1.8945247769355773 min 	 lr= 0.125 	 loss= 1.9375313876830424 	 error= 80.7422682182076 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 12 	 time= 2.066851802666982 min 	 lr= 0.125 	 loss= 1.9380281094423275 	 error= 80.72164986551422 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 13 	 time= 2.240915668010712 min 	 lr= 0.125 	 loss= 1.935679101452385 	 error= 81.07216536384267 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 14 	 time= 2.417655551433563 min 	 lr= 0.0625 	 loss= 1.9354584057306505 	 error= 80.86597987057007 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 15 	 time= 2.5941766023635866 min 	 lr= 0.0625 	 loss= 1.9353706566328854 	 error= 80.88659828471154 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 16 	 time= 2.7713255127271017 min 	 lr= 0.0625 	 loss= 1.934105093946162 	 error= 80.72164980406615 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 17 	 time= 2.9497241775194802 min 	 lr= 0.0625 	 loss= 1.9354609214153486 	 error= 80.84536108774009 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 18 	 time= 3.124914840857188 min 	 lr= 0.03125 	 loss= 1.9333565874198049 	 error= 80.59793845894411 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 19 	 time= 3.2999334295590717 min 	 lr= 0.03125 	 loss= 1.9339006303511943 	 error= 80.7628869395895 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 20 	 time= 3.473918588956197 min 	 lr= 0.03125 	 loss= 1.9334246055367066 	 error= 80.61855736467027 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 21 	 time= 3.64662561416626 min 	 lr= 0.03125 	 loss= 1.9338537528342807 	 error= 80.72164974261806 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 22 	 time= 3.8229596773783365 min 	 lr= 0.03125 	 loss= 1.9331823759472246 	 error= 80.72164980406615 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 23 	 time= 3.997994593779246 min 	 lr= 0.03125 	 loss= 1.933456720765104 	 error= 80.76288669379717 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 24 	 time= 4.1756946961085 min 	 lr= 0.03125 	 loss= 1.933597670387976 	 error= 80.68041266854277 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 25 	 time= 4.348475130399068 min 	 lr= 0.03125 	 loss= 1.933074492769143 	 error= 80.78350541517906 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 26 	 time= 4.522015007336934 min 	 lr= 0.03125 	 loss= 1.9337960665987939 	 error= 80.72165011130657 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 27 	 time= 4.694840693473816 min 	 lr= 0.03125 	 loss= 1.933499466512621 	 error= 80.7835057838676 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 28 	 time= 4.867517558733622 min 	 lr= 0.03125 	 loss= 1.9338408819178945 	 error= 80.72164986551422 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 29 	 time= 5.042272222042084 min 	 lr= 0.03125 	 loss= 1.9332444360575725 	 error= 80.74226840255186 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 30 	 time= 5.216053132216135 min 	 lr= 0.03125 	 loss= 1.9324700709470768 	 error= 80.65979443874556 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 31 	 time= 5.394228251775106 min 	 lr= 0.03125 	 loss= 1.9331636723783827 	 error= 80.7628870010376 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 32 	 time= 5.568822193145752 min 	 lr= 0.03125 	 loss= 1.9318263702785845 	 error= 80.88659822326345 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 33 	 time= 5.746372028191884 min 	 lr= 0.03125 	 loss= 1.9328004134070014 	 error= 80.72164961972189 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 34 	 time= 5.925148673852285 min 	 lr= 0.03125 	 loss= 1.9321314932144795 	 error= 80.68041279143894 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 35 	 time= 6.099864093462626 min 	 lr= 0.03125 	 loss= 1.9323341072220164 	 error= 80.6804129757832 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 36 	 time= 6.278474577267965 min 	 lr= 0.03125 	 loss= 1.9321695836548953 	 error= 80.74226846399995 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 37 	 time= 6.456819224357605 min 	 lr= 0.03125 	 loss= 1.931684609540959 	 error= 80.74226827965569 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 38 	 time= 6.631294409434001 min 	 lr= 0.03125 	 loss= 1.9315227663394101 	 error= 80.70103132847657 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 39 	 time= 6.807824726899465 min 	 lr= 0.03125 	 loss= 1.9305703529377574 	 error= 80.68041291433511 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 40 	 time= 6.982254707813263 min 	 lr= 0.03125 	 loss= 1.9306694281469916 	 error= 80.76288718538186 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 41 	 time= 7.15846688747406 min 	 lr= 0.03125 	 loss= 1.9305209167224844 	 error= 80.61855699598175 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 42 	 time= 7.335222633679708 min 	 lr= 0.03125 	 loss= 1.9297040049562748 	 error= 80.65979388571277 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 43 	 time= 7.516233233610789 min 	 lr= 0.03125 	 loss= 1.9291154760675333 	 error= 80.82474298083905 percent
# error rate on test set = 78.78409136425365 percent
#
# epoch= 44 	 time= 7.693091396490733 min 	 lr= 0.03125 	 loss= 1.9286762549705112 	 error= 80.90721682174919 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 45 	 time= 7.872366841634115 min 	 lr= 0.03125 	 loss= 1.9283212914909285 	 error= 81.03092822831931 percent
# error rate on test set = 80.34090995788574 percent
#
# epoch= 46 	 time= 8.052373627821604 min 	 lr= 0.03125 	 loss= 1.9283142175871073 	 error= 80.7835052308348 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 47 	 time= 8.231864587465923 min 	 lr= 0.03125 	 loss= 1.927083798290528 	 error= 80.96907230996594 percent
# error rate on test set = 81.27272725105286 percent
#
# epoch= 48 	 time= 8.410572278499604 min 	 lr= 0.03125 	 loss= 1.9270825238571954 	 error= 80.57731998335454 percent
# error rate on test set = 80.36363666707818 percent
#
# epoch= 49 	 time= 8.588834790388743 min 	 lr= 0.03125 	 loss= 1.9266707626814694 	 error= 80.5567010161803 percent
# error rate on test set = 81.42045519568704 percent
#
# epoch= 50 	 time= 8.765416300296783 min 	 lr= 0.03125 	 loss= 1.9254771151493506 	 error= 80.37113473587429 percent
# error rate on test set = 80.54545467550103 percent
#
# epoch= 51 	 time= 8.940456978480022 min 	 lr= 0.03125 	 loss= 1.9262704787795077 	 error= 80.41237168705341 percent
# error rate on test set = 80.00000010837208 percent
#
# epoch= 52 	 time= 9.115635633468628 min 	 lr= 0.03125 	 loss= 1.9256724918011539 	 error= 80.43299053133148 percent
# error rate on test set = 80.36363666707818 percent
#
# epoch= 53 	 time= 9.29198434750239 min 	 lr= 0.03125 	 loss= 1.924069271874182 	 error= 80.20618582509228 percent
# error rate on test set = 80.72727268392389 percent
#
# epoch= 54 	 time= 9.469819704691568 min 	 lr= 0.03125 	 loss= 1.9250711141173373 	 error= 80.72164986551422 percent
# error rate on test set = 78.96590991453691 percent
#
# epoch= 55 	 time= 9.646781889597575 min 	 lr= 0.03125 	 loss= 1.924684528223018 	 error= 80.39175302711958 percent
# error rate on test set = 80.18181865865533 percent
#
# epoch= 56 	 time= 9.818519230683645 min 	 lr= 0.03125 	 loss= 1.922123085592211 	 error= 80.51546455658588 percent
# error rate on test set = 82.53409103913741 percent
#
# epoch= 57 	 time= 9.994798036416372 min 	 lr= 0.03125 	 loss= 1.9245953301793521 	 error= 80.41237174850149 percent
# error rate on test set = 80.3636372089386 percent
#
# epoch= 58 	 time= 10.17326216697693 min 	 lr= 0.03125 	 loss= 1.924194750097609 	 error= 80.30927881752092 percent
# error rate on test set = 80.36363666707818 percent
#
# epoch= 59 	 time= 10.350094270706176 min 	 lr= 0.03125 	 loss= 1.9218135936973022 	 error= 80.63917541012322 percent
# error rate on test set = 80.36363666707818 percent
#
# epoch= 60 	 time= 10.52813852628072 min 	 lr= 0.03125 	 loss= 1.9237263817148111 	 error= 80.18556777963933 percent
# error rate on test set = 81.27272833477367 percent
#
# epoch= 61 	 time= 10.707688291867575 min 	 lr= 0.03125 	 loss= 1.9211648665752608 	 error= 80.7010312055804 percent
# error rate on test set = 80.90909177606757 percent
#
# epoch= 62 	 time= 10.882754596074422 min 	 lr= 0.03125 	 loss= 1.9191700060343004 	 error= 80.28866003469093 percent
# error rate on test set = 80.87500008669767 percent
#
# epoch= 63 	 time= 11.061437344551086 min 	 lr= 0.03125 	 loss= 1.9176191828914524 	 error= 80.536082724935 percent
# error rate on test set = 78.94318212162365 percent
#
# epoch= 64 	 time= 11.238350172837576 min 	 lr= 0.03125 	 loss= 1.9183925070713477 	 error= 80.47422754395869 percent
# error rate on test set = 81.27272833477367 percent
#
# epoch= 65 	 time= 11.416601876417795 min 	 lr= 0.03125 	 loss= 1.9151203730671675 	 error= 80.16494899680934 percent
# error rate on test set = 78.840909762816 percent
#
# epoch= 66 	 time= 11.591730435689291 min 	 lr= 0.03125 	 loss= 1.9128205665608042 	 error= 79.27835110536556 percent
# error rate on test set = 78.8409092209556 percent
#
# epoch= 67 	 time= 11.771473681926727 min 	 lr= 0.03125 	 loss= 1.9114611124254994 	 error= 79.91752630656528 percent
# error rate on test set = 83.20454521612687 percent
#
# epoch= 68 	 time= 11.949623115857442 min 	 lr= 0.03125 	 loss= 1.9079344260323907 	 error= 78.59793852285011 percent
# error rate on test set = 75.6363646550612 percent
#
# epoch= 69 	 time= 12.12688516775767 min 	 lr= 0.03125 	 loss= 1.9037490493243503 	 error= 78.45360851779427 percent
# error rate on test set = 79.40909103913741 percent
#
# epoch= 70 	 time= 12.303053053220113 min 	 lr= 0.03125 	 loss= 1.9007866542363905 	 error= 78.35051564826179 percent
# error rate on test set = 77.27272781458768 percent
#
# epoch= 71 	 time= 12.481492133935292 min 	 lr= 0.03125 	 loss= 1.894291297676637 	 error= 77.56701074924666 percent
# error rate on test set = 74.59090893918817 percent
#
# epoch= 72 	 time= 12.658549745877584 min 	 lr= 0.03125 	 loss= 1.8888031821889975 	 error= 77.71134100009486 percent
# error rate on test set = 77.93181863698092 percent
#
# epoch= 73 	 time= 12.83618403673172 min 	 lr= 0.03125 	 loss= 1.882814152953551 	 error= 77.25773269368202 percent
# error rate on test set = 74.87500039013949 percent
#
# epoch= 74 	 time= 13.010806028048197 min 	 lr= 0.03125 	 loss= 1.874278192667617 	 error= 76.74226865326006 percent
# error rate on test set = 76.63636370138688 percent
#
# epoch= 75 	 time= 13.188963953653971 min 	 lr= 0.03125 	 loss= 1.866927361979927 	 error= 75.50515514059165 percent
# error rate on test set = 75.2727291800759 percent
#
# epoch= 76 	 time= 13.36552426815033 min 	 lr= 0.03125 	 loss= 1.8590018306810832 	 error= 75.5051548947993 percent
# error rate on test set = 75.43181722814386 percent
#
# epoch= 77 	 time= 13.541527318954468 min 	 lr= 0.03125 	 loss= 1.851847992729895 	 error= 75.38144422560623 percent
# error rate on test set = 73.82954521612687 percent
#
# epoch= 78 	 time= 13.71840888261795 min 	 lr= 0.03125 	 loss= 1.8453527000761523 	 error= 74.76288749999607 percent
# error rate on test set = 74.50000101869757 percent
#
# epoch= 79 	 time= 13.8940753976504 min 	 lr= 0.03125 	 loss= 1.82710237109784 	 error= 73.6701035622469 percent
# error rate on test set = 72.31818275018172 percent
#
# epoch= 80 	 time= 14.070192631085714 min 	 lr= 0.03125 	 loss= 1.8234127944277734 	 error= 73.5876295369925 percent
# error rate on test set = 70.96590941602533 percent
#
# epoch= 81 	 time= 14.246747867266338 min 	 lr= 0.03125 	 loss= 1.813999544713915 	 error= 73.13402098478731 percent
# error rate on test set = 72.67045432871039 percent
#
# epoch= 82 	 time= 14.424071725209554 min 	 lr= 0.03125 	 loss= 1.809770230165462 	 error= 72.72164993679401 percent
# error rate on test set = 72.36363671042703 percent
#
# epoch= 83 	 time= 14.601392467816671 min 	 lr= 0.03125 	 loss= 1.8010903940987342 	 error= 71.95876326757607 percent
# error rate on test set = 77.87499969655816 percent
#
# epoch= 84 	 time= 14.778580824534098 min 	 lr= 0.03125 	 loss= 1.7944030380740608 	 error= 71.62886704366231 percent
# error rate on test set = 72.69318212162365 percent
#
# epoch= 85 	 time= 14.958258966604868 min 	 lr= 0.03125 	 loss= 1.7819800167968594 	 error= 72.14433034670722 percent
# error rate on test set = 70.52272829142484 percent
#
# epoch= 86 	 time= 15.13366725842158 min 	 lr= 0.03125 	 loss= 1.7696769372704102 	 error= 70.61855706971946 percent
# error rate on test set = 69.43181807344611 percent
#
# epoch= 87 	 time= 15.310980939865113 min 	 lr= 0.03125 	 loss= 1.7679413901161902 	 error= 70.49484615473403 percent
# error rate on test set = 67.75000149553473 percent
#
# epoch= 88 	 time= 15.48768751223882 min 	 lr= 0.03125 	 loss= 1.7560765792414086 	 error= 69.25773245772136 percent
# error rate on test set = 68.84091008793224 percent
#
# epoch= 89 	 time= 15.665140469868978 min 	 lr= 0.03125 	 loss= 1.7470463207087565 	 error= 68.41237207048947 percent
# error rate on test set = 66.97727225043558 percent
#
# epoch= 90 	 time= 15.844214777151743 min 	 lr= 0.03125 	 loss= 1.7440099175443355 	 error= 69.56701137355923 percent
# error rate on test set = 68.76136389645663 percent
#
# epoch= 91 	 time= 16.021840206782024 min 	 lr= 0.03125 	 loss= 1.7286820915556445 	 error= 67.6288663726492 percent
# error rate on test set = 68.39772733775052 percent
#
# epoch= 92 	 time= 16.199610658486684 min 	 lr= 0.03125 	 loss= 1.7200388650304264 	 error= 68.10309358478821 percent
# error rate on test set = 68.92045465382662 percent
#
# epoch= 93 	 time= 16.376054108142853 min 	 lr= 0.03125 	 loss= 1.717399487790373 	 error= 68.12371230617012 percent
# error rate on test set = 66.81818203492598 percent
#
# epoch= 94 	 time= 16.555346175034842 min 	 lr= 0.03125 	 loss= 1.7053552398976592 	 error= 66.35051615459403 percent
# error rate on test set = 68.81818121129815 percent
#
# epoch= 95 	 time= 16.731302392482757 min 	 lr= 0.03125 	 loss= 1.7041543009354896 	 error= 66.61855725897956 percent
# error rate on test set = 70.06818110292609 percent
#
# epoch= 96 	 time= 16.90601748228073 min 	 lr= 0.03125 	 loss= 1.6897016493315549 	 error= 66.49484603675371 percent
# error rate on test set = 65.56818214329806 percent
#
# epoch= 97 	 time= 17.077899940808614 min 	 lr= 0.03125 	 loss= 1.6860563189712996 	 error= 66.10309371014232 percent
# error rate on test set = 64.17045593261719 percent
#
# epoch= 98 	 time= 17.256335520744322 min 	 lr= 0.03125 	 loss= 1.6737131568574415 	 error= 66.12371144835481 percent
# error rate on test set = 65.52272818305276 percent
#
# epoch= 99 	 time= 17.431722315152488 min 	 lr= 0.03125 	 loss= 1.6704940992532318 	 error= 64.74226879090378 percent
# error rate on test set = 64.84090956774625 percent
#
# epoch= 100 	 time= 17.60707573890686 min 	 lr= 0.03125 	 loss= 1.6573482567502051 	 error= 64.84536153754009 percent
# error rate on test set = 65.69318175315857 percent
#
# epoch= 101 	 time= 17.78621589342753 min 	 lr= 0.03125 	 loss= 1.6563971091791527 	 error= 64.26804176310903 percent
# error rate on test set = 66.81818203492598 percent
#
# epoch= 102 	 time= 17.96485393444697 min 	 lr= 0.03125 	 loss= 1.6398389597528988 	 error= 63.95876383044056 percent
# error rate on test set = 63.102274049412124 percent
#
# epoch= 103 	 time= 18.143370882670084 min 	 lr= 0.03125 	 loss= 1.6265936475439169 	 error= 64.12371231108597 percent
# error rate on test set = 67.25000143051147 percent
#
# epoch= 104 	 time= 18.325059747695924 min 	 lr= 0.03125 	 loss= 1.6245437553248454 	 error= 62.41237213931132 percent
# error rate on test set = 65.45454588803378 percent
#
# epoch= 105 	 time= 18.504397650559742 min 	 lr= 0.03125 	 loss= 1.6191659686491662 	 error= 63.17525880852926 percent
# error rate on test set = 63.40909220955589 percent
#
# epoch= 106 	 time= 18.682694307963054 min 	 lr= 0.03125 	 loss= 1.6182316738305633 	 error= 62.90721684387049 percent
# error rate on test set = 63.26136318120089 percent
#
# epoch= 107 	 time= 18.86254997253418 min 	 lr= 0.03125 	 loss= 1.6001763687920325 	 error= 61.85567053322939 percent
# error rate on test set = 60.78409173271873 percent
#
# epoch= 108 	 time= 19.038921312491098 min 	 lr= 0.03125 	 loss= 1.5960503841183848 	 error= 62.22680487583593 percent
# error rate on test set = 62.522727251052856 percent
#
# epoch= 109 	 time= 19.214438927173614 min 	 lr= 0.03125 	 loss= 1.5960629404205637 	 error= 62.26804164267078 percent
# error rate on test set = 61.443182555111974 percent
#
# epoch= 110 	 time= 19.391205640633903 min 	 lr= 0.03125 	 loss= 1.5777382346772657 	 error= 61.58762967463621 percent
# error rate on test set = 61.93181818181818 percent
#
# epoch= 111 	 time= 19.56958175500234 min 	 lr= 0.03125 	 loss= 1.5741824440120422 	 error= 60.185567619874305 percent
# error rate on test set = 60.863637924194336 percent
#
# epoch= 112 	 time= 19.749676541487375 min 	 lr= 0.03125 	 loss= 1.5609235898735596 	 error= 60.90721752225738 percent
# error rate on test set = 61.96591041304848 percent
#
# epoch= 113 	 time= 19.928732148806255 min 	 lr= 0.03125 	 loss= 1.554122986252775 	 error= 60.18556774277049 percent
# error rate on test set = 62.340909784490414 percent
#
# epoch= 114 	 time= 20.106204982598623 min 	 lr= 0.03125 	 loss= 1.5510159288485026 	 error= 60.02061956936551 percent
# error rate on test set = 59.465909546071835 percent
#
# epoch= 115 	 time= 20.285120936234794 min 	 lr= 0.03125 	 loss= 1.5349998904257705 	 error= 59.587629738542226 percent
# error rate on test set = 61.55681935223666 percent
#
# epoch= 116 	 time= 20.46657478014628 min 	 lr= 0.03125 	 loss= 1.5348699203471547 	 error= 59.09278441950217 percent
# error rate on test set = 59.26136374473572 percent
#
# epoch= 117 	 time= 20.643152252833048 min 	 lr= 0.03125 	 loss= 1.525413028972665 	 error= 58.51546446072686 percent
# error rate on test set = 59.30681933056224 percent
#
# epoch= 118 	 time= 20.824201154708863 min 	 lr= 0.03125 	 loss= 1.5235372327037693 	 error= 58.329897565939994 percent
# error rate on test set = 59.75000045516274 percent
#
# epoch= 119 	 time= 21.00303211212158 min 	 lr= 0.03125 	 loss= 1.5071762517555474 	 error= 57.91752657939478 percent
# error rate on test set = 57.90909095243975 percent
#
# epoch= 120 	 time= 21.183395993709563 min 	 lr= 0.03125 	 loss= 1.4991720546152174 	 error= 57.505155592849576 percent
# error rate on test set = 61.90909093076532 percent
#
# epoch= 121 	 time= 21.36128970781962 min 	 lr= 0.03125 	 loss= 1.4955006174205505 	 error= 56.86598045309794 percent
# error rate on test set = 67.98863627693869 percent
#
# epoch= 122 	 time= 21.540926420688628 min 	 lr= 0.03125 	 loss= 1.4762027079297095 	 error= 56.5154648933214 percent
# error rate on test set = 57.625001668930054 percent
#
# epoch= 123 	 time= 21.718884805838268 min 	 lr= 0.03125 	 loss= 1.47628088464442 	 error= 56.5154648933214 percent
# error rate on test set = 56.25000108372081 percent
#
# epoch= 124 	 time= 21.900348587830862 min 	 lr= 0.03125 	 loss= 1.462811997256328 	 error= 55.83505280239066 percent
# error rate on test set = 56.86363632028753 percent
#
# epoch= 125 	 time= 22.081785555680593 min 	 lr= 0.03125 	 loss= 1.4551054448196568 	 error= 55.23711418368153 percent
# error rate on test set = 55.82954612645236 percent
#
# epoch= 126 	 time= 22.26220999956131 min 	 lr= 0.03125 	 loss= 1.437827525679598 	 error= 54.474227698807866 percent
# error rate on test set = 56.17045651782643 percent
#
# epoch= 127 	 time= 22.445402491092683 min 	 lr= 0.03125 	 loss= 1.4264066231619452 	 error= 54.12371244627175 percent
# error rate on test set = 58.000000498511575 percent
#
# epoch= 128 	 time= 22.626028382778166 min 	 lr= 0.03125 	 loss= 1.4251857430664534 	 error= 53.60824834440172 percent
# error rate on test set = 71.8295460397547 percent
#
# epoch= 129 	 time= 22.804371778170268 min 	 lr= 0.03125 	 loss= 1.4144208197741164 	 error= 54.020619822531636 percent
# error rate on test set = 59.44318229501898 percent
#
# epoch= 130 	 time= 22.98585546016693 min 	 lr= 0.03125 	 loss= 1.3980921396275157 	 error= 52.90721765498525 percent
# error rate on test set = 54.556818983771585 percent
#
# epoch= 131 	 time= 23.166493582725526 min 	 lr= 0.03125 	 loss= 1.3972337147624223 	 error= 52.22680531826216 percent
# error rate on test set = 63.53409127755598 percent
#
# epoch= 132 	 time= 23.348709197839103 min 	 lr= 0.03125 	 loss= 1.3872978257149766 	 error= 51.979382197881485 percent
# error rate on test set = 59.69318368218162 percent
#
# epoch= 133 	 time= 23.53088131348292 min 	 lr= 0.03125 	 loss= 1.3770400519223558 	 error= 51.75257798322698 percent
# error rate on test set = 58.079546148126774 percent
#
# epoch= 134 	 time= 23.712230249245962 min 	 lr= 0.03125 	 loss= 1.3634856066752954 	 error= 51.505156030359956 percent
# error rate on test set = 58.03409164602106 percent
#
# epoch= 135 	 time= 23.8918474038442 min 	 lr= 0.03125 	 loss= 1.363784933827587 	 error= 51.587630055614355 percent
# error rate on test set = 59.26136428659613 percent
#
# epoch= 136 	 time= 24.07425004641215 min 	 lr= 0.03125 	 loss= 1.342142212022211 	 error= 50.49484636365753 percent
# error rate on test set = 54.943182251670144 percent
#
# epoch= 137 	 time= 24.254772222042085 min 	 lr= 0.03125 	 loss= 1.342406909490369 	 error= 50.53608362207708 percent
# error rate on test set = 56.31818229501898 percent
#
# epoch= 138 	 time= 24.43941377401352 min 	 lr= 0.03125 	 loss= 1.3283902898277204 	 error= 49.64948560773712 percent
# error rate on test set = 56.77272785793651 percent
#
# epoch= 139 	 time= 24.620780758063 min 	 lr= 0.03125 	 loss= 1.3188740383718431 	 error= 50.41237239985122 percent
# error rate on test set = 52.784092317927964 percent
#
# epoch= 140 	 time= 24.80235030253728 min 	 lr= 0.03125 	 loss= 1.2977033411104655 	 error= 47.958764218792474 percent
# error rate on test set = 54.23863638531078 percent
#
# epoch= 141 	 time= 24.98376611073812 min 	 lr= 0.03125 	 loss= 1.2802718933095638 	 error= 47.917527267613366 percent
# error rate on test set = 59.715910391374074 percent
#
# epoch= 142 	 time= 25.166232967376708 min 	 lr= 0.03125 	 loss= 1.2832554443595336 	 error= 48.9072176599011 percent
# error rate on test set = 53.89772870323875 percent
#
# epoch= 143 	 time= 25.346542223294577 min 	 lr= 0.03125 	 loss= 1.2543523870792586 	 error= 47.19587761102264 percent
# error rate on test set = 54.863636602054946 percent
#
# epoch= 144 	 time= 25.52553403377533 min 	 lr= 0.03125 	 loss= 1.2374049511152445 	 error= 46.20618697294255 percent
# error rate on test set = 53.85227311741222 percent
#
# epoch= 145 	 time= 25.70286262432734 min 	 lr= 0.03125 	 loss= 1.24393909862361 	 error= 46.474228077328085 percent
# error rate on test set = 54.84091097658331 percent
#
# epoch= 146 	 time= 25.88683128754298 min 	 lr= 0.03125 	 loss= 1.2202225352070994 	 error= 45.3195893887392 percent
# error rate on test set = 59.50000177730214 percent
#
# epoch= 147 	 time= 26.07148285706838 min 	 lr= 0.03125 	 loss= 1.2059513361183638 	 error= 44.288661369343394 percent
# error rate on test set = 53.48863818428733 percent
#
# epoch= 148 	 time= 26.254608527819315 min 	 lr= 0.03125 	 loss= 1.1859051984610016 	 error= 43.97938300653831 percent
# error rate on test set = 55.522727966308594 percent
#
# epoch= 149 	 time= 26.435846904913586 min 	 lr= 0.03125 	 loss= 1.1843089860739167 	 error= 43.56701183564884 percent
# error rate on test set = 53.25000015172091 percent
#
# epoch= 150 	 time= 26.618368224302927 min 	 lr= 0.03125 	 loss= 1.1707760968159155 	 error= 43.38144469506962 percent
# error rate on test set = 59.840910543094985 percent
#
# epoch= 151 	 time= 26.799894857406617 min 	 lr= 0.03125 	 loss= 1.148601975637613 	 error= 41.958764164718154 percent
# error rate on test set = 53.02272764119235 percent
#
# epoch= 152 	 time= 26.980521380901337 min 	 lr= 0.03125 	 loss= 1.1365962778170084 	 error= 42.824743703468556 percent
# error rate on test set = 56.80681846358559 percent
#
# epoch= 153 	 time= 27.161717275778454 min 	 lr= 0.03125 	 loss= 1.1192227300909376 	 error= 41.52577494837574 percent
# error rate on test set = 56.022728573192246 percent
#
# epoch= 154 	 time= 27.341721359888712 min 	 lr= 0.03125 	 loss= 1.1152837313327593 	 error= 41.40206335746136 percent
# error rate on test set = 58.829546516591854 percent
#
# epoch= 155 	 time= 27.520644994576774 min 	 lr= 0.03125 	 loss= 1.0671975391427266 	 error= 39.54639336497514 percent
# error rate on test set = 59.88636396147988 percent
#
# epoch= 156 	 time= 27.698707679907482 min 	 lr= 0.03125 	 loss= 1.0921148590205871 	 error= 40.00000148704371 percent
# error rate on test set = 53.590910543094985 percent
#
# epoch= 157 	 time= 27.877548937002818 min 	 lr= 0.03125 	 loss= 1.044615392832412 	 error= 38.47422777991934 percent
# error rate on test set = 55.897727879610926 percent
#
# epoch= 158 	 time= 28.058466629187265 min 	 lr= 0.03125 	 loss= 1.034455500927168 	 error= 38.28866131526908 percent
# error rate on test set = 52.579546516591854 percent
#
# epoch= 159 	 time= 28.240092074871065 min 	 lr= 0.03125 	 loss= 1.0101730252049632 	 error= 36.1237128370816 percent
# error rate on test set = 54.045456106012516 percent
#
# epoch= 160 	 time= 28.419613925615945 min 	 lr= 0.03125 	 loss= 1.0014362544128574 	 error= 37.25773341876945 percent
# error rate on test set = 56.62500099702314 percent
#
# epoch= 161 	 time= 28.60061534643173 min 	 lr= 0.03125 	 loss= 0.9833575179896403 	 error= 36.55670248356062 percent
# error rate on test set = 56.36363788084551 percent
#
# epoch= 162 	 time= 28.783534971872964 min 	 lr= 0.03125 	 loss= 0.9665578450124288 	 error= 35.42268184042469 percent
# error rate on test set = 60.84091013128107 percent
#
# epoch= 163 	 time= 28.96589869260788 min 	 lr= 0.03125 	 loss= 0.9481477915626211 	 error= 33.979383080276016 percent
# error rate on test set = 57.31818296692588 percent
#
# epoch= 164 	 time= 29.148845279216765 min 	 lr= 0.03125 	 loss= 0.9186499641113675 	 error= 33.23711476375147 percent
# error rate on test set = 52.53409255634654 percent
#
# epoch= 165 	 time= 29.32970544497172 min 	 lr= 0.03125 	 loss= 0.8996290005359453 	 error= 32.72165078477761 percent
# error rate on test set = 54.681819677352905 percent
#
# epoch= 166 	 time= 29.511141296227773 min 	 lr= 0.03125 	 loss= 0.8884018481392222 	 error= 32.82474383865435 percent
# error rate on test set = 57.57954608310353 percent
#
# epoch= 167 	 time= 29.690944159030913 min 	 lr= 0.03125 	 loss= 0.8646120072640094 	 error= 31.134022203917354 percent
# error rate on test set = 58.28409194946289 percent
#
# epoch= 168 	 time= 29.872451515992484 min 	 lr= 0.03125 	 loss= 0.8458032162533593 	 error= 30.78350676703699 percent
# error rate on test set = 56.94318251176313 percent
#
# epoch= 169 	 time= 30.055125228563945 min 	 lr= 0.03125 	 loss= 0.8241012120984265 	 error= 30.412372670222805 percent
# error rate on test set = 58.193181861530654 percent
#
# epoch= 170 	 time= 30.236460117499032 min 	 lr= 0.03125 	 loss= 0.8057367958358883 	 error= 29.38144477372317 percent
# error rate on test set = 56.39772794463418 percent
#
# epoch= 171 	 time= 30.41769819657008 min 	 lr= 0.03125 	 loss= 0.754930173306121 	 error= 27.21649666422421 percent
# error rate on test set = 54.056818376887925 percent
#
# epoch= 172 	 time= 30.599030462900796 min 	 lr= 0.03125 	 loss= 0.774222117109397 	 error= 28.16495004388475 percent
# error rate on test set = 55.715909871188074 percent
#
# epoch= 173 	 time= 30.779565199216208 min 	 lr= 0.03125 	 loss= 0.7386085858050081 	 error= 26.391754260997182 percent
# error rate on test set = 56.272727792913265 percent
#
# epoch= 174 	 time= 30.959615727265675 min 	 lr= 0.03125 	 loss= 0.7129860544942089 	 error= 25.422682221402827 percent
# error rate on test set = 59.68182032758539 percent
#
# epoch= 175 	 time= 31.14078207015991 min 	 lr= 0.03125 	 loss= 0.7021253511463244 	 error= 24.86598092256133 percent
# error rate on test set = 56.00000132213939 percent
#
# epoch= 176 	 time= 31.321414399147034 min 	 lr= 0.03125 	 loss= 0.6463498033813595 	 error= 22.783507207005293 percent
# error rate on test set = 52.2386372089386 percent
#
# epoch= 177 	 time= 31.500292321046192 min 	 lr= 0.03125 	 loss= 0.6667474514430332 	 error= 23.25773411190387 percent
# error rate on test set = 56.93181915716692 percent
#
# epoch= 178 	 time= 31.68141573270162 min 	 lr= 0.03125 	 loss= 0.6347600581105223 	 error= 23.154641242371394 percent
# error rate on test set = 54.78409257802096 percent
#
# epoch= 179 	 time= 31.861907855669656 min 	 lr= 0.03125 	 loss= 0.6136405999513016 	 error= 22.494847196893595 percent
# error rate on test set = 54.45454608310353 percent
#
# epoch= 180 	 time= 32.04051053126653 min 	 lr= 0.03125 	 loss= 0.6003424270251363 	 error= 21.670105531043614 percent
# error rate on test set = 54.84090989286249 percent
#
# epoch= 181 	 time= 32.21925246318181 min 	 lr= 0.03125 	 loss= 0.5597557735811803 	 error= 19.319589973724995 percent
# error rate on test set = 54.21591021797874 percent
#
# epoch= 182 	 time= 32.3971392472585 min 	 lr= 0.03125 	 loss= 0.5568465304743383 	 error= 20.18556914378687 percent
# error rate on test set = 53.69318181818182 percent
#
# epoch= 183 	 time= 32.57758649190267 min 	 lr= 0.03125 	 loss= 0.5548309812840727 	 error= 19.567012295280538 percent
# error rate on test set = 55.40909171104431 percent
#
# epoch= 184 	 time= 32.75879933436712 min 	 lr= 0.03125 	 loss= 0.5100639837304342 	 error= 18.185569637829495 percent
# error rate on test set = 55.76136437329379 percent
#
# epoch= 185 	 time= 32.93805969953537 min 	 lr= 0.03125 	 loss= 0.47944237768035575 	 error= 16.804126058657147 percent
# error rate on test set = 53.59091000123457 percent
#
# epoch= 186 	 time= 33.11811887025833 min 	 lr= 0.03125 	 loss= 0.49278351203682497 	 error= 17.31958991473483 percent
# error rate on test set = 59.2500009319999 percent
#
# epoch= 187 	 time= 33.29475942850113 min 	 lr= 0.03125 	 loss= 0.47767319645463807 	 error= 16.721651910506573 percent
# error rate on test set = 54.818183183670044 percent
#
# epoch= 188 	 time= 33.47255133390426 min 	 lr= 0.03125 	 loss= 0.42900514449040916 	 error= 15.505156811979628 percent
# error rate on test set = 52.54545536908236 percent
#
# epoch= 189 	 time= 33.64905718962351 min 	 lr= 0.03125 	 loss= 0.4323474142662029 	 error= 16.04123938943922 percent
# error rate on test set = 53.38636528361928 percent
#
# epoch= 190 	 time= 33.82693765560786 min 	 lr= 0.03125 	 loss= 0.4149257278012246 	 error= 13.979383780784213 percent
# error rate on test set = 54.215909676118336 percent
#
# epoch= 191 	 time= 34.00663630167643 min 	 lr= 0.03125 	 loss= 0.41084856286491317 	 error= 14.659796363299654 percent
# error rate on test set = 52.4772741577842 percent
#
# epoch= 192 	 time= 34.1884383002917 min 	 lr= 0.03125 	 loss= 0.3985026302104144 	 error= 14.247425008065923 percent
# error rate on test set = 56.13636374473572 percent
#
# epoch= 193 	 time= 34.36619440714518 min 	 lr= 0.03125 	 loss= 0.36477531262279783 	 error= 12.536084651947021 percent
# error rate on test set = 55.193183638832785 percent
#
# epoch= 194 	 time= 34.5443258245786 min 	 lr= 0.03125 	 loss= 0.35541614682711276 	 error= 12.20618793644856 percent
# error rate on test set = 54.03409112583507 percent
#
# epoch= 195 	 time= 34.720486625035605 min 	 lr= 0.03125 	 loss= 0.3552047584935562 	 error= 12.474229409522616 percent
# error rate on test set = 53.95454601808027 percent
#
# epoch= 196 	 time= 34.9001341342926 min 	 lr= 0.03125 	 loss= 0.34714854124587835 	 error= 12.061857869944621 percent
# error rate on test set = 56.034091385928065 percent
#
# epoch= 197 	 time= 35.079871730009714 min 	 lr= 0.03125 	 loss= 0.3385397063702652 	 error= 11.15464205594407 percent
# error rate on test set = 57.95454599640586 percent
#
# epoch= 198 	 time= 35.26079976161321 min 	 lr= 0.03125 	 loss= 0.31275503698390783 	 error= 10.453610874942898 percent
# error rate on test set = 55.193183638832785 percent
#
# epoch= 199 	 time= 35.44280279477437 min 	 lr= 0.03125 	 loss= 0.29749437014466706 	 error= 9.814435120710392 percent
# error rate on test set = 51.59091028300199 percent

# %% [markdown]
# # VGG -- nn.MaxPool2d(4 x 4)
# The attempted improvement done over here is to increase the size of the average pooling layers from 2x2 to 4x4. This was done for multiple reasons.
#
# We do not wish to resize the input layer of 1x128x128 first because this image classification tasks deals with facial expressions and facial features which are detailed and may contain useful features for each small pixel. However, due to the size of the input layer, it results in a number of parameters in the neural network. This may result in overfitting.
#
# Hence, to reduce the number of parameters, while seeking to retain the information captured at fine-grain pixel level, we attemp to increase the size of the average pooling layers.

# %%
class VGG_convnet_px128(nn.Module):

    def __init__(self):
        super(VGG_convnet, self).__init__()

        # block 1:         1 x 128 x 128 --> 64 x 32 x 32
        self.conv1a = nn.Conv2d(1, 64, kernel_size=3, padding=1)
        self.conv1b = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool2d(4, 4)

        # block 2:         64 x 32 x 32 --> 128 x 8 x 8
        self.conv2a = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv2b = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool2d(4, 4)

        # block 3:         128 x 8 x 8 --> 256 x 4 x 4
        self.conv3a = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv3b = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.pool3 = nn.MaxPool2d(2, 2)

        # block 4:          256 x 4 x 4 --> 512 x 2 x 2
        self.conv4a = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.pool4 = nn.MaxPool2d(2, 2)

        # linear layers:   512 x 2 x 2 --> 2048 --> 4096 --> 4096 --> 10
        self.linear1 = nn.Linear(2048, 4096)
        self.linear2 = nn.Linear(4096, 4096)
        self.linear3 = nn.Linear(4096, 10)

    def forward(self, x):
        # block 1:         1 x 128 x 128 --> 64 x 64 x 64
        x = self.conv1a(x)
        x = F.relu(x)
        x = self.conv1b(x)
        x = F.relu(x)
        x = self.pool1(x)

        # block 2:         64 x 64 x 64 --> 128 x 16 x 16
        x = self.conv2a(x)
        x = F.relu(x)
        x = self.conv2b(x)
        x = F.relu(x)
        x = self.pool2(x)

        # block 3:         128 x 16 x 16 --> 256 x 4 x 4
        x = self.conv3a(x)
        x = F.relu(x)
        x = self.conv3b(x)
        x = F.relu(x)
        x = self.pool3(x)

        # block 4:          256 x 4 x 4 --> 512 x 2 x 2
        x = self.conv4a(x)
        x = F.relu(x)
        x = self.pool4(x)

        # linear layers:   512 x 2 x 2 --> 2048 --> 4096 --> 4096 --> 10
        x = x.view(-1, 2048)
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        x = self.linear3(x)

        return x
    
'''
utils.display_num_param(net)

VGG_convnet_px128(
  (conv1a): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (conv1b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (pool1): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
  (conv2a): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (conv2b): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (pool2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
  (conv3a): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (conv3b): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
  (conv4a): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
  (linear1): Linear(in_features=2048, out_features=4096, bias=True)
  (linear2): Linear(in_features=4096, out_features=4096, bias=True)
  (linear3): Linear(in_features=4096, out_features=10, bias=True)
  There are 27539402 (27.54 million) parameters in this neural network
)
'''

'''
See log/vgg_px128.txt for the full output.
 
epoch= 197 	 time= 13.116444532076518 min 	 lr= 0.03125 	 loss= 0.1217539941642395 	 error= 4.123713613785419 percent
error rate on test set = 53.06818268515847 percent
 
epoch= 198 	 time= 13.181400994459787 min 	 lr= 0.03125 	 loss= 0.10981417798734817 	 error= 3.4639196912037957 percent
error rate on test set = 49.53409162434665 percent
 
epoch= 199 	 time= 13.245910755793254 min 	 lr= 0.03125 	 loss= 0.10294757859262917 	 error= 3.216496878063556 percent
error rate on test set = 50.806818767027416 percent
'''

# %% [markdown]
# # Dropout
# We find that the error rate on the train set is much higher than the test set.
#
# In order to combat overfitting in the network, we try inserting Dropout layers after convolutional layers.

# %%
class VGG_convnet_dropout(nn.Module):

    def __init__(self):
        super(VGG_convnet, self).__init__()

        # block 1:         1 x 128 x 128 --> 64 x 32 x 32
        self.conv1a = nn.Conv2d(1, 64, kernel_size=3, padding=1)
        self.conv1b = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool2d(4, 4)

        # block 2:         64 x 32 x 32 --> 128 x 8 x 8
        self.conv2a = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv2b = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool2d(4, 4)

        # block 3:         128 x 8 x 8 --> 256 x 4 x 4
        self.conv3a = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv3b = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.pool3 = nn.MaxPool2d(2, 2)

        # block 4:          256 x 4 x 4 --> 512 x 2 x 2
        self.conv4a = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.pool4 = nn.MaxPool2d(2, 2)

        # linear layers:   512 x 2 x 2 --> 2048 --> 4096 --> 4096 --> 10
        self.linear1 = nn.Linear(2048, 4096)
        self.linear2 = nn.Linear(4096, 4096)
        self.linear3 = nn.Linear(4096, 10)

    def forward(self, x):
        # block 1:         1 x 128 x 128 --> 64 x 32 x 32
        x = self.conv1a(x)
        x = F.relu(x)
        x = self.conv1b(x)
        x = F.relu(x)
        x = self.pool1(x)

        # block 2:         64 x 32 x 32 --> 128 x 8 x 8
        x = self.conv2a(x)
        x = F.relu(x)
        x = self.conv2b(x)
        x = F.relu(x)
        x = self.pool2(x)

        # block 3:         128 x 8 x 8 --> 256 x 4 x 4
        x = self.conv3a(x)
        x = F.relu(x)
        x = self.conv3b(x)
        x = F.relu(x)
        x = self.pool3(x)

        # block 4:          256 x 4 x 4 --> 512 x 2 x 2
        x = self.conv4a(x)
        x = F.relu(x)
        x = self.pool4(x)

        # linear layers:   512 x 2 x 2 --> 2048 --> 4096 --> 4096 --> 10
        x = x.view(-1, 2048)
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        x = self.linear3(x)

        return x

'''
VGG_convnet(     
  (conv1a): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (conv1b): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (pool1): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
  (drop1): Dropout(p=0.5, inplace=False)
  (conv2a): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (conv2b): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (pool2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
  (drop2): Dropout(p=0.5, inplace=False)
  (conv3a): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (conv3b): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
  (drop3): Dropout(p=0.5, inplace=False)
  (conv4a): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
  (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
  (linear1): Linear(in_features=2048, out_features=4096, bias=True)
  (linear2): Linear(in_features=4096, out_features=4096, bias=True)
  (linear3): Linear(in_features=4096, out_features=10, bias=True)
)
There are 27539402 (27.54 million) parameters in this neural network
'''

'''
See log/vgg_dropout.txt for the full output.
 
epoch= 196 	 time= 13.345274138450623 min 	 lr= 0.03125 	 loss= 0.5204616894119793 	 error= 19.60824961514817 percent
error rate on test set = 49.590908939188175 percent
 
epoch= 197 	 time= 13.412516383330027 min 	 lr= 0.03125 	 loss= 0.5394029445254925 	 error= 20.49484738369578 percent
error rate on test set = 50.23863857442682 percent
 
epoch= 198 	 time= 13.479526805877686 min 	 lr= 0.03125 	 loss= 0.5349615907546171 	 error= 19.793816694279307 percent
error rate on test set = 50.943182273344554 percent
 
epoch= 199 	 time= 13.546925719579061 min 	 lr= 0.03125 	 loss= 0.5200335079247189 	 error= 19.31958985082882 percent
error rate on test set = 50.69318251176313 percent
'''

# %% [markdown]
# # Choice of Optimizer
#
# We try three optimizers:
# + SGD
# + SGD + Momentum
# + Adam
#
# For fare comparision, we use the default values of learning rate, beta1 and beta2 in pytorch.
#
#
# Our observations:
#
# + Convergence. Adaptive optimizers such as Adam give fatser convergence than SGD and Momentum SGD, but it may get stuck in a local minima somehow and provides poor generalization
#
# + Global minima. SGD+momentum can achieve to find a global minima, but it relies on robust initializations and it might take longer than Adam to converge

# %%
utils.plot_optimizers('error')

# %%
 utils.plot_optimizers('loss')

# %%
import utils
utils.plot_optimizers('test error')

# %% [markdown]
# ## SGD

# %%
optimizer = torch.optim.SGD(net.parameters(), lr=0.01)

'''
See log/optimizer_sgd.txt for the full output.

epoch= 197 	 time= 16.640492721398672 min 	 loss= 1.4266390739027988 	 error= 55.340207421902534 percent
error rate on test set = 58.886363831433385 percent
epoch= 198 	 time= 16.727175052960714 min 	 loss= 1.4200772022463612 	 error= 54.90721771397542 percent
error rate on test set = 57.602274959737606 percent
epoch= 199 	 time= 16.81212347348531 min 	 loss= 1.4205077726816393 	 error= 54.08247543364456 percent
error rate on test set = 57.27272792295977 percent
'''

# %% [markdown]
# ## SGD + Momentum

# %%
# Momentum SGD
optimizer = torch.optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

'''
See log/optimizer_sgd_momentum.txt for the full output.

epoch= 197 	 time= 17.621728281180065 min 	 loss= 0.31581137352383015 	 error= 11.175260347189363 percent
error rate on test set = 47.12500084530223 percent
epoch= 198 	 time= 17.705276453495024 min 	 loss= 0.3418008195063503 	 error= 12.350518064400584 percent
error rate on test set = 47.30681831186468 percent
epoch= 199 	 time= 17.794385369618734 min 	 loss= 0.31510837414522763 	 error= 11.711342617408517 percent
error rate on test set = 44.95454647324302 percent
'''

# %% [markdown]
# ## Adam

# %%
# Adam
optimizer = torch.optim.Adam(net.parameters(), lr=0.0001)

'''
See log/optimizer_adam.txt for the full output.

epoch= 197 	 time= 14.945561536153157 min 	 lr= 0.0001 	 loss= 0.21837057687879838 	 error= 8.247424523854994 percent
error rate on test set = 46.76136482845653 percent
epoch= 198 	 time= 15.016908542315166 min 	 lr= 0.0001 	 loss= 0.239205996246682 	 error= 8.536084964103305 percent
error rate on test set = 45.306819677352905 percent
epoch= 199 	 time= 15.092707566420238 min 	 lr= 0.0001 	 loss= 0.23558733973306478 	 error= 8.247424953991604 percent
error rate on test set = 49.977273832667954 percent
'''

# %% [markdown]
# # Validate Model Using Standard Dataset
# We train our model a public dataset [fer-2013](https://www.kaggle.com/msambare/fer2013).
#
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.

# %%
'''
See log/vgg_fer_2013.txt for the full output.

epoch= 197 	 time= 70.96889228026072 min 	 loss= 0.1701572123931154 	 error= 5.754978128101515 percent
error rate on test set = 37.50396979351838 percent
epoch= 198 	 time= 71.32047909498215 min 	 loss= 0.1636838308264218 	 error= 5.540871723838475 percent
error rate on test set = 37.52678744494915 percent
epoch= 199 	 time= 71.68298303683599 min 	 loss= 0.1676228751918382 	 error= 5.481741283250892 percent
error rate on test set = 38.29861258467038 percent
'''

# %% [markdown]
# # 3. LeNet5
# Over here, we train a simple LeNet5 Architecture that was proposed by LeCun and team in 1998. It has a total of two sets of convolution layers with a combination of subsampling, followed by two fully connected layers.
#
#
#
# 1.   The first layer is the input layer with feature map size 1x128x128.
# 2.   Then, we have the convolution layer with 50 filters of size 3x3 and stride 1. The activation function used at this layer is ReLU. The output feature map is 50x128x128.
# 3.   Next, we have an max pooling layer with filter size 2x2 and stride 1. The resulting feature map is 50x64x64.
# 4.   Then, we have a second convolution layer with 100 filters of size 3x3 and stride 1. The activation function used at this layer is ReLU. The output feature map is 100x64x64.
# 5.   Next, we have an max pooling layer with filter size 2x2 and stride 1. The resulting feature map is 100x32x32.
# 6.   Then, we have a fully connected layer with 100 neurons that results in the output of 100 values. The activation function used is also ReLU.
# 7.   Finally, we have a fully connected layer with 7 neurons to output 7 values that will represent the class that a data point would belong to.

# %%
class LeNet5_convnet(nn.Module):

    def __init__(self):

        super(LeNet5_convnet, self).__init__()

        # CL1:   128 x 128  -->    50 x 128 x 128 
        self.conv1 = nn.Conv2d(1,   50,  kernel_size=3,  padding=1 )
        
        # MP1: 50 x 128 x 128 -->    50 x 64 x 64
        self.pool1  = nn.MaxPool2d(2,2)
        
        # CL2:   50 x 64 x 64  -->    100 x 64 x 64 
        self.conv2 = nn.Conv2d(50,  100,  kernel_size=3,  padding=1 )
        
        # MP2: 100 x 64 x 64 -->    100 x 32 x 32
        self.pool2 = nn.MaxPool2d(2,2)
        
        # LL1:   100 x 32 x 32 = 102,400 -->  100
        self.linear1 = nn.Linear(102400, 100)
        
        # LL2:   100  -->  7
        self.linear2 = nn.Linear(100, 7)


    def forward(self, x):

        self.x1 = self.conv1(x)
        self.x2 = torch.relu(self.x1)
        self.x3 = self.pool1(self.x2)
        self.x4 = self.conv2(self.x3)
        self.x5 = torch.relu(self.x4)
        self.x6 = self.pool2(self.x5)
        self.x7 = self.x6.view(-1, 102400)
        self.x8 = self.linear1(self.x7)
        self.x9 = torch.relu(self.x8)
        self.out = self.linear2(self.x9)
    
        return self.out

    def get_features(self):
        return self.x1, self.x2, self.x3, self.x4, self.x5, self.x6, self.x7, self.x8, self.x9, self.out

# %% [markdown]
# The number of trainable parameters of this architecture is approximately 10.29 million.

# %%
lenet5 = LeNet5_convnet()
print(lenet5)
utils.display_num_param(lenet5)
# Out:
# LeNet5_convnet(
#   (conv1): Conv2d(1, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(50, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (linear1): Linear(in_features=102400, out_features=100, bias=True)
#   (linear2): Linear(in_features=100, out_features=7, bias=True)
# )
# There are 10286407 (10.29 million) parameters in this neural network

# %% [markdown]
# Over here, we are doing 200 passes through the training set and dividing the learning rate by 1.5 every 10 epochs to decay it.

# %%
criterion = nn.CrossEntropyLoss()
my_lr = 0.25
device = torch.device('cuda')
net = net.to(device)
# mean = mean.to(device)
# std = std.to(device)

start = time.time()

for epoch in range(1,200):
    
    if not epoch%10:
        my_lr = my_lr / 1.5
        
    optimizer = torch.optim.SGD( net.parameters() , lr=my_lr )
    
    #################
    # TRAINING DATA #
    #################
        
    train_running_loss = 0
    train_running_error = 0
    train_num_batches = 0
    
    for train_minibatch_data, train_minibatch_label in train_dl:
        
        # FORWARD AND BACKWARD PASS
    
        optimizer.zero_grad()
        
        train_minibatch_data = train_minibatch_data.to(device)
        train_minibatch_label = train_minibatch_label.to(device)
        
        train_inputs = train_minibatch_data.view(-1, 1, 128, 128) # (train_minibatch_data - mean) / std
        
        train_inputs.requires_grad_()

        train_scores = lenet5(train_inputs) 

        train_loss = criterion(train_scores , train_minibatch_label) 
          
        train_loss.backward()
        
        optimizer.step()
        
        # COMPUTE STATS
        
        train_running_loss += train_loss.detach().item()
        
        train_error = utils.get_error(train_scores.detach() , train_minibatch_label)
        train_running_error += train_error.item()
        
        train_num_batches += 1        
    
    
    # AVERAGE STATS THEN DISPLAY
    train_total_loss = train_running_loss / train_num_batches
    train_total_error = train_running_error / train_num_batches
    train_elapsed = (time.time()-start) / 60
    
    print(
        'epoch=', epoch,
        '\t time=', train_elapsed,
        'min', 
        '\t lr=', my_lr ,
        '\t loss=', train_total_loss, 
        '\t error=', train_total_error*100,
        'percent'
    )
    
    ###################
    # VALIDATION DATA #
    ###################
    
    eval_on_dataset_loader(lenet5, valid_dl)
    
#     valid_running_error=0
#     valid_num_batches=0

#     for valid_minibatch_data, valid_minibatch_label in valid_dl:

#         valid_minibatch_data = valid_minibatch_data.to(device)
#         valid_minibatch_label = valid_minibatch_label.to(device)
        
#         valid_inputs = valid_minibatch_data.view(-1, 1, 128, 128) # (valid_minibatch_data - mean) / std    # ONLY CHANGE IS HERE!

#         valid_scores = net(valid_inputs) 

#         valid_error = utils.get_error(valid_scores , valid_minibatch_label)

#         valid_running_error += valid_error.item()

#         valid_num_batches+=1


#     valid_total_error = valid_running_error / valid_num_batches
#     print('error rate on test set =', valid_total_error*100 , 'percent')
#     print(' ')
# Out:
# epoch= 1 	 time= 6.661961348851522 min 	 lr= 0.25 	 loss= 1.9702238035202027 	 error= 82.66000080108643 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 2 	 time= 7.951790396372477 min 	 lr= 0.25 	 loss= 1.932634859085083 	 error= 80.70000076293945 percent
# error rate on test set = 81.16161823272705 percent
#
# epoch= 3 	 time= 8.179031737645467 min 	 lr= 0.25 	 loss= 1.9336142015457154 	 error= 80.82000064849854 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 4 	 time= 8.408081058661143 min 	 lr= 0.25 	 loss= 1.9312482738494874 	 error= 80.760000705719 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 5 	 time= 8.637881529331207 min 	 lr= 0.25 	 loss= 1.9255378866195678 	 error= 79.20000052452087 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 6 	 time= 8.868585646152496 min 	 lr= 0.25 	 loss= 1.9193805265426636 	 error= 79.51999998092651 percent
# error rate on test set = 79.78282968203226 percent
#
# epoch= 7 	 time= 9.100392838319143 min 	 lr= 0.25 	 loss= 1.9033500480651855 	 error= 78.36000061035156 percent
# error rate on test set = 78.23232213656107 percent
#
# epoch= 8 	 time= 9.331200317541759 min 	 lr= 0.25 	 loss= 1.912828540802002 	 error= 78.5600004196167 percent
# error rate on test set = 77.59595910708109 percent
#
# epoch= 9 	 time= 9.562224570910136 min 	 lr= 0.25 	 loss= 1.889834032058716 	 error= 76.89999985694885 percent
# error rate on test set = 81.65656725565592 percent
#
# epoch= 10 	 time= 9.792466314633687 min 	 lr= 0.16666666666666666 	 loss= 1.8681742811203004 	 error= 75.40000033378601 percent
# error rate on test set = 69.21717127164206 percent
#
# epoch= 11 	 time= 10.022756616274515 min 	 lr= 0.16666666666666666 	 loss= 1.8544115734100342 	 error= 74.66000056266785 percent
# error rate on test set = 72.66161640485129 percent
#
# epoch= 12 	 time= 10.254790508747101 min 	 lr= 0.16666666666666666 	 loss= 1.823693995475769 	 error= 72.74000144004822 percent
# error rate on test set = 79.40403819084167 percent
#
# epoch= 13 	 time= 10.484694250424702 min 	 lr= 0.16666666666666666 	 loss= 1.8420956468582153 	 error= 74.46000146865845 percent
# error rate on test set = 74.85858599344888 percent
#
# epoch= 14 	 time= 10.715574451287587 min 	 lr= 0.16666666666666666 	 loss= 1.8121363258361816 	 error= 72.32000064849854 percent
# error rate on test set = 69.6363627910614 percent
#
# epoch= 15 	 time= 10.946920084953309 min 	 lr= 0.16666666666666666 	 loss= 1.7890158414840698 	 error= 71.84000205993652 percent
# error rate on test set = 64.07070557276407 percent
#
# epoch= 16 	 time= 11.178287661075592 min 	 lr= 0.16666666666666666 	 loss= 1.7860370302200317 	 error= 70.44000101089478 percent
# error rate on test set = 69.07070676485696 percent
#
# epoch= 17 	 time= 11.409233093261719 min 	 lr= 0.16666666666666666 	 loss= 1.7632618951797485 	 error= 69.46000170707703 percent
# error rate on test set = 75.1565674940745 percent
#
# epoch= 18 	 time= 11.640275021394094 min 	 lr= 0.16666666666666666 	 loss= 1.770030870437622 	 error= 69.40000104904175 percent
# error rate on test set = 69.9545462926229 percent
#
# epoch= 19 	 time= 11.870598558584849 min 	 lr= 0.16666666666666666 	 loss= 1.776497378349304 	 error= 70.04000091552734 percent
# error rate on test set = 67.87373820940653 percent
#
# epoch= 20 	 time= 12.101012821992239 min 	 lr= 0.1111111111111111 	 loss= 1.7438609504699707 	 error= 68.0600004196167 percent
# error rate on test set = 68.03030172983804 percent
#
# epoch= 21 	 time= 12.330994141101836 min 	 lr= 0.1111111111111111 	 loss= 1.687566270828247 	 error= 64.9400007724762 percent
# error rate on test set = 78.23232412338257 percent
#
# epoch= 22 	 time= 12.560985406239828 min 	 lr= 0.1111111111111111 	 loss= 1.7054008722305298 	 error= 65.5400013923645 percent
# error rate on test set = 64.161616563797 percent
#
# epoch= 23 	 time= 12.791047072410583 min 	 lr= 0.1111111111111111 	 loss= 1.6867797565460205 	 error= 65.70000123977661 percent
# error rate on test set = 67.16161767641702 percent
#
# epoch= 24 	 time= 13.021925461292266 min 	 lr= 0.1111111111111111 	 loss= 1.6435726165771485 	 error= 63.06000065803528 percent
# error rate on test set = 61.24242345492045 percent
#
# epoch= 25 	 time= 13.252307903766631 min 	 lr= 0.1111111111111111 	 loss= 1.6237835884094238 	 error= 62.4000005722046 percent
# error rate on test set = 68.9090927441915 percent
#
# epoch= 26 	 time= 13.482794499397277 min 	 lr= 0.1111111111111111 	 loss= 1.6198704767227172 	 error= 63.220001220703125 percent
# error rate on test set = 75.87878902753195 percent
#
# epoch= 27 	 time= 13.713601009051006 min 	 lr= 0.1111111111111111 	 loss= 1.6595544242858886 	 error= 63.300001382827766 percent
# error rate on test set = 62.353537480036415 percent
#
# epoch= 28 	 time= 13.94480576912562 min 	 lr= 0.1111111111111111 	 loss= 1.6010011005401612 	 error= 60.4800009727478 percent
# error rate on test set = 59.4292938709259 percent
#
# epoch= 29 	 time= 14.17586507399877 min 	 lr= 0.1111111111111111 	 loss= 1.5901144456863403 	 error= 60.680001974105835 percent
# error rate on test set = 64.05050555864969 percent
#
# epoch= 30 	 time= 14.405548067887624 min 	 lr= 0.07407407407407407 	 loss= 1.5457960700988769 	 error= 58.66000151634216 percent
# error rate on test set = 63.11111251513163 percent
#
# epoch= 31 	 time= 14.635388886928558 min 	 lr= 0.07407407407407407 	 loss= 1.5159546613693238 	 error= 57.92000102996826 percent
# error rate on test set = 59.7777783870697 percent
#
# epoch= 32 	 time= 14.866924262046814 min 	 lr= 0.07407407407407407 	 loss= 1.5326107120513917 	 error= 58.84000086784362 percent
# error rate on test set = 63.93434206644694 percent
#
# epoch= 33 	 time= 15.09657789071401 min 	 lr= 0.07407407407407407 	 loss= 1.5304390096664429 	 error= 58.100000858306885 percent
# error rate on test set = 63.93434206644694 percent
#
# epoch= 34 	 time= 15.32706382671992 min 	 lr= 0.07407407407407407 	 loss= 1.5128923320770264 	 error= 57.44000101089477 percent
# error rate on test set = 64.75757360458374 percent
#
# epoch= 35 	 time= 15.558510593573253 min 	 lr= 0.07407407407407407 	 loss= 1.5055058050155639 	 error= 57.88000130653381 percent
# error rate on test set = 67.17676719029745 percent
#
# epoch= 36 	 time= 15.789553761482239 min 	 lr= 0.07407407407407407 	 loss= 1.5014288997650147 	 error= 57.62000131607056 percent
# error rate on test set = 61.51009798049927 percent
#
# epoch= 37 	 time= 16.02141066789627 min 	 lr= 0.07407407407407407 	 loss= 1.4896600770950317 	 error= 57.10000205039978 percent
# error rate on test set = 62.08586096763611 percent
#
# epoch= 38 	 time= 16.253072090943654 min 	 lr= 0.07407407407407407 	 loss= 1.4509455633163453 	 error= 54.86000108718873 percent
# error rate on test set = 58.06565880775452 percent
#
# epoch= 39 	 time= 16.484216050306955 min 	 lr= 0.07407407407407407 	 loss= 1.4556203699111938 	 error= 55.26000165939331 percent
# error rate on test set = 62.38383650779724 percent
#
# epoch= 40 	 time= 16.714816093444824 min 	 lr= 0.04938271604938271 	 loss= 1.4406740140914918 	 error= 54.52000045776367 percent
# error rate on test set = 57.51010179519653 percent
#
# epoch= 41 	 time= 16.945854866504668 min 	 lr= 0.04938271604938271 	 loss= 1.4139237737655639 	 error= 53.600000858306885 percent
# error rate on test set = 62.29292949040731 percent
#
# epoch= 42 	 time= 17.17715316216151 min 	 lr= 0.04938271604938271 	 loss= 1.426479263305664 	 error= 54.06000041961669 percent
# error rate on test set = 64.40404057502747 percent
#
# epoch= 43 	 time= 17.40861000617345 min 	 lr= 0.04938271604938271 	 loss= 1.4262452220916748 	 error= 54.22000026702881 percent
# error rate on test set = 58.45454533894857 percent
#
# epoch= 44 	 time= 17.638791179656984 min 	 lr= 0.04938271604938271 	 loss= 1.4151927661895751 	 error= 53.800000429153435 percent
# error rate on test set = 60.6818159421285 percent
#
# epoch= 45 	 time= 17.869926063219705 min 	 lr= 0.04938271604938271 	 loss= 1.4214054012298585 	 error= 53.52000045776367 percent
# error rate on test set = 56.737375259399414 percent
#
# epoch= 46 	 time= 18.101314707597098 min 	 lr= 0.04938271604938271 	 loss= 1.408938970565796 	 error= 53.58000040054321 percent
# error rate on test set = 59.28283135096232 percent
#
# epoch= 47 	 time= 18.33158997297287 min 	 lr= 0.04938271604938271 	 loss= 1.4021449851989747 	 error= 52.720000982284546 percent
# error rate on test set = 63.31313053766886 percent
#
# epoch= 48 	 time= 18.562963354587556 min 	 lr= 0.04938271604938271 	 loss= 1.3995736932754517 	 error= 52.86000084877014 percent
# error rate on test set = 60.64646442731222 percent
#
# epoch= 49 	 time= 18.793657700220745 min 	 lr= 0.04938271604938271 	 loss= 1.3913426637649535 	 error= 53.12000036239623 percent
# error rate on test set = 56.181816260019936 percent
#
# epoch= 50 	 time= 19.024024267991383 min 	 lr= 0.03292181069958847 	 loss= 1.3624330520629884 	 error= 51.46000099182129 percent
# error rate on test set = 61.85858647028605 percent
#
# epoch= 51 	 time= 19.25486561457316 min 	 lr= 0.03292181069958847 	 loss= 1.3612799644470215 	 error= 51.24000024795532 percent
# error rate on test set = 61.80302898089091 percent
#
# epoch= 52 	 time= 19.484983468055724 min 	 lr= 0.03292181069958847 	 loss= 1.366248049736023 	 error= 51.560000896453865 percent
# error rate on test set = 58.93434087435404 percent
#
# epoch= 53 	 time= 19.715687882900237 min 	 lr= 0.03292181069958847 	 loss= 1.3494713401794434 	 error= 51.380000591278076 percent
# error rate on test set = 58.60606034596761 percent
#
# epoch= 54 	 time= 19.946577525138856 min 	 lr= 0.03292181069958847 	 loss= 1.354286379814148 	 error= 50.12000107765198 percent
# error rate on test set = 56.42929474512736 percent
#
# epoch= 55 	 time= 20.176124330361684 min 	 lr= 0.03292181069958847 	 loss= 1.345648307800293 	 error= 51.679999828338616 percent
# error rate on test set = 58.69191884994507 percent
#
# epoch= 56 	 time= 20.40745717684428 min 	 lr= 0.03292181069958847 	 loss= 1.333488745689392 	 error= 50.32000064849853 percent
# error rate on test set = 57.8484853108724 percent
#
# epoch= 57 	 time= 20.639558219909667 min 	 lr= 0.03292181069958847 	 loss= 1.3314846181869506 	 error= 49.920000076293945 percent
# error rate on test set = 59.29797887802124 percent
#
# epoch= 58 	 time= 20.87183068195979 min 	 lr= 0.03292181069958847 	 loss= 1.3334709739685058 	 error= 49.72000074386597 percent
# error rate on test set = 58.4494948387146 percent
#
# epoch= 59 	 time= 21.104062859217326 min 	 lr= 0.03292181069958847 	 loss= 1.3255898761749267 	 error= 49.040000200271606 percent
# error rate on test set = 57.621212800343834 percent
#
# epoch= 60 	 time= 21.335752276579537 min 	 lr= 0.02194787379972565 	 loss= 1.3243326425552369 	 error= 49.19999980926514 percent
# error rate on test set = 55.772727727890015 percent
#
# epoch= 61 	 time= 21.568302631378174 min 	 lr= 0.02194787379972565 	 loss= 1.2962099504470825 	 error= 48.92000079154968 percent
# error rate on test set = 55.26262720425924 percent
#
# epoch= 62 	 time= 21.7996364235878 min 	 lr= 0.02194787379972565 	 loss= 1.2931019949913025 	 error= 48.16000032424927 percent
# error rate on test set = 54.74747618039449 percent
#
# epoch= 63 	 time= 22.03022767305374 min 	 lr= 0.02194787379972565 	 loss= 1.3076524114608765 	 error= 49.24000096321106 percent
# error rate on test set = 54.41919366518656 percent
#
# epoch= 64 	 time= 22.26173436244329 min 	 lr= 0.02194787379972565 	 loss= 1.295704836845398 	 error= 48.46000075340271 percent
# error rate on test set = 55.82828323046366 percent
#
# epoch= 65 	 time= 22.49303734699885 min 	 lr= 0.02194787379972565 	 loss= 1.2890560626983643 	 error= 47.6200008392334 percent
# error rate on test set = 58.69697133700053 percent
#
# epoch= 66 	 time= 22.723374140262603 min 	 lr= 0.02194787379972565 	 loss= 1.2951428937911986 	 error= 47.18000054359436 percent
# error rate on test set = 54.77272868156433 percent
#
# epoch= 67 	 time= 22.95449607372284 min 	 lr= 0.02194787379972565 	 loss= 1.2847900152206422 	 error= 48.1800012588501 percent
# error rate on test set = 55.757578214009605 percent
#
# epoch= 68 	 time= 23.185720407962798 min 	 lr= 0.02194787379972565 	 loss= 1.2873305034637452 	 error= 48.80000019073486 percent
# error rate on test set = 56.01515173912048 percent
#
# epoch= 69 	 time= 23.416886977354686 min 	 lr= 0.02194787379972565 	 loss= 1.2937461709976197 	 error= 48.1200008392334 percent
# error rate on test set = 57.601006825764976 percent
#
# epoch= 70 	 time= 23.647599828243255 min 	 lr= 0.014631915866483767 	 loss= 1.2782603120803833 	 error= 47.14000105857849 percent
# error rate on test set = 57.52525528271993 percent
#
# epoch= 71 	 time= 23.879477830727897 min 	 lr= 0.014631915866483767 	 loss= 1.2651978158950805 	 error= 47.320000648498535 percent
# error rate on test set = 53.42929164568583 percent
#
# epoch= 72 	 time= 24.110815036296845 min 	 lr= 0.014631915866483767 	 loss= 1.265753936767578 	 error= 47.480000734329224 percent
# error rate on test set = 56.11111124356588 percent
#
# epoch= 73 	 time= 24.341619686285654 min 	 lr= 0.014631915866483767 	 loss= 1.2738239765167236 	 error= 46.8000009059906 percent
# error rate on test set = 55.17676671346029 percent
#
# epoch= 74 	 time= 24.57270643313726 min 	 lr= 0.014631915866483767 	 loss= 1.2760938596725464 	 error= 46.46000051498413 percent
# error rate on test set = 55.343435208002724 percent
#
# epoch= 75 	 time= 24.80257413784663 min 	 lr= 0.014631915866483767 	 loss= 1.257895016670227 	 error= 46.18000102043152 percent
# error rate on test set = 54.33838367462158 percent
#
# epoch= 76 	 time= 25.033358216285706 min 	 lr= 0.014631915866483767 	 loss= 1.2564184045791627 	 error= 46.280001163482666 percent
# error rate on test set = 57.10100928942362 percent
#
# epoch= 77 	 time= 25.265079708894095 min 	 lr= 0.014631915866483767 	 loss= 1.2575209856033325 	 error= 47.220001220703125 percent
# error rate on test set = 56.01514975229899 percent
#
# epoch= 78 	 time= 25.497082595030466 min 	 lr= 0.014631915866483767 	 loss= 1.2532666635513305 	 error= 46.040000915527344 percent
# error rate on test set = 55.828285217285156 percent
#
# epoch= 79 	 time= 25.727154676119486 min 	 lr= 0.014631915866483767 	 loss= 1.255814847946167 	 error= 46.440001010894775 percent
# error rate on test set = 56.74747625986735 percent
#
# epoch= 80 	 time= 25.957503135999044 min 	 lr= 0.009754610577655845 	 loss= 1.2408691787719726 	 error= 45.24000072479248 percent
# error rate on test set = 55.52525122960409 percent
#
# epoch= 81 	 time= 26.18756703535716 min 	 lr= 0.009754610577655845 	 loss= 1.2444084835052491 	 error= 46.62000060081482 percent
# error rate on test set = 56.944443782170616 percent
#
# epoch= 82 	 time= 26.41718461116155 min 	 lr= 0.009754610577655845 	 loss= 1.2323353719711303 	 error= 45.26000094413757 percent
# error rate on test set = 53.26262513796488 percent
#
# epoch= 83 	 time= 26.64749054114024 min 	 lr= 0.009754610577655845 	 loss= 1.2407626247406005 	 error= 45.82000136375427 percent
# error rate on test set = 55.92929323514303 percent
#
# epoch= 84 	 time= 26.87997366587321 min 	 lr= 0.009754610577655845 	 loss= 1.2338633728027344 	 error= 45.34000086784363 percent
# error rate on test set = 53.42929164568583 percent
#
# epoch= 85 	 time= 27.11231232881546 min 	 lr= 0.009754610577655845 	 loss= 1.228171854019165 	 error= 44.540000438690186 percent
# error rate on test set = 54.171717166900635 percent
#
# epoch= 86 	 time= 27.344302256902058 min 	 lr= 0.009754610577655845 	 loss= 1.2316973400115967 	 error= 45.92000079154968 percent
# error rate on test set = 54.595959186553955 percent
#
# epoch= 87 	 time= 27.575410187244415 min 	 lr= 0.009754610577655845 	 loss= 1.2240742349624634 	 error= 45.160000801086426 percent
# error rate on test set = 57.93433984120687 percent
#
# epoch= 88 	 time= 27.80679088830948 min 	 lr= 0.009754610577655845 	 loss= 1.21373562335968 	 error= 44.08000063896179 percent
# error rate on test set = 54.09090916315714 percent
#
# epoch= 89 	 time= 28.038580667972564 min 	 lr= 0.009754610577655845 	 loss= 1.2332796096801757 	 error= 45.06000089645386 percent
# error rate on test set = 56.95959726969401 percent
#
# epoch= 90 	 time= 28.269447938601175 min 	 lr= 0.0065030737184372306 	 loss= 1.2128934907913207 	 error= 44.62000131607056 percent
# error rate on test set = 54.18181618054708 percent
#
# epoch= 91 	 time= 28.50062338113785 min 	 lr= 0.0065030737184372306 	 loss= 1.218298602104187 	 error= 44.880001068115234 percent
# error rate on test set = 53.17676663398743 percent
#
# epoch= 92 	 time= 28.731786092122395 min 	 lr= 0.0065030737184372306 	 loss= 1.2079156684875487 	 error= 44.5400013923645 percent
# error rate on test set = 54.42929069201151 percent
#
# epoch= 93 	 time= 28.963867676258086 min 	 lr= 0.0065030737184372306 	 loss= 1.2108619451522826 	 error= 45.380000829696655 percent
# error rate on test set = 54.01010115941366 percent
#
# epoch= 94 	 time= 29.195399709542592 min 	 lr= 0.0065030737184372306 	 loss= 1.2108925437927247 	 error= 44.74000120162964 percent
# error rate on test set = 54.75757718086243 percent
#
# epoch= 95 	 time= 29.426909506320953 min 	 lr= 0.0065030737184372306 	 loss= 1.2039031648635865 	 error= 44.2400004863739 percent
# error rate on test set = 55.02020319302877 percent
#
# epoch= 96 	 time= 29.658747665087382 min 	 lr= 0.0065030737184372306 	 loss= 1.2058697509765626 	 error= 44.0400013923645 percent
# error rate on test set = 54.59595719973246 percent
#
# epoch= 97 	 time= 29.89013228416443 min 	 lr= 0.0065030737184372306 	 loss= 1.1984751176834108 	 error= 43.80000114440918 percent
# error rate on test set = 54.50505018234253 percent
#
# epoch= 98 	 time= 30.12095679839452 min 	 lr= 0.0065030737184372306 	 loss= 1.2028779888153076 	 error= 44.92000126838684 percent
# error rate on test set = 53.60100865364075 percent
#
# epoch= 99 	 time= 30.351255496342976 min 	 lr= 0.0065030737184372306 	 loss= 1.2033715105056764 	 error= 44.08000087738037 percent
# error rate on test set = 54.33838367462158 percent
#
# epoch= 100 	 time= 30.582050788402558 min 	 lr= 0.004335382478958154 	 loss= 1.200902557373047 	 error= 44.30000138282776 percent
# error rate on test set = 54.176767667134605 percent
#
# epoch= 101 	 time= 30.811770311991374 min 	 lr= 0.004335382478958154 	 loss= 1.2094416904449463 	 error= 44.14000153541565 percent
# error rate on test set = 54.75757519404093 percent
#
# epoch= 102 	 time= 31.042762112617492 min 	 lr= 0.004335382478958154 	 loss= 1.1974393701553345 	 error= 44.18000102043152 percent
# error rate on test set = 53.924242655436196 percent
#
# epoch= 103 	 time= 31.273715031147002 min 	 lr= 0.004335382478958154 	 loss= 1.182896876335144 	 error= 43.40000104904175 percent
# error rate on test set = 54.75757519404093 percent
#
# epoch= 104 	 time= 31.504697155952453 min 	 lr= 0.004335382478958154 	 loss= 1.2082754707336425 	 error= 44.26000142097473 percent
# error rate on test set = 53.505051136016846 percent
#
# epoch= 105 	 time= 31.73574242591858 min 	 lr= 0.004335382478958154 	 loss= 1.199798903465271 	 error= 43.62000060081482 percent
# error rate on test set = 53.42929164568583 percent
#
# epoch= 106 	 time= 31.96558799346288 min 	 lr= 0.004335382478958154 	 loss= 1.1885385084152222 	 error= 43.86000084877014 percent
# error rate on test set = 53.59090765317281 percent
#
# epoch= 107 	 time= 32.197227187951405 min 	 lr= 0.004335382478958154 	 loss= 1.180689492225647 	 error= 43.320000648498535 percent
# error rate on test set = 54.26262617111206 percent
#
# epoch= 108 	 time= 32.42729442119598 min 	 lr= 0.004335382478958154 	 loss= 1.198321771621704 	 error= 43.96000099182129 percent
# error rate on test set = 54.09595767656962 percent
#
# epoch= 109 	 time= 32.65705900986989 min 	 lr= 0.004335382478958154 	 loss= 1.1968151330947876 	 error= 44.58000087738037 percent
# error rate on test set = 53.25757463773092 percent
#
# epoch= 110 	 time= 32.88736335039139 min 	 lr= 0.0028902549859721027 	 loss= 1.1879157781600953 	 error= 43.84000110626221 percent
# error rate on test set = 53.848483165105186 percent
#
# epoch= 111 	 time= 33.117461800575256 min 	 lr= 0.0028902549859721027 	 loss= 1.1967656660079955 	 error= 43.84000062942505 percent
# error rate on test set = 54.08586064974467 percent
#
# epoch= 112 	 time= 33.34956114689509 min 	 lr= 0.0028902549859721027 	 loss= 1.1934949159622192 	 error= 43.4800009727478 percent
# error rate on test set = 53.66666714350382 percent
#
# epoch= 113 	 time= 33.58026199738185 min 	 lr= 0.0028902549859721027 	 loss= 1.1728636121749878 	 error= 42.86000108718872 percent
# error rate on test set = 52.51009861628214 percent
#
# epoch= 114 	 time= 33.8104029417038 min 	 lr= 0.0028902549859721027 	 loss= 1.1791517281532287 	 error= 43.6800012588501 percent
# error rate on test set = 53.42929164568583 percent
#
# epoch= 115 	 time= 34.04171821276347 min 	 lr= 0.0028902549859721027 	 loss= 1.1843284034729005 	 error= 43.540000677108765 percent
# error rate on test set = 53.75757614771525 percent
#
# epoch= 116 	 time= 34.271374666690825 min 	 lr= 0.0028902549859721027 	 loss= 1.1797340726852417 	 error= 42.86000108718872 percent
# error rate on test set = 53.767675161361694 percent
#
# epoch= 117 	 time= 34.50173052151998 min 	 lr= 0.0028902549859721027 	 loss= 1.1836194324493408 	 error= 43.08000135421753 percent
# error rate on test set = 54.42929267883301 percent
#
# epoch= 118 	 time= 34.73257760206858 min 	 lr= 0.0028902549859721027 	 loss= 1.1928639650344848 	 error= 43.68000102043152 percent
# error rate on test set = 53.015148639678955 percent
#
# epoch= 119 	 time= 34.964145890871684 min 	 lr= 0.0028902549859721027 	 loss= 1.1845743036270142 	 error= 43.12000131607056 percent
# error rate on test set = 54.26262617111206 percent
#
# epoch= 120 	 time= 35.19519720872243 min 	 lr= 0.001926836657314735 	 loss= 1.167797598838806 	 error= 42.36000108718872 percent
# error rate on test set = 53.59595815340678 percent
#
# epoch= 121 	 time= 35.424384049574535 min 	 lr= 0.001926836657314735 	 loss= 1.1870163822174071 	 error= 42.98000144958496 percent
# error rate on test set = 52.590906620025635 percent
#
# epoch= 122 	 time= 35.654700811704 min 	 lr= 0.001926836657314735 	 loss= 1.1606431603431702 	 error= 41.88000154495239 percent
# error rate on test set = 53.09595664342245 percent
#
# epoch= 123 	 time= 35.88497567176819 min 	 lr= 0.001926836657314735 	 loss= 1.190463924407959 	 error= 43.92000079154968 percent
# error rate on test set = 53.17676663398743 percent
#
# epoch= 124 	 time= 36.116370753447214 min 	 lr= 0.001926836657314735 	 loss= 1.1771466875076293 	 error= 42.24000144004822 percent
# error rate on test set = 53.762624661127724 percent
#
# epoch= 125 	 time= 36.34725382328033 min 	 lr= 0.001926836657314735 	 loss= 1.182965979576111 	 error= 43.80000138282776 percent
# error rate on test set = 53.762624661127724 percent
#
# epoch= 126 	 time= 36.57886684735616 min 	 lr= 0.001926836657314735 	 loss= 1.1762686014175414 	 error= 43.440001010894775 percent
# error rate on test set = 53.17676464716593 percent
#
# epoch= 127 	 time= 36.80946036179861 min 	 lr= 0.001926836657314735 	 loss= 1.1776062870025634 	 error= 43.06000089645386 percent
# error rate on test set = 54.34343417485555 percent
#
# epoch= 128 	 time= 37.039316769440966 min 	 lr= 0.001926836657314735 	 loss= 1.170910015106201 	 error= 43.44000029563904 percent
# error rate on test set = 52.171715100606285 percent
#
# epoch= 129 	 time= 37.269875355561574 min 	 lr= 0.001926836657314735 	 loss= 1.1757363414764403 	 error= 42.92000102996826 percent
# error rate on test set = 52.33838160832723 percent
#
# epoch= 130 	 time= 37.501250219345096 min 	 lr= 0.0012845577715431568 	 loss= 1.181116623878479 	 error= 43.660001277923584 percent
# error rate on test set = 52.41918961207072 percent
#
# epoch= 131 	 time= 37.732659697532654 min 	 lr= 0.0012845577715431568 	 loss= 1.1732556462287902 	 error= 42.80000042915344 percent
# error rate on test set = 52.25757360458374 percent
#
# epoch= 132 	 time= 37.96385937531789 min 	 lr= 0.0012845577715431568 	 loss= 1.1742730379104613 	 error= 43.14000129699707 percent
# error rate on test set = 53.01010012626648 percent
#
# epoch= 133 	 time= 38.19561339616776 min 	 lr= 0.0012845577715431568 	 loss= 1.173723864555359 	 error= 42.30000114440918 percent
# error rate on test set = 51.67676607767741 percent
#
# epoch= 134 	 time= 38.42764911254247 min 	 lr= 0.0012845577715431568 	 loss= 1.1769638872146606 	 error= 42.000001430511475 percent
# error rate on test set = 52.50505010286967 percent
#
# epoch= 135 	 time= 38.659648060798645 min 	 lr= 0.0012845577715431568 	 loss= 1.18170578956604 	 error= 43.68000149726868 percent
# error rate on test set = 52.343432108561196 percent
#
# epoch= 136 	 time= 38.89112697442373 min 	 lr= 0.0012845577715431568 	 loss= 1.179653787612915 	 error= 43.08000087738037 percent
# error rate on test set = 53.343433141708374 percent
#
# epoch= 137 	 time= 39.121019844214125 min 	 lr= 0.0012845577715431568 	 loss= 1.1837037563323975 	 error= 42.460001945495605 percent
# error rate on test set = 53.10100714365641 percent
#
# epoch= 138 	 time= 39.352077241738634 min 	 lr= 0.0012845577715431568 	 loss= 1.1809372234344482 	 error= 43.32000136375427 percent
# error rate on test set = 52.25757360458374 percent
#
# epoch= 139 	 time= 39.58176272710164 min 	 lr= 0.0012845577715431568 	 loss= 1.179063172340393 	 error= 42.440001010894775 percent
# error rate on test set = 53.015148639678955 percent
#
# epoch= 140 	 time= 39.813540923595426 min 	 lr= 0.0008563718476954379 	 loss= 1.1780239677429198 	 error= 43.1800012588501 percent
# error rate on test set = 52.252525091171265 percent
#
# epoch= 141 	 time= 40.04530030091603 min 	 lr= 0.0008563718476954379 	 loss= 1.1849157190322877 	 error= 43.14000105857849 percent
# error rate on test set = 52.00000007947286 percent
#
# epoch= 142 	 time= 40.27558839718501 min 	 lr= 0.0008563718476954379 	 loss= 1.1736652231216431 	 error= 41.940000772476196 percent
# error rate on test set = 52.33838359514872 percent
#
# epoch= 143 	 time= 40.50764228105545 min 	 lr= 0.0008563718476954379 	 loss= 1.177826533317566 	 error= 42.720001459121704 percent
# error rate on test set = 52.59090860684713 percent
#
# epoch= 144 	 time= 40.73921202818553 min 	 lr= 0.0008563718476954379 	 loss= 1.1836911010742188 	 error= 42.600001096725464 percent
# error rate on test set = 53.09090813000997 percent
#
# epoch= 145 	 time= 40.96961439053218 min 	 lr= 0.0008563718476954379 	 loss= 1.1689508771896362 	 error= 42.7400016784668 percent
# error rate on test set = 52.59090860684713 percent
#
# epoch= 146 	 time= 41.20141065120697 min 	 lr= 0.0008563718476954379 	 loss= 1.155583577156067 	 error= 42.26000142097473 percent
# error rate on test set = 53.17676663398743 percent
#
# epoch= 147 	 time= 41.43234260082245 min 	 lr= 0.0008563718476954379 	 loss= 1.1689827013015748 	 error= 42.68000078201294 percent
# error rate on test set = 52.25757360458374 percent
#
# epoch= 148 	 time= 41.663453002770744 min 	 lr= 0.0008563718476954379 	 loss= 1.1748558616638183 	 error= 43.000001430511475 percent
# error rate on test set = 52.00504859288534 percent
#
# epoch= 149 	 time= 41.89617267847061 min 	 lr= 0.0008563718476954379 	 loss= 1.1679518079757691 	 error= 42.46000099182129 percent
# error rate on test set = 52.67676512400309 percent
#
# epoch= 150 	 time= 42.127354673544566 min 	 lr= 0.0005709145651302919 	 loss= 1.1607964372634887 	 error= 42.38000130653381 percent
# error rate on test set = 52.75757511456808 percent
#
# epoch= 151 	 time= 42.35846198797226 min 	 lr= 0.0005709145651302919 	 loss= 1.1573004627227783 	 error= 42.440001249313354 percent
# error rate on test set = 52.75757511456808 percent
#
# epoch= 152 	 time= 42.59080540736516 min 	 lr= 0.0005709145651302919 	 loss= 1.1730112648010254 	 error= 43.000000953674316 percent
# error rate on test set = 52.00504859288534 percent
#
# epoch= 153 	 time= 42.82169567743937 min 	 lr= 0.0005709145651302919 	 loss= 1.1778515338897706 	 error= 42.92000126838684 percent
# error rate on test set = 52.42424011230469 percent
#
# epoch= 154 	 time= 43.053218738238016 min 	 lr= 0.0005709145651302919 	 loss= 1.162876091003418 	 error= 42.560001373291016 percent
# error rate on test set = 53.09090813000997 percent
#
# epoch= 155 	 time= 43.28409754832585 min 	 lr= 0.0005709145651302919 	 loss= 1.1742218542098999 	 error= 43.20000100135803 percent
# error rate on test set = 52.75757511456808 percent
#
# epoch= 156 	 time= 43.515658899148306 min 	 lr= 0.0005709145651302919 	 loss= 1.1538879919052123 	 error= 41.600001096725464 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 157 	 time= 43.74546033541362 min 	 lr= 0.0005709145651302919 	 loss= 1.1527235364913941 	 error= 42.68000054359436 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 158 	 time= 43.97595473527908 min 	 lr= 0.0005709145651302919 	 loss= 1.1619862532615661 	 error= 41.60000157356262 percent
# error rate on test set = 52.75757511456808 percent
#
# epoch= 159 	 time= 44.20640428463618 min 	 lr= 0.0005709145651302919 	 loss= 1.1578995704650878 	 error= 41.820000886917114 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 160 	 time= 44.438510262966155 min 	 lr= 0.0003806097100868613 	 loss= 1.153115577697754 	 error= 42.000001192092896 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 161 	 time= 44.66940394639969 min 	 lr= 0.0003806097100868613 	 loss= 1.1609188795089722 	 error= 42.3000009059906 percent
# error rate on test set = 52.59090860684713 percent
#
# epoch= 162 	 time= 44.90033175150553 min 	 lr= 0.0003806097100868613 	 loss= 1.1539729976654052 	 error= 41.70000076293945 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 163 	 time= 45.1305174946785 min 	 lr= 0.0003806097100868613 	 loss= 1.1728474855422975 	 error= 42.5400013923645 percent
# error rate on test set = 52.75757511456808 percent
#
# epoch= 164 	 time= 45.36043403546015 min 	 lr= 0.0003806097100868613 	 loss= 1.165382661819458 	 error= 41.88000154495239 percent
# error rate on test set = 52.75757511456808 percent
#
# epoch= 165 	 time= 45.5896473646164 min 	 lr= 0.0003806097100868613 	 loss= 1.1832060265541076 	 error= 42.780001163482666 percent
# error rate on test set = 52.59090860684713 percent
#
# epoch= 166 	 time= 45.82192161083221 min 	 lr= 0.0003806097100868613 	 loss= 1.176317048072815 	 error= 43.14000153541565 percent
# error rate on test set = 52.84343361854553 percent
#
# epoch= 167 	 time= 46.052137553691864 min 	 lr= 0.0003806097100868613 	 loss= 1.1752960729598998 	 error= 42.880001068115234 percent
# error rate on test set = 52.51010060310364 percent
#
# epoch= 168 	 time= 46.28317637443543 min 	 lr= 0.0003806097100868613 	 loss= 1.1670941066741944 	 error= 42.38000154495239 percent
# error rate on test set = 52.75757511456808 percent
#
# epoch= 169 	 time= 46.514170503616334 min 	 lr= 0.0003806097100868613 	 loss= 1.1696391248703002 	 error= 42.500001192092896 percent
# error rate on test set = 52.33838359514872 percent
#
# epoch= 170 	 time= 46.74480135043462 min 	 lr= 0.0002537398067245742 	 loss= 1.1592003011703491 	 error= 42.500000953674316 percent
# error rate on test set = 52.59090860684713 percent
#
# epoch= 171 	 time= 46.97599851290385 min 	 lr= 0.0002537398067245742 	 loss= 1.1668880605697631 	 error= 43.06000113487244 percent
# error rate on test set = 52.59090860684713 percent
#
# epoch= 172 	 time= 47.20719826618831 min 	 lr= 0.0002537398067245742 	 loss= 1.1593803215026854 	 error= 41.96000123023987 percent
# error rate on test set = 52.590906620025635 percent
#
# epoch= 173 	 time= 47.43725925683975 min 	 lr= 0.0002537398067245742 	 loss= 1.162428011894226 	 error= 42.24000072479248 percent
# error rate on test set = 52.75757511456808 percent
#
# epoch= 174 	 time= 47.66843792597453 min 	 lr= 0.0002537398067245742 	 loss= 1.1640597295761108 	 error= 42.58000135421753 percent
# error rate on test set = 52.75757511456808 percent
#
# epoch= 175 	 time= 47.89929682811101 min 	 lr= 0.0002537398067245742 	 loss= 1.1584965324401855 	 error= 42.36000108718872 percent
# error rate on test set = 53.01010012626648 percent
#
# epoch= 176 	 time= 48.130218823750816 min 	 lr= 0.0002537398067245742 	 loss= 1.176292552947998 	 error= 42.98000121116638 percent
# error rate on test set = 53.01010012626648 percent
#
# epoch= 177 	 time= 48.36163420677185 min 	 lr= 0.0002537398067245742 	 loss= 1.1685129594802857 	 error= 41.940001249313354 percent
# error rate on test set = 53.17676663398743 percent
#
# epoch= 178 	 time= 48.59292335510254 min 	 lr= 0.0002537398067245742 	 loss= 1.171300024986267 	 error= 42.58000135421753 percent
# error rate on test set = 52.84343163172404 percent
#
# epoch= 179 	 time= 48.82387926181158 min 	 lr= 0.0002537398067245742 	 loss= 1.1639613437652587 	 error= 41.56000113487244 percent
# error rate on test set = 52.67676512400309 percent
#
# epoch= 180 	 time= 49.05514473120372 min 	 lr= 0.00016915987114971614 	 loss= 1.175206003189087 	 error= 42.36000108718872 percent
# error rate on test set = 52.84343361854553 percent
#
# epoch= 181 	 time= 49.28742693265279 min 	 lr= 0.00016915987114971614 	 loss= 1.155886971950531 	 error= 41.400001525878906 percent
# error rate on test set = 52.84343361854553 percent
#
# epoch= 182 	 time= 49.51846502621969 min 	 lr= 0.00016915987114971614 	 loss= 1.170520601272583 	 error= 41.76000142097473 percent
# error rate on test set = 52.59090860684713 percent
#
# epoch= 183 	 time= 49.74920281569163 min 	 lr= 0.00016915987114971614 	 loss= 1.1779531717300415 	 error= 43.10000133514404 percent
# error rate on test set = 52.59090860684713 percent
#
# epoch= 184 	 time= 49.980798419316606 min 	 lr= 0.00016915987114971614 	 loss= 1.1625374746322632 	 error= 42.1200008392334 percent
# error rate on test set = 52.84343361854553 percent
#
# epoch= 185 	 time= 50.21240544319153 min 	 lr= 0.00016915987114971614 	 loss= 1.1579840469360352 	 error= 41.600001096725464 percent
# error rate on test set = 52.75757511456808 percent
#
# epoch= 186 	 time= 50.44431920051575 min 	 lr= 0.00016915987114971614 	 loss= 1.1689265394210815 	 error= 42.880001068115234 percent
# error rate on test set = 52.75757511456808 percent
#
# epoch= 187 	 time= 50.675436504681905 min 	 lr= 0.00016915987114971614 	 loss= 1.1670917558670044 	 error= 42.70000100135803 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 188 	 time= 50.90789237817128 min 	 lr= 0.00016915987114971614 	 loss= 1.1713890314102173 	 error= 42.6200008392334 percent
# error rate on test set = 53.17676663398743 percent
#
# epoch= 189 	 time= 51.139071683088936 min 	 lr= 0.00016915987114971614 	 loss= 1.1651090097427368 	 error= 42.14000129699707 percent
# error rate on test set = 53.17676663398743 percent
#
# epoch= 190 	 time= 51.370776959260304 min 	 lr= 0.0001127732474331441 	 loss= 1.1806922769546508 	 error= 43.12000131607056 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 191 	 time= 51.6024529894193 min 	 lr= 0.0001127732474331441 	 loss= 1.1764783430099488 	 error= 42.70000147819519 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 192 	 time= 51.83404667377472 min 	 lr= 0.0001127732474331441 	 loss= 1.1671074604988099 	 error= 42.14000153541565 percent
# error rate on test set = 52.75757312774658 percent
#
# epoch= 193 	 time= 52.06505892276764 min 	 lr= 0.0001127732474331441 	 loss= 1.1701257181167604 	 error= 42.820000648498535 percent
# error rate on test set = 52.671716610590614 percent
#
# epoch= 194 	 time= 52.29671401977539 min 	 lr= 0.0001127732474331441 	 loss= 1.1541078186035156 	 error= 41.96000099182129 percent
# error rate on test set = 52.75757312774658 percent
#
# epoch= 195 	 time= 52.528484423955284 min 	 lr= 0.0001127732474331441 	 loss= 1.1721576690673827 	 error= 43.060001373291016 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 196 	 time= 52.761069317658745 min 	 lr= 0.0001127732474331441 	 loss= 1.1631208038330079 	 error= 42.100000619888306 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 197 	 time= 52.99256364107132 min 	 lr= 0.0001127732474331441 	 loss= 1.1676659870147705 	 error= 43.14000129699707 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 198 	 time= 53.22363104025523 min 	 lr= 0.0001127732474331441 	 loss= 1.1689979720115662 	 error= 43.02000093460083 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 199 	 time= 53.45476477543513 min 	 lr= 0.0001127732474331441 	 loss= 1.158595449924469 	 error= 41.84000110626221 percent
# error rate on test set = 52.924241622289024 percent

# %%
torch.save(lenet5.state_dict(), 'trained_models/emotion/lenet5_128_rotate.pt')

# %% [markdown]
# ## LeNet5 -- nn.MaxPool2d(4 x 4)
#
# The attempted improvement done over here is to increase the size of the max pooling layers from 2x2 to 4x4. This was done for multiple reasons.
#
# We do not wish to resize the input layer of 1x128x128 first because this image classification tasks deals with facial expressions and facial features which are detailed and may contain useful features for each small pixel. However, due to the size of the input layer, it results in a number of parameters in the neural network. This may result in overfitting.
#
# Hence, to reduce the number of parameters, while seeking to retain the information captured at fine-grain pixel level, we attempt to increase the size of the max pooling layers.

# %%
class LeNet5_convnet(nn.Module):

    def __init__(self):

        super(LeNet5_convnet, self).__init__()

        # CL1:   128 x 128  -->    50 x 128 x 128 
        self.conv1 = nn.Conv2d(1,   50,  kernel_size=3,  padding=1 )
        
        # MP1: 50 x 128 x 128 -->    50 x 32 x 32
        self.pool1  = nn.MaxPool2d(4,4)
        
        # CL2:   50 x 32 x 32  -->    100 x 32 x 32 
        self.conv2 = nn.Conv2d(50,  100,  kernel_size=3,  padding=1 )
        
        # MP2: 100 x 32 x 32 -->    100 x 8 x 8
        self.pool2 = nn.MaxPool2d(4,4)
        
        # LL1:   100 x 8 x 8 = 6400 -->  100
        self.linear1 = nn.Linear(6400, 100)
        
        # LL2:   100  -->  7
        self.linear2 = nn.Linear(100, 7)


    def forward(self, x):

        self.x1 = self.conv1(x)
        self.x2 = torch.relu(self.x1)
        self.x3 = self.pool1(self.x2)
        self.x4 = self.conv2(self.x3)
        self.x5 = torch.relu(self.x4)
        self.x6 = self.pool2(self.x5)
        self.x7 = self.x6.view(-1, 6400)
        self.x8 = self.linear1(self.x7)
        self.x9 = torch.relu(self.x8)
        self.out = self.linear2(self.x9)
    
        return self.out

    def get_features(self):
        return self.x1, self.x2, self.x3, self.x4, self.x5, self.x6, self.x7, self.x8, self.x9, self.out

# %%
lenet5_v2 = LeNet5_convnet()
print(lenet5_v2)
utils.display_num_param(lenet5_v2)
# Out:
# LeNet5_convnet(
#   (conv1): Conv2d(1, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(50, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (linear1): Linear(in_features=6400, out_features=100, bias=True)
#   (linear2): Linear(in_features=100, out_features=7, bias=True)
# )
# There are 686407 (0.69 million) parameters in this neural network

# %%
criterion = nn.CrossEntropyLoss()
my_lr = 0.25
lenet5_v2 = net.to(device)
# mean = mean.to(device)
# std = std.to(device)

start = time.time()

for epoch in range(1,200):
    
    if not epoch%10:
        my_lr = my_lr / 1.5
        
    optimizer = torch.optim.SGD( net.parameters() , lr=my_lr )
    
    #################
    # TRAINING DATA #
    #################
        
    train_running_loss = 0
    train_running_error = 0
    train_num_batches = 0
    
    for train_minibatch_data, train_minibatch_label in train_dl:
        
        # FORWARD AND BACKWARD PASS
    
        optimizer.zero_grad()
        
        train_minibatch_data = train_minibatch_data.to(device)
        train_minibatch_label = train_minibatch_label.to(device)
        
        train_inputs = train_minibatch_data.view(-1, 1, 128, 128) # (train_minibatch_data - mean) / std
        
        train_inputs.requires_grad_()

        train_scores = lenet5_v2(train_inputs) 

        train_loss = criterion(train_scores , train_minibatch_label) 
          
        train_loss.backward()
        
        optimizer.step()
        
        # COMPUTE STATS
        
        train_running_loss += train_loss.detach().item()
        
        train_error = utils.get_error(train_scores.detach() , train_minibatch_label)
        train_running_error += train_error.item()
        
        train_num_batches += 1        
    
    
    # AVERAGE STATS THEN DISPLAY
    train_total_loss = train_running_loss / train_num_batches
    train_total_error = train_running_error / train_num_batches
    train_elapsed = (time.time()-start) / 60
    
    print(
        'epoch=', epoch,
        '\t time=', train_elapsed,
        'min', 
        '\t lr=', my_lr ,
        '\t loss=', train_total_loss, 
        '\t error=', train_total_error*100,
        'percent'
    )
    
    ###################
    # VALIDATION DATA #
    ###################
    
    eval_on_dataset_loader(lenet5_v2, valid_dl)
    
#     valid_running_error=0
#     valid_num_batches=0

#     for valid_minibatch_data, valid_minibatch_label in valid_dl:

#         valid_minibatch_data = valid_minibatch_data.to(device)
#         valid_minibatch_label = valid_minibatch_label.to(device)
        
#         valid_inputs = valid_minibatch_data.view(-1, 1, 128, 128) # (valid_minibatch_data - mean) / std    # ONLY CHANGE IS HERE!

#         valid_scores = net(valid_inputs) 

#         valid_error = utils.get_error(valid_scores , valid_minibatch_label)

#         valid_running_error += valid_error.item()

#         valid_num_batches+=1


#     valid_total_error = valid_running_error / valid_num_batches
#     print('error rate on test set =', valid_total_error*100 , 'percent')
#     print(' ')
# Out:
# epoch= 1 	 time= 0.15357844432195028 min 	 lr= 0.25 	 loss= 1.937640199661255 	 error= 81.16000056266785 percent
# error rate on test set = 82.5000007947286 percent
#
# epoch= 2 	 time= 0.3268059770266215 min 	 lr= 0.25 	 loss= 1.930358691215515 	 error= 81.42000007629395 percent
# error rate on test set = 83.21212132771811 percent
#
# epoch= 3 	 time= 0.4992769757906596 min 	 lr= 0.25 	 loss= 1.9228908109664917 	 error= 79.90000081062317 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 4 	 time= 0.6723734458287557 min 	 lr= 0.25 	 loss= 1.913659052848816 	 error= 78.62000012397766 percent
# error rate on test set = 78.78787914911905 percent
#
# epoch= 5 	 time= 0.8460733413696289 min 	 lr= 0.25 	 loss= 1.9360142374038696 	 error= 80.5 percent
# error rate on test set = 82.16666777928671 percent
#
# epoch= 6 	 time= 1.0133268713951111 min 	 lr= 0.25 	 loss= 1.9022597932815553 	 error= 78.84000039100647 percent
# error rate on test set = 74.80808099110922 percent
#
# epoch= 7 	 time= 1.183873442808787 min 	 lr= 0.25 	 loss= 1.8870272064208984 	 error= 75.98000025749207 percent
# error rate on test set = 76.42929156621298 percent
#
# epoch= 8 	 time= 1.3476201017697653 min 	 lr= 0.25 	 loss= 1.8710416555404663 	 error= 75.44000053405762 percent
# error rate on test set = 72.39899039268494 percent
#
# epoch= 9 	 time= 1.5112676819165547 min 	 lr= 0.25 	 loss= 1.8445664739608765 	 error= 74.54000043869019 percent
# error rate on test set = 65.75757463773093 percent
#
# epoch= 10 	 time= 1.6757518728574117 min 	 lr= 0.16666666666666666 	 loss= 1.7842618656158447 	 error= 71.36000061035156 percent
# error rate on test set = 67.52525170644125 percent
#
# epoch= 11 	 time= 1.840957808494568 min 	 lr= 0.16666666666666666 	 loss= 1.7964784908294678 	 error= 71.8200011253357 percent
# error rate on test set = 76.95454557736716 percent
#
# epoch= 12 	 time= 2.0125348567962646 min 	 lr= 0.16666666666666666 	 loss= 1.8035804367065429 	 error= 72.08000087738037 percent
# error rate on test set = 69.32323177655539 percent
#
# epoch= 13 	 time= 2.1755688786506653 min 	 lr= 0.16666666666666666 	 loss= 1.7713486099243163 	 error= 69.46000051498413 percent
# error rate on test set = 70.2373723189036 percent
#
# epoch= 14 	 time= 2.339792025089264 min 	 lr= 0.16666666666666666 	 loss= 1.7770680427551269 	 error= 70.38000130653381 percent
# error rate on test set = 66.0151501496633 percent
#
# epoch= 15 	 time= 2.510534210999807 min 	 lr= 0.16666666666666666 	 loss= 1.7519249486923218 	 error= 69.2200014591217 percent
# error rate on test set = 68.1969702243805 percent
#
# epoch= 16 	 time= 2.6758684277534486 min 	 lr= 0.16666666666666666 	 loss= 1.7473436737060546 	 error= 68.94000053405762 percent
# error rate on test set = 68.92929275830588 percent
#
# epoch= 17 	 time= 2.8429173707962034 min 	 lr= 0.16666666666666666 	 loss= 1.7526663541793823 	 error= 69.22000074386597 percent
# error rate on test set = 69.26262577374777 percent
#
# epoch= 18 	 time= 3.0095584988594055 min 	 lr= 0.16666666666666666 	 loss= 1.7305786228179931 	 error= 67.98000049591064 percent
# error rate on test set = 75.73232253392538 percent
#
# epoch= 19 	 time= 3.179675010840098 min 	 lr= 0.16666666666666666 	 loss= 1.768919677734375 	 error= 70.64000129699707 percent
# error rate on test set = 70.29292980829874 percent
#
# epoch= 20 	 time= 3.35233496427536 min 	 lr= 0.1111111111111111 	 loss= 1.7101976299285888 	 error= 68.04000115394592 percent
# error rate on test set = 64.5252525806427 percent
#
# epoch= 21 	 time= 3.5170967817306518 min 	 lr= 0.1111111111111111 	 loss= 1.7015653705596925 	 error= 66.70000004768372 percent
# error rate on test set = 64.82828458150229 percent
#
# epoch= 22 	 time= 3.680724044640859 min 	 lr= 0.1111111111111111 	 loss= 1.6943280649185182 	 error= 66.70000100135803 percent
# error rate on test set = 76.54040455818176 percent
#
# epoch= 23 	 time= 3.8467013001441956 min 	 lr= 0.1111111111111111 	 loss= 1.6926443576812744 	 error= 66.10000014305115 percent
# error rate on test set = 70.38383682568869 percent
#
# epoch= 24 	 time= 4.012064675490062 min 	 lr= 0.1111111111111111 	 loss= 1.6786072063446045 	 error= 66.80000066757202 percent
# error rate on test set = 67.48989820480347 percent
#
# epoch= 25 	 time= 4.1750061710675554 min 	 lr= 0.1111111111111111 	 loss= 1.6720344591140748 	 error= 65.78000116348267 percent
# error rate on test set = 69.97979680697122 percent
#
# epoch= 26 	 time= 4.340097212791443 min 	 lr= 0.1111111111111111 	 loss= 1.6722479152679444 	 error= 66.36000037193298 percent
# error rate on test set = 71.49495085080466 percent
#
# epoch= 27 	 time= 4.5042316794395445 min 	 lr= 0.1111111111111111 	 loss= 1.6801966285705567 	 error= 65.84000086784363 percent
# error rate on test set = 66.80807868639627 percent
#
# epoch= 28 	 time= 4.669658637046814 min 	 lr= 0.1111111111111111 	 loss= 1.6572953462600708 	 error= 64.78000020980835 percent
# error rate on test set = 73.58585794766745 percent
#
# epoch= 29 	 time= 4.835605990886688 min 	 lr= 0.1111111111111111 	 loss= 1.654109230041504 	 error= 64.02000069618225 percent
# error rate on test set = 74.95454549789429 percent
#
# epoch= 30 	 time= 5.0028126041094465 min 	 lr= 0.07407407407407407 	 loss= 1.6142943477630616 	 error= 62.56000089645386 percent
# error rate on test set = 62.18686898549398 percent
#
# epoch= 31 	 time= 5.167234015464783 min 	 lr= 0.07407407407407407 	 loss= 1.6044085025787354 	 error= 62.28000068664551 percent
# error rate on test set = 68.81818175315857 percent
#
# epoch= 32 	 time= 5.333613510926565 min 	 lr= 0.07407407407407407 	 loss= 1.605720329284668 	 error= 62.45999956130981 percent
# error rate on test set = 71.48484786351523 percent
#
# epoch= 33 	 time= 5.500101582209269 min 	 lr= 0.07407407407407407 	 loss= 1.615175828933716 	 error= 63.20000147819519 percent
# error rate on test set = 64.44949706395468 percent
#
# epoch= 34 	 time= 5.66686802705129 min 	 lr= 0.07407407407407407 	 loss= 1.570884757041931 	 error= 61.02000093460083 percent
# error rate on test set = 61.919192473093666 percent
#
# epoch= 35 	 time= 5.832738999525706 min 	 lr= 0.07407407407407407 	 loss= 1.5876989364624023 	 error= 61.74000144004822 percent
# error rate on test set = 63.84343504905701 percent
#
# epoch= 36 	 time= 6.000387632846833 min 	 lr= 0.07407407407407407 	 loss= 1.587491750717163 	 error= 61.60000038146972 percent
# error rate on test set = 62.954547007878624 percent
#
# epoch= 37 	 time= 6.165158271789551 min 	 lr= 0.07407407407407407 	 loss= 1.5894652462005616 	 error= 61.660001039505005 percent
# error rate on test set = 68.51515173912048 percent
#
# epoch= 38 	 time= 6.332039932409923 min 	 lr= 0.07407407407407407 	 loss= 1.5823327445983886 	 error= 60.84000086784363 percent
# error rate on test set = 64.28283055623373 percent
#
# epoch= 39 	 time= 6.4973214864730835 min 	 lr= 0.07407407407407407 	 loss= 1.5718158054351807 	 error= 60.58000111579895 percent
# error rate on test set = 67.04545617103577 percent
#
# epoch= 40 	 time= 6.6586239139239 min 	 lr= 0.04938271604938271 	 loss= 1.557987461090088 	 error= 59.36000061035156 percent
# error rate on test set = 70.49494981765747 percent
#
# epoch= 41 	 time= 6.82538323799769 min 	 lr= 0.04938271604938271 	 loss= 1.5564801597595215 	 error= 60.660001039505005 percent
# error rate on test set = 62.43939598401388 percent
#
# epoch= 42 	 time= 6.995305399099986 min 	 lr= 0.04938271604938271 	 loss= 1.557242693901062 	 error= 59.36000156402588 percent
# error rate on test set = 62.272727489471436 percent
#
# epoch= 43 	 time= 7.161019639174143 min 	 lr= 0.04938271604938271 	 loss= 1.5345853471755981 	 error= 58.70000171661377 percent
# error rate on test set = 61.51515245437622 percent
#
# epoch= 44 	 time= 7.329674625396729 min 	 lr= 0.04938271604938271 	 loss= 1.5406940698623657 	 error= 59.30000138282776 percent
# error rate on test set = 61.51009996732076 percent
#
# epoch= 45 	 time= 7.500386051336924 min 	 lr= 0.04938271604938271 	 loss= 1.5441228532791138 	 error= 58.62000060081481 percent
# error rate on test set = 66.11616412798563 percent
#
# epoch= 46 	 time= 7.668496751785279 min 	 lr= 0.04938271604938271 	 loss= 1.5282310009002686 	 error= 59.70000123977661 percent
# error rate on test set = 61.535354455312095 percent
#
# epoch= 47 	 time= 7.833279248078664 min 	 lr= 0.04938271604938271 	 loss= 1.5111850833892821 	 error= 57.14000153541565 percent
# error rate on test set = 62.32828497886658 percent
#
# epoch= 48 	 time= 7.999850726127624 min 	 lr= 0.04938271604938271 	 loss= 1.518472146987915 	 error= 58.400001525878906 percent
# error rate on test set = 59.84343489011129 percent
#
# epoch= 49 	 time= 8.164151811599732 min 	 lr= 0.04938271604938271 	 loss= 1.5218052530288697 	 error= 57.60000181198121 percent
# error rate on test set = 66.1717176437378 percent
#
# epoch= 50 	 time= 8.325816297531128 min 	 lr= 0.03292181069958847 	 loss= 1.5080949687957763 	 error= 56.960001945495605 percent
# error rate on test set = 61.58585945765177 percent
#
# epoch= 51 	 time= 8.49141769806544 min 	 lr= 0.03292181069958847 	 loss= 1.5018421697616577 	 error= 57.78000187873841 percent
# error rate on test set = 61.16666595141093 percent
#
# epoch= 52 	 time= 8.659823886553447 min 	 lr= 0.03292181069958847 	 loss= 1.5012840700149537 	 error= 57.440001249313354 percent
# error rate on test set = 61.34848395983378 percent
#
# epoch= 53 	 time= 8.825028860569 min 	 lr= 0.03292181069958847 	 loss= 1.4850473594665528 	 error= 56.96000051498413 percent
# error rate on test set = 59.500000874201454 percent
#
# epoch= 54 	 time= 8.989625827471416 min 	 lr= 0.03292181069958847 	 loss= 1.4845549726486207 	 error= 56.220001697540276 percent
# error rate on test set = 59.2727263768514 percent
#
# epoch= 55 	 time= 9.15417104959488 min 	 lr= 0.03292181069958847 	 loss= 1.4777776002883911 	 error= 56.660001039505005 percent
# error rate on test set = 61.69696847597758 percent
#
# epoch= 56 	 time= 9.320251870155335 min 	 lr= 0.03292181069958847 	 loss= 1.485519633293152 	 error= 56.3600013256073 percent
# error rate on test set = 57.590909798940025 percent
#
# epoch= 57 	 time= 9.490376329421997 min 	 lr= 0.03292181069958847 	 loss= 1.4877704620361327 	 error= 55.80000138282776 percent
# error rate on test set = 69.5555547873179 percent
#
# epoch= 58 	 time= 9.657825620969136 min 	 lr= 0.03292181069958847 	 loss= 1.4784352588653564 	 error= 55.96000123023986 percent
# error rate on test set = 59.969695409139 percent
#
# epoch= 59 	 time= 9.82430808544159 min 	 lr= 0.03292181069958847 	 loss= 1.476932406425476 	 error= 55.980000495910645 percent
# error rate on test set = 60.8535369237264 percent
#
# epoch= 60 	 time= 9.990947862466177 min 	 lr= 0.02194787379972565 	 loss= 1.4714431762695312 	 error= 55.38000178337097 percent
# error rate on test set = 58.85353684425354 percent
#
# epoch= 61 	 time= 10.158339993158977 min 	 lr= 0.02194787379972565 	 loss= 1.4775275802612304 	 error= 55.880001068115234 percent
# error rate on test set = 59.41919287045797 percent
#
# epoch= 62 	 time= 10.319204080104829 min 	 lr= 0.02194787379972565 	 loss= 1.469214506149292 	 error= 56.1200020313263 percent
# error rate on test set = 58.3383838335673 percent
#
# epoch= 63 	 time= 10.48544185558955 min 	 lr= 0.02194787379972565 	 loss= 1.4620149660110473 	 error= 55.46000123023986 percent
# error rate on test set = 58.348482847213745 percent
#
# epoch= 64 	 time= 10.654459683100383 min 	 lr= 0.02194787379972565 	 loss= 1.4595449161529541 	 error= 55.5400013923645 percent
# error rate on test set = 62.34848499298096 percent
#
# epoch= 65 	 time= 10.825613296031952 min 	 lr= 0.02194787379972565 	 loss= 1.4577169704437256 	 error= 55.52000093460083 percent
# error rate on test set = 61.409089962641396 percent
#
# epoch= 66 	 time= 10.998868477344512 min 	 lr= 0.02194787379972565 	 loss= 1.4550031089782716 	 error= 54.280000686645515 percent
# error rate on test set = 58.34343433380127 percent
#
# epoch= 67 	 time= 11.163527512550354 min 	 lr= 0.02194787379972565 	 loss= 1.4619477844238282 	 error= 54.58000087738037 percent
# error rate on test set = 59.01515086491903 percent
#
# epoch= 68 	 time= 11.331464838981628 min 	 lr= 0.02194787379972565 	 loss= 1.4472559690475464 	 error= 54.72000026702881 percent
# error rate on test set = 58.24747482935587 percent
#
# epoch= 69 	 time= 11.492051076889037 min 	 lr= 0.02194787379972565 	 loss= 1.4499271249771117 	 error= 54.82000088691712 percent
# error rate on test set = 60.353535413742065 percent
#
# epoch= 70 	 time= 11.65578425725301 min 	 lr= 0.014631915866483767 	 loss= 1.445273060798645 	 error= 54.66000056266785 percent
# error rate on test set = 57.762626806894936 percent
#
# epoch= 71 	 time= 11.820897893110912 min 	 lr= 0.014631915866483767 	 loss= 1.43366596698761 	 error= 53.920000314712524 percent
# error rate on test set = 58.85858734448751 percent
#
# epoch= 72 	 time= 11.985699276129404 min 	 lr= 0.014631915866483767 	 loss= 1.4421534061431884 	 error= 54.32000088691712 percent
# error rate on test set = 58.6060623327891 percent
#
# epoch= 73 	 time= 12.152794126669566 min 	 lr= 0.014631915866483767 	 loss= 1.4429555320739746 	 error= 54.10000061988831 percent
# error rate on test set = 58.6060623327891 percent
#
# epoch= 74 	 time= 12.323627444108327 min 	 lr= 0.014631915866483767 	 loss= 1.4486819887161255 	 error= 54.160000801086426 percent
# error rate on test set = 57.85353581110636 percent
#
# epoch= 75 	 time= 12.497089477380117 min 	 lr= 0.014631915866483767 	 loss= 1.4243710899353028 	 error= 53.680001735687256 percent
# error rate on test set = 60.242424408594765 percent
#
# epoch= 76 	 time= 12.663591492176057 min 	 lr= 0.014631915866483767 	 loss= 1.4397072219848632 	 error= 53.22000050544739 percent
# error rate on test set = 57.60606129964193 percent
#
# epoch= 77 	 time= 12.830497523148855 min 	 lr= 0.014631915866483767 	 loss= 1.4465449523925782 	 error= 53.53999996185303 percent
# error rate on test set = 57.34848380088806 percent
#
# epoch= 78 	 time= 12.999414491653443 min 	 lr= 0.014631915866483767 	 loss= 1.4320877838134765 	 error= 53.9800009727478 percent
# error rate on test set = 56.000002225240074 percent
#
# epoch= 79 	 time= 13.169889803727468 min 	 lr= 0.014631915866483767 	 loss= 1.4378600025177002 	 error= 52.80000066757202 percent
# error rate on test set = 56.863635778427124 percent
#
# epoch= 80 	 time= 13.337618001302083 min 	 lr= 0.009754610577655845 	 loss= 1.441635069847107 	 error= 54.420001029968255 percent
# error rate on test set = 54.83333667119344 percent
#
# epoch= 81 	 time= 13.504743091265361 min 	 lr= 0.009754610577655845 	 loss= 1.4331294250488282 	 error= 53.62000060081482 percent
# error rate on test set = 57.17171629269918 percent
#
# epoch= 82 	 time= 13.672885425885518 min 	 lr= 0.009754610577655845 	 loss= 1.4268323183059692 	 error= 53.74000024795532 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 83 	 time= 13.839977812767028 min 	 lr= 0.009754610577655845 	 loss= 1.4399783515930176 	 error= 53.96000075340272 percent
# error rate on test set = 56.919193267822266 percent
#
# epoch= 84 	 time= 14.00517654021581 min 	 lr= 0.009754610577655845 	 loss= 1.4213891649246215 	 error= 53.42000007629395 percent
# error rate on test set = 58.34848483403524 percent
#
# epoch= 85 	 time= 14.171410000324249 min 	 lr= 0.009754610577655845 	 loss= 1.4217368459701538 	 error= 53.360000133514404 percent
# error rate on test set = 57.34343330065409 percent
#
# epoch= 86 	 time= 14.336231255531311 min 	 lr= 0.009754610577655845 	 loss= 1.4340300941467286 	 error= 53.55999946594239 percent
# error rate on test set = 57.08585778872172 percent
#
# epoch= 87 	 time= 14.50092287460963 min 	 lr= 0.009754610577655845 	 loss= 1.421099967956543 	 error= 54.06000065803528 percent
# error rate on test set = 57.60101079940796 percent
#
# epoch= 88 	 time= 14.672011387348174 min 	 lr= 0.009754610577655845 	 loss= 1.4022050762176514 	 error= 51.8199999332428 percent
# error rate on test set = 56.74747625986735 percent
#
# epoch= 89 	 time= 14.83508070309957 min 	 lr= 0.009754610577655845 	 loss= 1.4190014123916626 	 error= 52.41999959945679 percent
# error rate on test set = 56.68687025705973 percent
#
# epoch= 90 	 time= 14.993919491767883 min 	 lr= 0.0065030737184372306 	 loss= 1.4161944913864135 	 error= 53.49999976158142 percent
# error rate on test set = 56.33838574091593 percent
#
# epoch= 91 	 time= 15.161984972159068 min 	 lr= 0.0065030737184372306 	 loss= 1.4125576257705688 	 error= 52.380000352859504 percent
# error rate on test set = 56.51010274887085 percent
#
# epoch= 92 	 time= 15.330486849943798 min 	 lr= 0.0065030737184372306 	 loss= 1.4296454620361327 	 error= 53.040000200271606 percent
# error rate on test set = 57.33333428700765 percent
#
# epoch= 93 	 time= 15.497334718704224 min 	 lr= 0.0065030737184372306 	 loss= 1.4021798181533813 	 error= 52.55999994277955 percent
# error rate on test set = 56.494951248168945 percent
#
# epoch= 94 	 time= 15.660159993171693 min 	 lr= 0.0065030737184372306 	 loss= 1.4167549705505371 	 error= 52.660000801086426 percent
# error rate on test set = 55.58585921923319 percent
#
# epoch= 95 	 time= 15.828071049849193 min 	 lr= 0.0065030737184372306 	 loss= 1.4147625541687012 	 error= 53.220001220703125 percent
# error rate on test set = 56.59595926602682 percent
#
# epoch= 96 	 time= 15.99741172393163 min 	 lr= 0.0065030737184372306 	 loss= 1.4116235494613647 	 error= 52.519999504089355 percent
# error rate on test set = 57.00504978497823 percent
#
# epoch= 97 	 time= 16.16837745110194 min 	 lr= 0.0065030737184372306 	 loss= 1.4074710559844972 	 error= 52.880000591278076 percent
# error rate on test set = 55.75757622718811 percent
#
# epoch= 98 	 time= 16.337922171751657 min 	 lr= 0.0065030737184372306 	 loss= 1.4082368326187134 	 error= 52.3400001525879 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 99 	 time= 16.508427059650423 min 	 lr= 0.0065030737184372306 	 loss= 1.4027278518676758 	 error= 51.64000058174133 percent
# error rate on test set = 58.005050818125405 percent
#
# epoch= 100 	 time= 16.676453145345054 min 	 lr= 0.004335382478958154 	 loss= 1.4042778301239014 	 error= 51.540000200271606 percent
# error rate on test set = 54.49495116869608 percent
#
# epoch= 101 	 time= 16.839519810676574 min 	 lr= 0.004335382478958154 	 loss= 1.4109371900558472 	 error= 53.00000071525574 percent
# error rate on test set = 56.92424178123474 percent
#
# epoch= 102 	 time= 17.005981437365215 min 	 lr= 0.004335382478958154 	 loss= 1.3994975233078002 	 error= 51.96000027656555 percent
# error rate on test set = 54.74242369333903 percent
#
# epoch= 103 	 time= 17.175728114446006 min 	 lr= 0.004335382478958154 	 loss= 1.3967730522155761 	 error= 52.42000055313111 percent
# error rate on test set = 56.0909112294515 percent
#
# epoch= 104 	 time= 17.339647603034972 min 	 lr= 0.004335382478958154 	 loss= 1.412984881401062 	 error= 52.66000032424927 percent
# error rate on test set = 56.419193744659424 percent
#
# epoch= 105 	 time= 17.50998456478119 min 	 lr= 0.004335382478958154 	 loss= 1.4079503011703491 	 error= 52.36000084877014 percent
# error rate on test set = 56.848486264546715 percent
#
# epoch= 106 	 time= 17.677236394087473 min 	 lr= 0.004335382478958154 	 loss= 1.4033529615402223 	 error= 52.640000104904175 percent
# error rate on test set = 56.095959742863975 percent
#
# epoch= 107 	 time= 17.849460057417552 min 	 lr= 0.004335382478958154 	 loss= 1.3991826105117797 	 error= 51.80000114440918 percent
# error rate on test set = 55.59090971946716 percent
#
# epoch= 108 	 time= 18.016563630104066 min 	 lr= 0.004335382478958154 	 loss= 1.389657883644104 	 error= 51.9200005531311 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 109 	 time= 18.188180832068124 min 	 lr= 0.004335382478958154 	 loss= 1.4162775087356567 	 error= 53.139999866485596 percent
# error rate on test set = 56.419193744659424 percent
#
# epoch= 110 	 time= 18.353375240166983 min 	 lr= 0.0028902549859721027 	 loss= 1.396439685821533 	 error= 51.40000033378601 percent
# error rate on test set = 55.333336194356285 percent
#
# epoch= 111 	 time= 18.5190753142039 min 	 lr= 0.0028902549859721027 	 loss= 1.4075564813613892 	 error= 53.02000093460083 percent
# error rate on test set = 57.08080927530924 percent
#
# epoch= 112 	 time= 18.679076766967775 min 	 lr= 0.0028902549859721027 	 loss= 1.4091103792190551 	 error= 52.96000075340272 percent
# error rate on test set = 55.752527713775635 percent
#
# epoch= 113 	 time= 18.844180794556937 min 	 lr= 0.0028902549859721027 	 loss= 1.3964487934112548 	 error= 52.06000113487244 percent
# error rate on test set = 56.16666873296102 percent
#
# epoch= 114 	 time= 19.006357634067534 min 	 lr= 0.0028902549859721027 	 loss= 1.4032789850234986 	 error= 52.62000060081482 percent
# error rate on test set = 56.75252676010132 percent
#
# epoch= 115 	 time= 19.168818295001984 min 	 lr= 0.0028902549859721027 	 loss= 1.4036482620239257 	 error= 52.98000049591064 percent
# error rate on test set = 55.828285217285156 percent
#
# epoch= 116 	 time= 19.332388691107433 min 	 lr= 0.0028902549859721027 	 loss= 1.3987228679656982 	 error= 52.06000065803528 percent
# error rate on test set = 55.50000270207723 percent
#
# epoch= 117 	 time= 19.502305738131206 min 	 lr= 0.0028902549859721027 	 loss= 1.3963961505889892 	 error= 51.700000524520874 percent
# error rate on test set = 55.752527713775635 percent
#
# epoch= 118 	 time= 19.66741523742676 min 	 lr= 0.0028902549859721027 	 loss= 1.3888693571090698 	 error= 51.64000058174133 percent
# error rate on test set = 55.92424472173055 percent
#
# epoch= 119 	 time= 19.833123199145 min 	 lr= 0.0028902549859721027 	 loss= 1.385333113670349 	 error= 51.00000071525573 percent
# error rate on test set = 56.50505224863688 percent
#
# epoch= 120 	 time= 19.993418788909914 min 	 lr= 0.001926836657314735 	 loss= 1.3754111862182616 	 error= 50.18000078201293 percent
# error rate on test set = 55.50000270207723 percent
#
# epoch= 121 	 time= 20.158658023675283 min 	 lr= 0.001926836657314735 	 loss= 1.4064107942581177 	 error= 52.92000007629395 percent
# error rate on test set = 56.16666873296102 percent
#
# epoch= 122 	 time= 20.31992449760437 min 	 lr= 0.001926836657314735 	 loss= 1.3947413682937622 	 error= 51.640000343322754 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 123 	 time= 20.48421396811803 min 	 lr= 0.001926836657314735 	 loss= 1.389565076828003 	 error= 51.46000027656555 percent
# error rate on test set = 56.671718756357826 percent
#
# epoch= 124 	 time= 20.64318466981252 min 	 lr= 0.001926836657314735 	 loss= 1.4007485294342041 	 error= 51.94000029563903 percent
# error rate on test set = 56.419193744659424 percent
#
# epoch= 125 	 time= 20.8080335577329 min 	 lr= 0.001926836657314735 	 loss= 1.3891062927246094 	 error= 51.660000085830696 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 126 	 time= 20.96741140683492 min 	 lr= 0.001926836657314735 	 loss= 1.3935008764266967 	 error= 51.75999903678894 percent
# error rate on test set = 56.16666873296102 percent
#
# epoch= 127 	 time= 21.132057321071624 min 	 lr= 0.001926836657314735 	 loss= 1.391826548576355 	 error= 52.32000017166138 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 128 	 time= 21.296295940876007 min 	 lr= 0.001926836657314735 	 loss= 1.3923033332824708 	 error= 52.24000048637391 percent
# error rate on test set = 55.41414419809977 percent
#
# epoch= 129 	 time= 21.45720956325531 min 	 lr= 0.001926836657314735 	 loss= 1.3826239228248596 	 error= 51.2400004863739 percent
# error rate on test set = 56.671718756357826 percent
#
# epoch= 130 	 time= 21.61820222934087 min 	 lr= 0.0012845577715431568 	 loss= 1.3826359844207763 	 error= 51.56000065803528 percent
# error rate on test set = 56.58586025238037 percent
#
# epoch= 131 	 time= 21.78476930061976 min 	 lr= 0.0012845577715431568 	 loss= 1.395603528022766 	 error= 51.880000352859504 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 132 	 time= 21.94840318361918 min 	 lr= 0.0012845577715431568 	 loss= 1.4072119665145875 	 error= 51.56000065803528 percent
# error rate on test set = 56.671718756357826 percent
#
# epoch= 133 	 time= 22.10979271332423 min 	 lr= 0.0012845577715431568 	 loss= 1.3848231315612793 	 error= 51.12000012397766 percent
# error rate on test set = 56.000002225240074 percent
#
# epoch= 134 	 time= 22.27090151309967 min 	 lr= 0.0012845577715431568 	 loss= 1.3867082071304322 	 error= 52.05999994277954 percent
# error rate on test set = 55.58586120605469 percent
#
# epoch= 135 	 time= 22.436168336868285 min 	 lr= 0.0012845577715431568 	 loss= 1.4004149532318115 	 error= 52.82000017166138 percent
# error rate on test set = 56.08586072921753 percent
#
# epoch= 136 	 time= 22.599829288323722 min 	 lr= 0.0012845577715431568 	 loss= 1.3841327714920044 	 error= 51.37999963760376 percent
# error rate on test set = 55.080811182657875 percent
#
# epoch= 137 	 time= 22.76469208796819 min 	 lr= 0.0012845577715431568 	 loss= 1.4059617805480957 	 error= 52.28000020980835 percent
# error rate on test set = 56.171719233194985 percent
#
# epoch= 138 	 time= 22.920725695292155 min 	 lr= 0.0012845577715431568 	 loss= 1.3940021705627441 	 error= 51.74000024795532 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 139 	 time= 23.07995497385661 min 	 lr= 0.0012845577715431568 	 loss= 1.3883686351776123 	 error= 52.03999996185302 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 140 	 time= 23.24716629187266 min 	 lr= 0.0008563718476954379 	 loss= 1.3972022819519043 	 error= 51.919999837875366 percent
# error rate on test set = 55.58081070582072 percent
#
# epoch= 141 	 time= 23.412671236197152 min 	 lr= 0.0008563718476954379 	 loss= 1.384308886528015 	 error= 51.519999980926514 percent
# error rate on test set = 55.328285694122314 percent
#
# epoch= 142 	 time= 23.582125461101533 min 	 lr= 0.0008563718476954379 	 loss= 1.3853648757934571 	 error= 51.380000591278076 percent
# error rate on test set = 55.66666920979818 percent
#
# epoch= 143 	 time= 23.74618496497472 min 	 lr= 0.0008563718476954379 	 loss= 1.3848551654815673 	 error= 51.27999973297119 percent
# error rate on test set = 56.419193744659424 percent
#
# epoch= 144 	 time= 23.909551552931468 min 	 lr= 0.0008563718476954379 	 loss= 1.3957766437530517 	 error= 52.62000012397766 percent
# error rate on test set = 56.000002225240074 percent
#
# epoch= 145 	 time= 24.07236808538437 min 	 lr= 0.0008563718476954379 	 loss= 1.3895287227630615 	 error= 51.5600004196167 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 146 	 time= 24.233539199829103 min 	 lr= 0.0008563718476954379 	 loss= 1.4012943935394286 	 error= 51.52000093460083 percent
# error rate on test set = 55.91414372126261 percent
#
# epoch= 147 	 time= 24.396045299371085 min 	 lr= 0.0008563718476954379 	 loss= 1.3896919870376587 	 error= 51.72000026702881 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 148 	 time= 24.554168697198232 min 	 lr= 0.0008563718476954379 	 loss= 1.391043610572815 	 error= 51.72000002861022 percent
# error rate on test set = 55.747477213541664 percent
#
# epoch= 149 	 time= 24.707345155874886 min 	 lr= 0.0008563718476954379 	 loss= 1.392330331802368 	 error= 51.540000200271606 percent
# error rate on test set = 56.000002225240074 percent
#
# epoch= 150 	 time= 24.86467110713323 min 	 lr= 0.0005709145651302919 	 loss= 1.3933891344070435 	 error= 52.46000027656555 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 151 	 time= 25.030250684420267 min 	 lr= 0.0005709145651302919 	 loss= 1.391422700881958 	 error= 51.880000352859504 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 152 	 time= 25.18866597811381 min 	 lr= 0.0005709145651302919 	 loss= 1.3860324430465698 	 error= 51.12000060081482 percent
# error rate on test set = 55.747477213541664 percent
#
# epoch= 153 	 time= 25.353291086355846 min 	 lr= 0.0005709145651302919 	 loss= 1.3917091035842895 	 error= 51.380000591278076 percent
# error rate on test set = 55.16161918640137 percent
#
# epoch= 154 	 time= 25.518034064769743 min 	 lr= 0.0005709145651302919 	 loss= 1.3973952913284302 	 error= 52.079999923706055 percent
# error rate on test set = 55.49495220184326 percent
#
# epoch= 155 	 time= 25.678175417582192 min 	 lr= 0.0005709145651302919 	 loss= 1.3983155918121337 	 error= 52.09999966621399 percent
# error rate on test set = 55.41414419809977 percent
#
# epoch= 156 	 time= 25.836572070916493 min 	 lr= 0.0005709145651302919 	 loss= 1.3831309175491333 	 error= 51.22000026702881 percent
# error rate on test set = 55.91919422149658 percent
#
# epoch= 157 	 time= 25.998317209879556 min 	 lr= 0.0005709145651302919 	 loss= 1.3892037868499756 	 error= 51.2400004863739 percent
# error rate on test set = 55.66666920979818 percent
#
# epoch= 158 	 time= 26.161955451965333 min 	 lr= 0.0005709145651302919 	 loss= 1.3828641653060914 	 error= 50.660000562667854 percent
# error rate on test set = 56.000002225240074 percent
#
# epoch= 159 	 time= 26.324867848555247 min 	 lr= 0.0005709145651302919 	 loss= 1.4005923128128053 	 error= 52.22000050544738 percent
# error rate on test set = 56.16161823272705 percent
#
# epoch= 160 	 time= 26.48713562488556 min 	 lr= 0.0003806097100868613 	 loss= 1.3890757989883422 	 error= 51.38000011444092 percent
# error rate on test set = 56.08081022898356 percent
#
# epoch= 161 	 time= 26.652737323443095 min 	 lr= 0.0003806097100868613 	 loss= 1.391764063835144 	 error= 51.10000038146973 percent
# error rate on test set = 56.000002225240074 percent
#
# epoch= 162 	 time= 26.814377613862355 min 	 lr= 0.0003806097100868613 	 loss= 1.3870590114593506 	 error= 51.30000042915345 percent
# error rate on test set = 56.000002225240074 percent
#
# epoch= 163 	 time= 26.976855448881786 min 	 lr= 0.0003806097100868613 	 loss= 1.3926206254959106 	 error= 50.639999866485596 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 164 	 time= 27.13704955180486 min 	 lr= 0.0003806097100868613 	 loss= 1.402040672302246 	 error= 51.69999957084656 percent
# error rate on test set = 55.49495220184326 percent
#
# epoch= 165 	 time= 27.296634670098623 min 	 lr= 0.0003806097100868613 	 loss= 1.3985557460784912 	 error= 51.040001392364495 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 166 	 time= 27.458422887325288 min 	 lr= 0.0003806097100868613 	 loss= 1.3942306327819824 	 error= 52.02000093460083 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 167 	 time= 27.616476929187776 min 	 lr= 0.0003806097100868613 	 loss= 1.379795742034912 	 error= 50.72000026702881 percent
# error rate on test set = 56.000002225240074 percent
#
# epoch= 168 	 time= 27.777894035975137 min 	 lr= 0.0003806097100868613 	 loss= 1.3870818424224853 	 error= 51.640000104904175 percent
# error rate on test set = 56.08586072921753 percent
#
# epoch= 169 	 time= 27.937092582384746 min 	 lr= 0.0003806097100868613 	 loss= 1.38845458984375 	 error= 51.44000077247619 percent
# error rate on test set = 55.66666920979818 percent
#
# epoch= 170 	 time= 28.09379466374715 min 	 lr= 0.0002537398067245742 	 loss= 1.389208574295044 	 error= 52.27999973297119 percent
# error rate on test set = 56.000002225240074 percent
#
# epoch= 171 	 time= 28.25439443985621 min 	 lr= 0.0002537398067245742 	 loss= 1.3850014734268188 	 error= 51.96000003814697 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 172 	 time= 28.4212237517039 min 	 lr= 0.0002537398067245742 	 loss= 1.3920227956771851 	 error= 51.8400001525879 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 173 	 time= 28.58552503188451 min 	 lr= 0.0002537398067245742 	 loss= 1.4052340126037597 	 error= 51.72000026702881 percent
# error rate on test set = 55.747477213541664 percent
#
# epoch= 174 	 time= 28.745157178243 min 	 lr= 0.0002537398067245742 	 loss= 1.4072120523452758 	 error= 52.5 percent
# error rate on test set = 56.08586072921753 percent
#
# epoch= 175 	 time= 28.904867152372997 min 	 lr= 0.0002537398067245742 	 loss= 1.3977441930770873 	 error= 52.64000058174133 percent
# error rate on test set = 55.91919422149658 percent
#
# epoch= 176 	 time= 29.06534320116043 min 	 lr= 0.0002537398067245742 	 loss= 1.3899774503707887 	 error= 51.62000012397766 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 177 	 time= 29.22712459961573 min 	 lr= 0.0002537398067245742 	 loss= 1.382478404045105 	 error= 51.10000014305115 percent
# error rate on test set = 55.41414419809977 percent
#
# epoch= 178 	 time= 29.390224345525105 min 	 lr= 0.0002537398067245742 	 loss= 1.3842187023162842 	 error= 50.99999952316284 percent
# error rate on test set = 55.328285694122314 percent
#
# epoch= 179 	 time= 29.556696232159933 min 	 lr= 0.0002537398067245742 	 loss= 1.3968599224090577 	 error= 51.739999771118164 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 180 	 time= 29.721985801060995 min 	 lr= 0.00016915987114971614 	 loss= 1.4020250177383422 	 error= 52.299999713897705 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 181 	 time= 29.88512794971466 min 	 lr= 0.00016915987114971614 	 loss= 1.3931645345687866 	 error= 51.79999995231629 percent
# error rate on test set = 55.58081070582072 percent
#
# epoch= 182 	 time= 30.053323606650036 min 	 lr= 0.00016915987114971614 	 loss= 1.3896093273162842 	 error= 50.75999999046326 percent
# error rate on test set = 56.000002225240074 percent
#
# epoch= 183 	 time= 30.225335772832235 min 	 lr= 0.00016915987114971614 	 loss= 1.3968566513061524 	 error= 51.44000053405762 percent
# error rate on test set = 55.66666920979818 percent
#
# epoch= 184 	 time= 30.3869060754776 min 	 lr= 0.00016915987114971614 	 loss= 1.390374732017517 	 error= 51.63999962806701 percent
# error rate on test set = 55.66666920979818 percent
#
# epoch= 185 	 time= 30.554040579001107 min 	 lr= 0.00016915987114971614 	 loss= 1.3895401668548584 	 error= 51.97999978065491 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 186 	 time= 30.715706543127695 min 	 lr= 0.00016915987114971614 	 loss= 1.394678692817688 	 error= 52.139999866485596 percent
# error rate on test set = 56.08586072921753 percent
#
# epoch= 187 	 time= 30.880536588033042 min 	 lr= 0.00016915987114971614 	 loss= 1.4000027990341186 	 error= 52.32000017166138 percent
# error rate on test set = 56.25252723693848 percent
#
# epoch= 188 	 time= 31.048008739948273 min 	 lr= 0.00016915987114971614 	 loss= 1.3892354011535644 	 error= 51.96000027656555 percent
# error rate on test set = 56.08586072921753 percent
#
# epoch= 189 	 time= 31.214233899116515 min 	 lr= 0.00016915987114971614 	 loss= 1.3919252681732177 	 error= 52.420000076293945 percent
# error rate on test set = 55.41414419809977 percent
#
# epoch= 190 	 time= 31.376171350479126 min 	 lr= 0.0001127732474331441 	 loss= 1.3868591117858886 	 error= 50.87999963760376 percent
# error rate on test set = 55.66666920979818 percent
#
# epoch= 191 	 time= 31.538583962122598 min 	 lr= 0.0001127732474331441 	 loss= 1.3864004707336426 	 error= 51.26000022888184 percent
# error rate on test set = 55.41414419809977 percent
#
# epoch= 192 	 time= 31.700146849950155 min 	 lr= 0.0001127732474331441 	 loss= 1.394842848777771 	 error= 51.519999265670776 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 193 	 time= 31.85891508658727 min 	 lr= 0.0001127732474331441 	 loss= 1.4007062673568726 	 error= 51.859999656677246 percent
# error rate on test set = 55.41414419809977 percent
#
# epoch= 194 	 time= 32.01868888934453 min 	 lr= 0.0001127732474331441 	 loss= 1.3985326051712037 	 error= 51.96000123023987 percent
# error rate on test set = 55.66666920979818 percent
#
# epoch= 195 	 time= 32.182778100172676 min 	 lr= 0.0001127732474331441 	 loss= 1.390627498626709 	 error= 51.96000027656555 percent
# error rate on test set = 56.000002225240074 percent
#
# epoch= 196 	 time= 32.35020043849945 min 	 lr= 0.0001127732474331441 	 loss= 1.394702100753784 	 error= 52.06000018119812 percent
# error rate on test set = 55.41414419809977 percent
#
# epoch= 197 	 time= 32.513890945911406 min 	 lr= 0.0001127732474331441 	 loss= 1.3925529861450194 	 error= 52.18000078201294 percent
# error rate on test set = 55.83333571751913 percent
#
# epoch= 198 	 time= 32.676172629992166 min 	 lr= 0.0001127732474331441 	 loss= 1.3870771074295043 	 error= 51.12000012397766 percent
# error rate on test set = 56.419193744659424 percent
#
# epoch= 199 	 time= 32.84039182662964 min 	 lr= 0.0001127732474331441 	 loss= 1.3962902641296386 	 error= 52.1800000667572 percent
# error rate on test set = 56.25252723693848 percent

# %%
torch.save(lenet5_v2.state_dict(), 'trained_models/emotion/lenet5_128_rotate_4x4.pt')

# %% [markdown]
# ## Slow Down Decaying of LR
# In the previous rounds, we notice that the LR decayed too quickly. Hence, the error rate on test set stagnant at an early stage. Hence, over here, we decrease learning rate only after 50 epoch instead of 10 epoch.

# %%
lenet5_v3 = LeNet5_convnet()
print(lenet5_v3)
utils.display_num_param(lenet5_v3)

criterion = nn.CrossEntropyLoss()
my_lr = 0.25
lenet5_v3 = lenet5_v3.to(device)
# mean = mean.to(device)
# std = std.to(device)

start = time.time()

for epoch in range(1,200):
    
    if not epoch%50:
        my_lr = my_lr / 1.5
        
    optimizer = torch.optim.SGD( net.parameters() , lr=my_lr )
    
    #################
    # TRAINING DATA #
    #################
        
    train_running_loss = 0
    train_running_error = 0
    train_num_batches = 0
    
    for train_minibatch_data, train_minibatch_label in train_dl:
        
        # FORWARD AND BACKWARD PASS
    
        optimizer.zero_grad()
        
        train_minibatch_data = train_minibatch_data.to(device)
        train_minibatch_label = train_minibatch_label.to(device)
        
        train_inputs = train_minibatch_data.view(-1, 1, 128, 128) # (train_minibatch_data - mean) / std
        
        train_inputs.requires_grad_()

        train_scores = lenet5_v3(train_inputs) 

        train_loss = criterion(train_scores , train_minibatch_label) 
          
        train_loss.backward()
        
        optimizer.step()
        
        # COMPUTE STATS
        
        train_running_loss += train_loss.detach().item()
        
        train_error = utils.get_error(train_scores.detach() , train_minibatch_label)
        train_running_error += train_error.item()
        
        train_num_batches += 1        
    
    
    # AVERAGE STATS THEN DISPLAY
    train_total_loss = train_running_loss / train_num_batches
    train_total_error = train_running_error / train_num_batches
    train_elapsed = (time.time()-start) / 60
    
    print(
        'epoch=', epoch,
        '\t time=', train_elapsed,
        'min', 
        '\t lr=', my_lr ,
        '\t loss=', train_total_loss, 
        '\t error=', train_total_error*100,
        'percent'
    )
    
    ###################
    # VALIDATION DATA #
    ###################
    
    eval_on_dataset_loader(lenet5_v3, valid_dl)
    
#     valid_running_error=0
#     valid_num_batches=0

#     for valid_minibatch_data, valid_minibatch_label in valid_dl:

#         valid_minibatch_data = valid_minibatch_data.to(device)
#         valid_minibatch_label = valid_minibatch_label.to(device)
        
#         valid_inputs = valid_minibatch_data.view(-1, 1, 128, 128) # (valid_minibatch_data - mean) / std    # ONLY CHANGE IS HERE!

#         valid_scores = net(valid_inputs) 

#         valid_error = utils.get_error(valid_scores , valid_minibatch_label)

#         valid_running_error += valid_error.item()

#         valid_num_batches+=1


#     valid_total_error = valid_running_error / valid_num_batches
#     print('error rate on test set =', valid_total_error*100 , 'percent')
#     print(' ')
# Out:
# LeNet5_convnet(
#   (conv1): Conv2d(1, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(50, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (linear1): Linear(in_features=6400, out_features=100, bias=True)
#   (linear2): Linear(in_features=100, out_features=7, bias=True)
# )
# There are 686407 (0.69 million) parameters in this neural network
# epoch= 1 	 time= 0.15087319612503053 min 	 lr= 0.25 	 loss= 1.934810633659363 	 error= 81.92000102996826 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 2 	 time= 0.31600950558980306 min 	 lr= 0.25 	 loss= 1.9305361032485961 	 error= 81.12000036239624 percent
# error rate on test set = 79.88888820012411 percent
#
# epoch= 3 	 time= 0.4836360772450765 min 	 lr= 0.25 	 loss= 1.9260465669631959 	 error= 80.28000068664551 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 4 	 time= 0.650538170337677 min 	 lr= 0.25 	 loss= 1.921759181022644 	 error= 80.4400007724762 percent
# error rate on test set = 82.33333428700766 percent
#
# epoch= 5 	 time= 0.8153952995936076 min 	 lr= 0.25 	 loss= 1.913068356513977 	 error= 78.58000040054321 percent
# error rate on test set = 82.66666730244955 percent
#
# epoch= 6 	 time= 0.9824853976567586 min 	 lr= 0.25 	 loss= 1.8985695123672486 	 error= 77.82000064849854 percent
# error rate on test set = 85.83333293596903 percent
#
# epoch= 7 	 time= 1.1464266816775004 min 	 lr= 0.25 	 loss= 1.8867949008941651 	 error= 77.9400007724762 percent
# error rate on test set = 82.8333338101705 percent
#
# epoch= 8 	 time= 1.315006419022878 min 	 lr= 0.25 	 loss= 1.885652732849121 	 error= 76.06000089645386 percent
# error rate on test set = 72.40908940633139 percent
#
# epoch= 9 	 time= 1.4771605610847474 min 	 lr= 0.25 	 loss= 1.8532274961471558 	 error= 75.18000078201294 percent
# error rate on test set = 78.28787962595621 percent
#
# epoch= 10 	 time= 1.6398229161898294 min 	 lr= 0.25 	 loss= 1.8484135580062866 	 error= 73.58000183105469 percent
# error rate on test set = 70.09595831235251 percent
#
# epoch= 11 	 time= 1.8062163670857747 min 	 lr= 0.25 	 loss= 1.8161712074279786 	 error= 73.00000143051147 percent
# error rate on test set = 70.65151333808899 percent
#
# epoch= 12 	 time= 1.971547019481659 min 	 lr= 0.25 	 loss= 1.782109832763672 	 error= 71.54000210762024 percent
# error rate on test set = 74.67676599820456 percent
#
# epoch= 13 	 time= 2.1379254420598346 min 	 lr= 0.25 	 loss= 1.7852195310592651 	 error= 71.4000015258789 percent
# error rate on test set = 70.74242432912192 percent
#
# epoch= 14 	 time= 2.2982689778010053 min 	 lr= 0.25 	 loss= 1.7638995504379273 	 error= 70.44000172615051 percent
# error rate on test set = 69.28282777468362 percent
#
# epoch= 15 	 time= 2.4626178542772927 min 	 lr= 0.25 	 loss= 1.7519970083236693 	 error= 70.50000095367432 percent
# error rate on test set = 70.7626243432363 percent
#
# epoch= 16 	 time= 2.6289611498514813 min 	 lr= 0.25 	 loss= 1.7213744401931763 	 error= 67.8600013256073 percent
# error rate on test set = 67.92424321174622 percent
#
# epoch= 17 	 time= 2.790662205219269 min 	 lr= 0.25 	 loss= 1.7191144323349 	 error= 67.46000075340271 percent
# error rate on test set = 68.2121217250824 percent
#
# epoch= 18 	 time= 2.9529184182484944 min 	 lr= 0.25 	 loss= 1.7191572761535645 	 error= 67.40000009536743 percent
# error rate on test set = 69.68181729316711 percent
#
# epoch= 19 	 time= 3.11552525361379 min 	 lr= 0.25 	 loss= 1.7164501810073853 	 error= 68.44000029563904 percent
# error rate on test set = 71.55555287996927 percent
#
# epoch= 20 	 time= 3.274987800916036 min 	 lr= 0.25 	 loss= 1.7856848955154419 	 error= 70.52000045776367 percent
# error rate on test set = 66.35353565216064 percent
#
# epoch= 21 	 time= 3.4367295622825624 min 	 lr= 0.25 	 loss= 1.6881933546066283 	 error= 66.25999975204468 percent
# error rate on test set = 67.91919072469076 percent
#
# epoch= 22 	 time= 3.6017524878184 min 	 lr= 0.25 	 loss= 1.6628790140151977 	 error= 64.46000051498413 percent
# error rate on test set = 70.14646728833517 percent
#
# epoch= 23 	 time= 3.766929058233897 min 	 lr= 0.25 	 loss= 1.643056435585022 	 error= 64.61999988555908 percent
# error rate on test set = 70.08081078529358 percent
#
# epoch= 24 	 time= 3.9288139899571735 min 	 lr= 0.25 	 loss= 1.644007534980774 	 error= 63.46000027656555 percent
# error rate on test set = 76.4242430528005 percent
#
# epoch= 25 	 time= 4.092808036009471 min 	 lr= 0.25 	 loss= 1.6832970142364503 	 error= 66.20000100135803 percent
# error rate on test set = 70.72222034136453 percent
#
# epoch= 26 	 time= 4.258972942829132 min 	 lr= 0.25 	 loss= 1.6081014347076417 	 error= 61.58000087738037 percent
# error rate on test set = 64.70706860224405 percent
#
# epoch= 27 	 time= 4.422168076038361 min 	 lr= 0.25 	 loss= 1.5938688325881958 	 error= 61.120001554489136 percent
# error rate on test set = 69.55050428708395 percent
#
# epoch= 28 	 time= 4.583516176541647 min 	 lr= 0.25 	 loss= 1.6154111814498902 	 error= 62.840001106262214 percent
# error rate on test set = 61.59596045811971 percent
#
# epoch= 29 	 time= 4.747304936250051 min 	 lr= 0.25 	 loss= 1.572250919342041 	 error= 60.02000141143798 percent
# error rate on test set = 63.23232253392538 percent
#
# epoch= 30 	 time= 4.918076161543528 min 	 lr= 0.25 	 loss= 1.5681184864044189 	 error= 61.120001554489136 percent
# error rate on test set = 66.99495116869608 percent
#
# epoch= 31 	 time= 5.081987555821737 min 	 lr= 0.25 	 loss= 1.5674483060836792 	 error= 60.1200008392334 percent
# error rate on test set = 63.16666603088379 percent
#
# epoch= 32 	 time= 5.245985694726309 min 	 lr= 0.25 	 loss= 1.5235548496246338 	 error= 57.80000185966492 percent
# error rate on test set = 66.8838381767273 percent
#
# epoch= 33 	 time= 5.4088044683138525 min 	 lr= 0.25 	 loss= 1.5506034040451049 	 error= 59.56000161170959 percent
# error rate on test set = 65.82828362782797 percent
#
# epoch= 34 	 time= 5.575379228591919 min 	 lr= 0.25 	 loss= 1.5346549367904663 	 error= 58.76000046730041 percent
# error rate on test set = 78.29293012619019 percent
#
# epoch= 35 	 time= 5.737948008378347 min 	 lr= 0.25 	 loss= 1.6864191246032716 	 error= 64.62000060081482 percent
# error rate on test set = 60.919191439946495 percent
#
# epoch= 36 	 time= 5.903605242570241 min 	 lr= 0.25 	 loss= 1.5593290615081787 	 error= 60.18000173568726 percent
# error rate on test set = 67.63636271158853 percent
#
# epoch= 37 	 time= 6.069777397314708 min 	 lr= 0.25 	 loss= 1.5340610313415528 	 error= 59.300002098083496 percent
# error rate on test set = 61.883838971455894 percent
#
# epoch= 38 	 time= 6.228264204661051 min 	 lr= 0.25 	 loss= 1.5129077672958373 	 error= 58.080000400543206 percent
# error rate on test set = 57.166667779286705 percent
#
# epoch= 39 	 time= 6.391256527105967 min 	 lr= 0.25 	 loss= 1.4801691007614135 	 error= 57.06000113487244 percent
# error rate on test set = 61.94444497426351 percent
#
# epoch= 40 	 time= 6.554605158170064 min 	 lr= 0.25 	 loss= 1.499318733215332 	 error= 57.68000149726868 percent
# error rate on test set = 63.03535302480062 percent
#
# epoch= 41 	 time= 6.719374855359395 min 	 lr= 0.25 	 loss= 1.504741725921631 	 error= 57.440000057220466 percent
# error rate on test set = 61.34848197301229 percent
#
# epoch= 42 	 time= 6.882735482851664 min 	 lr= 0.25 	 loss= 1.4648035335540772 	 error= 55.36000084877014 percent
# error rate on test set = 67.12626417477927 percent
#
# epoch= 43 	 time= 7.042220342159271 min 	 lr= 0.25 	 loss= 1.4800250768661498 	 error= 56.78000092506409 percent
# error rate on test set = 60.52525242169698 percent
#
# epoch= 44 	 time= 7.205502061049144 min 	 lr= 0.25 	 loss= 1.4339367723464966 	 error= 53.96000051498413 percent
# error rate on test set = 64.22222256660461 percent
#
# epoch= 45 	 time= 7.369499512513479 min 	 lr= 0.25 	 loss= 1.4409013175964356 	 error= 55.040000438690186 percent
# error rate on test set = 64.38888907432556 percent
#
# epoch= 46 	 time= 7.534369218349457 min 	 lr= 0.25 	 loss= 1.4418990802764893 	 error= 54.06000137329101 percent
# error rate on test set = 62.318180004755654 percent
#
# epoch= 47 	 time= 7.694334455331167 min 	 lr= 0.25 	 loss= 1.4209367895126344 	 error= 53.480000257492065 percent
# error rate on test set = 59.69697038332621 percent
#
# epoch= 48 	 time= 7.856507563591004 min 	 lr= 0.25 	 loss= 1.3992916965484619 	 error= 52.40000057220458 percent
# error rate on test set = 58.4343413511912 percent
#
# epoch= 49 	 time= 8.020536681016287 min 	 lr= 0.25 	 loss= 1.411686749458313 	 error= 52.079999923706055 percent
# error rate on test set = 74.94949499766031 percent
#
# epoch= 50 	 time= 8.181105109055837 min 	 lr= 0.16666666666666666 	 loss= 1.5199044179916381 	 error= 56.34000110626221 percent
# error rate on test set = 57.41919279098511 percent
#
# epoch= 51 	 time= 8.34955490430196 min 	 lr= 0.16666666666666666 	 loss= 1.3535593605041505 	 error= 50.100001096725464 percent
# error rate on test set = 57.272728284200035 percent
#
# epoch= 52 	 time= 8.512121482690175 min 	 lr= 0.16666666666666666 	 loss= 1.3570650911331177 	 error= 50.08000016212464 percent
# error rate on test set = 61.227271954218544 percent
#
# epoch= 53 	 time= 8.673987444241842 min 	 lr= 0.16666666666666666 	 loss= 1.3559641456604004 	 error= 50.9200005531311 percent
# error rate on test set = 55.41414419809977 percent
#
# epoch= 54 	 time= 8.836037230491637 min 	 lr= 0.16666666666666666 	 loss= 1.329476499557495 	 error= 48.50000071525574 percent
# error rate on test set = 58.116161823272705 percent
#
# epoch= 55 	 time= 9.003407661120097 min 	 lr= 0.16666666666666666 	 loss= 1.3325066900253295 	 error= 49.540000200271606 percent
# error rate on test set = 57.56060679753622 percent
#
# epoch= 56 	 time= 9.166419271628062 min 	 lr= 0.16666666666666666 	 loss= 1.310464949607849 	 error= 48.26000094413757 percent
# error rate on test set = 54.60100769996643 percent
#
# epoch= 57 	 time= 9.330129865805308 min 	 lr= 0.16666666666666666 	 loss= 1.3033470249176025 	 error= 48.60000038146973 percent
# error rate on test set = 64.8888885974884 percent
#
# epoch= 58 	 time= 9.49577632745107 min 	 lr= 0.16666666666666666 	 loss= 1.3113344955444335 	 error= 48.44000053405762 percent
# error rate on test set = 58.09595783551534 percent
#
# epoch= 59 	 time= 9.662787703673045 min 	 lr= 0.16666666666666666 	 loss= 1.3056660842895509 	 error= 49.22000074386597 percent
# error rate on test set = 59.616162379582725 percent
#
# epoch= 60 	 time= 9.822722589969635 min 	 lr= 0.16666666666666666 	 loss= 1.2799755620956421 	 error= 47.96000051498413 percent
# error rate on test set = 54.57575718561808 percent
#
# epoch= 61 	 time= 9.983814819653828 min 	 lr= 0.16666666666666666 	 loss= 1.2867178726196289 	 error= 47.480000734329224 percent
# error rate on test set = 63.9242430528005 percent
#
# epoch= 62 	 time= 10.146216475963593 min 	 lr= 0.16666666666666666 	 loss= 1.3417320823669434 	 error= 50.040000200271606 percent
# error rate on test set = 63.121211528778076 percent
#
# epoch= 63 	 time= 10.311554177602131 min 	 lr= 0.16666666666666666 	 loss= 1.2826851844787597 	 error= 47.660000801086426 percent
# error rate on test set = 60.98484992980957 percent
#
# epoch= 64 	 time= 10.475427758693694 min 	 lr= 0.16666666666666666 	 loss= 1.2603945350646972 	 error= 46.46000027656555 percent
# error rate on test set = 52.25252707799276 percent
#
# epoch= 65 	 time= 10.639829337596893 min 	 lr= 0.16666666666666666 	 loss= 1.2760732221603392 	 error= 47.32000112533569 percent
# error rate on test set = 57.77777830759684 percent
#
# epoch= 66 	 time= 10.802117598056793 min 	 lr= 0.16666666666666666 	 loss= 1.2568885898590088 	 error= 47.22000026702881 percent
# error rate on test set = 53.065655628840126 percent
#
# epoch= 67 	 time= 10.96408632993698 min 	 lr= 0.16666666666666666 	 loss= 1.2593140935897826 	 error= 46.44000029563904 percent
# error rate on test set = 57.34848380088806 percent
#
# epoch= 68 	 time= 11.12622484366099 min 	 lr= 0.16666666666666666 	 loss= 1.2383352375030519 	 error= 46.18000030517578 percent
# error rate on test set = 55.48989772796631 percent
#
# epoch= 69 	 time= 11.28885771036148 min 	 lr= 0.16666666666666666 	 loss= 1.223768265247345 	 error= 44.58000087738037 percent
# error rate on test set = 53.5757581392924 percent
#
# epoch= 70 	 time= 11.450867406527202 min 	 lr= 0.16666666666666666 	 loss= 1.2273680353164673 	 error= 45.1200008392334 percent
# error rate on test set = 60.33333341280619 percent
#
# epoch= 71 	 time= 11.613845507303873 min 	 lr= 0.16666666666666666 	 loss= 1.2358907270431518 	 error= 46.220000982284546 percent
# error rate on test set = 58.50000182787577 percent
#
# epoch= 72 	 time= 11.778959866364797 min 	 lr= 0.16666666666666666 	 loss= 1.2294418573379517 	 error= 45.6200008392334 percent
# error rate on test set = 58.80302985509237 percent
#
# epoch= 73 	 time= 11.941055913766226 min 	 lr= 0.16666666666666666 	 loss= 1.209573426246643 	 error= 44.78000092506409 percent
# error rate on test set = 54.348484675089516 percent
#
# epoch= 74 	 time= 12.101700246334076 min 	 lr= 0.16666666666666666 	 loss= 1.195125150680542 	 error= 44.06000113487244 percent
# error rate on test set = 53.54545513788859 percent
#
# epoch= 75 	 time= 12.26960693995158 min 	 lr= 0.16666666666666666 	 loss= 1.1874753999710084 	 error= 43.820000886917114 percent
# error rate on test set = 51.66666507720947 percent
#
# epoch= 76 	 time= 12.434623110294343 min 	 lr= 0.16666666666666666 	 loss= 1.1913417530059816 	 error= 44.160001277923584 percent
# error rate on test set = 56.040406227111816 percent
#
# epoch= 77 	 time= 12.604785247643788 min 	 lr= 0.16666666666666666 	 loss= 1.1873372197151184 	 error= 42.840001344680786 percent
# error rate on test set = 69.06565626462302 percent
#
# epoch= 78 	 time= 12.764948479334514 min 	 lr= 0.16666666666666666 	 loss= 1.3536253356933594 	 error= 50.00000071525573 percent
# error rate on test set = 57.35353628794352 percent
#
# epoch= 79 	 time= 12.919871191183725 min 	 lr= 0.16666666666666666 	 loss= 1.2008526992797852 	 error= 43.90000128746033 percent
# error rate on test set = 59.22727386156718 percent
#
# epoch= 80 	 time= 13.084023356437683 min 	 lr= 0.16666666666666666 	 loss= 1.180881505012512 	 error= 43.380000829696655 percent
# error rate on test set = 55.131312211354576 percent
#
# epoch= 81 	 time= 13.248700030644734 min 	 lr= 0.16666666666666666 	 loss= 1.1533852910995483 	 error= 42.64000105857849 percent
# error rate on test set = 55.47979871431986 percent
#
# epoch= 82 	 time= 13.41207461754481 min 	 lr= 0.16666666666666666 	 loss= 1.1460387587547303 	 error= 42.20000123977661 percent
# error rate on test set = 56.479797760645546 percent
#
# epoch= 83 	 time= 13.579006389776866 min 	 lr= 0.16666666666666666 	 loss= 1.1774941110610961 	 error= 42.940001010894775 percent
# error rate on test set = 54.23737366994222 percent
#
# epoch= 84 	 time= 13.741780563195546 min 	 lr= 0.16666666666666666 	 loss= 1.1395744180679321 	 error= 41.220001220703125 percent
# error rate on test set = 60.424242417017616 percent
#
# epoch= 85 	 time= 13.902385826905569 min 	 lr= 0.16666666666666666 	 loss= 1.1659592294692993 	 error= 42.80000138282776 percent
# error rate on test set = 58.61616134643555 percent
#
# epoch= 86 	 time= 14.068999524911245 min 	 lr= 0.16666666666666666 	 loss= 1.1346715927124023 	 error= 42.160000801086426 percent
# error rate on test set = 58.62121184666952 percent
#
# epoch= 87 	 time= 14.232567969957987 min 	 lr= 0.16666666666666666 	 loss= 1.1362488079071045 	 error= 41.480000495910645 percent
# error rate on test set = 61.36868794759115 percent
#
# epoch= 88 	 time= 14.396751324335733 min 	 lr= 0.16666666666666666 	 loss= 1.1410761761665345 	 error= 41.70000100135803 percent
# error rate on test set = 68.07576020558676 percent
#
# epoch= 89 	 time= 14.559155853589376 min 	 lr= 0.16666666666666666 	 loss= 1.2023291110992431 	 error= 43.90000128746033 percent
# error rate on test set = 58.26262633005778 percent
#
# epoch= 90 	 time= 14.723652942975361 min 	 lr= 0.16666666666666666 	 loss= 1.0872144508361816 	 error= 39.960001707077026 percent
# error rate on test set = 56.78282777468363 percent
#
# epoch= 91 	 time= 14.887883333365123 min 	 lr= 0.16666666666666666 	 loss= 1.112822756767273 	 error= 40.660001277923584 percent
# error rate on test set = 50.979799032211304 percent
#
# epoch= 92 	 time= 15.055081001917522 min 	 lr= 0.16666666666666666 	 loss= 1.0792031860351563 	 error= 39.780001401901245 percent
# error rate on test set = 57.00000127156576 percent
#
# epoch= 93 	 time= 15.219202156861623 min 	 lr= 0.16666666666666666 	 loss= 1.0808838295936585 	 error= 39.92000126838684 percent
# error rate on test set = 57.262625296910606 percent
#
# epoch= 94 	 time= 15.383158334096272 min 	 lr= 0.16666666666666666 	 loss= 1.0994605827331543 	 error= 39.64000201225281 percent
# error rate on test set = 55.161615212758385 percent
#
# epoch= 95 	 time= 15.548146625359854 min 	 lr= 0.16666666666666666 	 loss= 1.0835905742645264 	 error= 39.0400013923645 percent
# error rate on test set = 53.828285137812294 percent
#
# epoch= 96 	 time= 15.708089236418406 min 	 lr= 0.16666666666666666 	 loss= 1.0751266980171204 	 error= 38.500001430511475 percent
# error rate on test set = 53.15151413281759 percent
#
# epoch= 97 	 time= 15.866550262769064 min 	 lr= 0.16666666666666666 	 loss= 1.052855796813965 	 error= 38.60000133514404 percent
# error rate on test set = 58.3686888217926 percent
#
# epoch= 98 	 time= 16.026325885454813 min 	 lr= 0.16666666666666666 	 loss= 1.0446823477745055 	 error= 38.68000102043152 percent
# error rate on test set = 57.474746306737266 percent
#
# epoch= 99 	 time= 16.19225794871648 min 	 lr= 0.16666666666666666 	 loss= 1.0613642382621764 	 error= 38.380001068115234 percent
# error rate on test set = 61.88888947168986 percent
#
# epoch= 100 	 time= 16.35437356233597 min 	 lr= 0.1111111111111111 	 loss= 1.0528757977485657 	 error= 37.340001821517944 percent
# error rate on test set = 55.772727727890015 percent
#
# epoch= 101 	 time= 16.516359694798787 min 	 lr= 0.1111111111111111 	 loss= 0.9894210934638977 	 error= 36.24000144004822 percent
# error rate on test set = 51.823232571283974 percent
#
# epoch= 102 	 time= 16.67968394756317 min 	 lr= 0.1111111111111111 	 loss= 0.9754458689689636 	 error= 35.60000157356262 percent
# error rate on test set = 53.58080863952637 percent
#
# epoch= 103 	 time= 16.847513675689697 min 	 lr= 0.1111111111111111 	 loss= 0.9815135359764099 	 error= 34.48000144958496 percent
# error rate on test set = 56.44949674606323 percent
#
# epoch= 104 	 time= 17.00992296934128 min 	 lr= 0.1111111111111111 	 loss= 0.9834255790710449 	 error= 34.780001163482666 percent
# error rate on test set = 52.62121558189392 percent
#
# epoch= 105 	 time= 17.173268810908 min 	 lr= 0.1111111111111111 	 loss= 0.976791639328003 	 error= 35.70000123977661 percent
# error rate on test set = 51.106059551239014 percent
#
# epoch= 106 	 time= 17.3364089012146 min 	 lr= 0.1111111111111111 	 loss= 0.9633891868591309 	 error= 33.92000079154968 percent
# error rate on test set = 51.636362075805664 percent
#
# epoch= 107 	 time= 17.500600695610046 min 	 lr= 0.1111111111111111 	 loss= 0.9707563138008117 	 error= 34.38000154495239 percent
# error rate on test set = 57.156564791997276 percent
#
# epoch= 108 	 time= 17.665161550045013 min 	 lr= 0.1111111111111111 	 loss= 0.9611264777183532 	 error= 34.52000164985657 percent
# error rate on test set = 62.257577975591026 percent
#
# epoch= 109 	 time= 17.83232302268346 min 	 lr= 0.1111111111111111 	 loss= 0.9701097130775451 	 error= 34.88000130653381 percent
# error rate on test set = 54.878787199656166 percent
#
# epoch= 110 	 time= 17.989900529384613 min 	 lr= 0.1111111111111111 	 loss= 0.9541004776954651 	 error= 34.14000058174133 percent
# error rate on test set = 50.42929251988729 percent
#
# epoch= 111 	 time= 18.15231580734253 min 	 lr= 0.1111111111111111 	 loss= 0.920613009929657 	 error= 33.38000202178955 percent
# error rate on test set = 52.43434111277262 percent
#
# epoch= 112 	 time= 18.31264049609502 min 	 lr= 0.1111111111111111 	 loss= 0.909241168498993 	 error= 32.66000175476074 percent
# error rate on test set = 54.601009686787926 percent
#
# epoch= 113 	 time= 18.47564138174057 min 	 lr= 0.1111111111111111 	 loss= 0.9365872955322265 	 error= 33.80000162124634 percent
# error rate on test set = 51.49495005607605 percent
#
# epoch= 114 	 time= 18.64356761376063 min 	 lr= 0.1111111111111111 	 loss= 0.9064489531517029 	 error= 32.94000196456909 percent
# error rate on test set = 56.621211767196655 percent
#
# epoch= 115 	 time= 18.805627445379894 min 	 lr= 0.1111111111111111 	 loss= 0.923914999961853 	 error= 33.6000018119812 percent
# error rate on test set = 53.89899214108785 percent
#
# epoch= 116 	 time= 18.973658696810404 min 	 lr= 0.1111111111111111 	 loss= 0.898657648563385 	 error= 32.680001974105835 percent
# error rate on test set = 54.79798118273417 percent
#
# epoch= 117 	 time= 19.133814028898875 min 	 lr= 0.1111111111111111 	 loss= 0.9015877294540405 	 error= 32.86000108718872 percent
# error rate on test set = 51.7575740814209 percent
#
# epoch= 118 	 time= 19.296972382068635 min 	 lr= 0.1111111111111111 	 loss= 0.900524549484253 	 error= 32.500001668930054 percent
# error rate on test set = 53.343433141708374 percent
#
# epoch= 119 	 time= 19.461322903633118 min 	 lr= 0.1111111111111111 	 loss= 0.8934166359901429 	 error= 32.36000204086304 percent
# error rate on test set = 62.96969652175903 percent
#
# epoch= 120 	 time= 19.624332559108733 min 	 lr= 0.1111111111111111 	 loss= 0.8997036790847779 	 error= 31.500001907348636 percent
# error rate on test set = 50.91919302940369 percent
#
# epoch= 121 	 time= 19.787864700953165 min 	 lr= 0.1111111111111111 	 loss= 0.8812582278251648 	 error= 31.020001173019406 percent
# error rate on test set = 54.67171867688497 percent
#
# epoch= 122 	 time= 19.95421073039373 min 	 lr= 0.1111111111111111 	 loss= 0.8707608723640442 	 error= 30.300001621246338 percent
# error rate on test set = 54.74242170651754 percent
#
# epoch= 123 	 time= 20.115124837557474 min 	 lr= 0.1111111111111111 	 loss= 0.8952341389656067 	 error= 31.820001840591434 percent
# error rate on test set = 54.666666189829506 percent
#
# epoch= 124 	 time= 20.276589024066926 min 	 lr= 0.1111111111111111 	 loss= 0.8702341890335084 	 error= 31.280001640319828 percent
# error rate on test set = 54.590908686319985 percent
#
# epoch= 125 	 time= 20.440062101682027 min 	 lr= 0.1111111111111111 	 loss= 0.867263445854187 	 error= 30.520002365112305 percent
# error rate on test set = 52.42424011230469 percent
#
# epoch= 126 	 time= 20.60515450636546 min 	 lr= 0.1111111111111111 	 loss= 0.8561843776702881 	 error= 31.180001735687256 percent
# error rate on test set = 61.96969747543335 percent
#
# epoch= 127 	 time= 20.77585590283076 min 	 lr= 0.1111111111111111 	 loss= 0.8753172159194946 	 error= 31.28000140190125 percent
# error rate on test set = 51.01515054702759 percent
#
# epoch= 128 	 time= 20.939539349079134 min 	 lr= 0.1111111111111111 	 loss= 0.8559420347213745 	 error= 29.880001306533817 percent
# error rate on test set = 54.227274656295776 percent
#
# epoch= 129 	 time= 21.105988001823427 min 	 lr= 0.1111111111111111 	 loss= 0.8644506931304932 	 error= 30.54000163078308 percent
# error rate on test set = 52.39394108454386 percent
#
# epoch= 130 	 time= 21.272004556655883 min 	 lr= 0.1111111111111111 	 loss= 0.816403546333313 	 error= 28.740001916885376 percent
# error rate on test set = 52.33838359514872 percent
#
# epoch= 131 	 time= 21.444034377733868 min 	 lr= 0.1111111111111111 	 loss= 0.8584092736244202 	 error= 30.58000159263611 percent
# error rate on test set = 52.47979760169983 percent
#
# epoch= 132 	 time= 21.607271536191305 min 	 lr= 0.1111111111111111 	 loss= 0.8438119792938232 	 error= 29.880001783370975 percent
# error rate on test set = 55.631313721338906 percent
#
# epoch= 133 	 time= 21.7742023507754 min 	 lr= 0.1111111111111111 	 loss= 0.8206406593322754 	 error= 30.66000127792358 percent
# error rate on test set = 52.393939097722374 percent
#
# epoch= 134 	 time= 21.942383797963462 min 	 lr= 0.1111111111111111 	 loss= 0.8043619060516357 	 error= 28.920002222061157 percent
# error rate on test set = 52.83838510513306 percent
#
# epoch= 135 	 time= 22.11331572930018 min 	 lr= 0.1111111111111111 	 loss= 0.7975063562393189 	 error= 29.040001392364502 percent
# error rate on test set = 50.42424201965332 percent
#
# epoch= 136 	 time= 22.278402241071067 min 	 lr= 0.1111111111111111 	 loss= 0.7990319657325745 	 error= 27.900001525878903 percent
# error rate on test set = 53.27777862548828 percent
#
# epoch= 137 	 time= 22.43996910651525 min 	 lr= 0.1111111111111111 	 loss= 0.7899906086921692 	 error= 27.72000169754028 percent
# error rate on test set = 54.86363569895426 percent
#
# epoch= 138 	 time= 22.61140598853429 min 	 lr= 0.1111111111111111 	 loss= 0.8184543132781983 	 error= 29.02000141143799 percent
# error rate on test set = 53.07575662930807 percent
#
# epoch= 139 	 time= 22.77548031806946 min 	 lr= 0.1111111111111111 	 loss= 0.7853566932678223 	 error= 27.520001888275146 percent
# error rate on test set = 57.580808798472084 percent
#
# epoch= 140 	 time= 22.93580878575643 min 	 lr= 0.1111111111111111 	 loss= 0.7972813153266907 	 error= 27.860001087188717 percent
# error rate on test set = 50.25757551193237 percent
#
# epoch= 141 	 time= 23.10048515399297 min 	 lr= 0.1111111111111111 	 loss= 0.7764147400856019 	 error= 26.92000150680542 percent
# error rate on test set = 61.15151643753052 percent
#
# epoch= 142 	 time= 23.26310575803121 min 	 lr= 0.1111111111111111 	 loss= 0.7783326363563537 	 error= 27.560001373291016 percent
# error rate on test set = 56.37878974278768 percent
#
# epoch= 143 	 time= 23.426969758669536 min 	 lr= 0.1111111111111111 	 loss= 0.7601225733757019 	 error= 26.88000178337097 percent
# error rate on test set = 49.63131149609883 percent
#
# epoch= 144 	 time= 23.5879242738088 min 	 lr= 0.1111111111111111 	 loss= 0.7462451481819152 	 error= 26.90000152587891 percent
# error rate on test set = 49.676765998204544 percent
#
# epoch= 145 	 time= 23.754674220085143 min 	 lr= 0.1111111111111111 	 loss= 0.7595895910263062 	 error= 26.540001630783085 percent
# error rate on test set = 55.04040519396464 percent
#
# epoch= 146 	 time= 23.9213725288709 min 	 lr= 0.1111111111111111 	 loss= 0.756498041152954 	 error= 26.040002107620243 percent
# error rate on test set = 56.60606026649475 percent
#
# epoch= 147 	 time= 24.083014170328777 min 	 lr= 0.1111111111111111 	 loss= 0.7995881772041321 	 error= 27.940001964569095 percent
# error rate on test set = 48.41919143994649 percent
#
# epoch= 148 	 time= 24.246664293607076 min 	 lr= 0.1111111111111111 	 loss= 0.7222570562362671 	 error= 25.000001430511475 percent
# error rate on test set = 53.51009964942932 percent
#
# epoch= 149 	 time= 24.408845885594687 min 	 lr= 0.1111111111111111 	 loss= 0.7463790702819825 	 error= 26.340001583099365 percent
# error rate on test set = 53.151516119639076 percent
#
# epoch= 150 	 time= 24.576380940278373 min 	 lr= 0.07407407407407407 	 loss= 0.6744640922546387 	 error= 23.440001726150513 percent
# error rate on test set = 50.74242353439331 percent
#
# epoch= 151 	 time= 24.74501885175705 min 	 lr= 0.07407407407407407 	 loss= 0.6527680230140686 	 error= 22.8600013256073 percent
# error rate on test set = 51.085859537124634 percent
#
# epoch= 152 	 time= 24.929385654131572 min 	 lr= 0.07407407407407407 	 loss= 0.6697507405281067 	 error= 22.900002241134644 percent
# error rate on test set = 49.56565499305725 percent
#
# epoch= 153 	 time= 25.10061309337616 min 	 lr= 0.07407407407407407 	 loss= 0.6740331554412842 	 error= 23.120002508163452 percent
# error rate on test set = 56.86868826548258 percent
#
# epoch= 154 	 time= 25.283457565307618 min 	 lr= 0.07407407407407407 	 loss= 0.6553683030605316 	 error= 23.080002307891846 percent
# error rate on test set = 48.83333444595337 percent
#
# epoch= 155 	 time= 25.463029535611472 min 	 lr= 0.07407407407407407 	 loss= 0.6529798793792725 	 error= 22.960001945495605 percent
# error rate on test set = 56.691918770472206 percent
#
# epoch= 156 	 time= 25.64108234246572 min 	 lr= 0.07407407407407407 	 loss= 0.644132227897644 	 error= 23.000002145767212 percent
# error rate on test set = 52.33333309491476 percent
#
# epoch= 157 	 time= 25.82282203435898 min 	 lr= 0.07407407407407407 	 loss= 0.6324408912658691 	 error= 21.780001640319824 percent
# error rate on test set = 51.570705572764076 percent
#
# epoch= 158 	 time= 26.003456036249798 min 	 lr= 0.07407407407407407 	 loss= 0.6292057871818543 	 error= 22.840001583099365 percent
# error rate on test set = 49.17171796162923 percent
#
# epoch= 159 	 time= 26.188056834538777 min 	 lr= 0.07407407407407407 	 loss= 0.6320410752296448 	 error= 22.140002012252808 percent
# error rate on test set = 55.14141321182251 percent
#
# epoch= 160 	 time= 26.348753416538237 min 	 lr= 0.07407407407407407 	 loss= 0.6450482749938965 	 error= 22.180002212524414 percent
# error rate on test set = 51.26262505849203 percent
#
# epoch= 161 	 time= 26.513059961795808 min 	 lr= 0.07407407407407407 	 loss= 0.6553994250297547 	 error= 22.54000186920166 percent
# error rate on test set = 52.757577101389565 percent
#
# epoch= 162 	 time= 26.67866874138514 min 	 lr= 0.07407407407407407 	 loss= 0.6145461273193359 	 error= 22.28000235557556 percent
# error rate on test set = 51.66161855061849 percent
#
# epoch= 163 	 time= 26.84076416095098 min 	 lr= 0.07407407407407407 	 loss= 0.6295632290840149 	 error= 22.38000178337097 percent
# error rate on test set = 48.72727394104004 percent
#
# epoch= 164 	 time= 27.00416601896286 min 	 lr= 0.07407407407407407 	 loss= 0.6111897575855255 	 error= 22.08000159263611 percent
# error rate on test set = 51.23737255732218 percent
#
# epoch= 165 	 time= 27.16979292233785 min 	 lr= 0.07407407407407407 	 loss= 0.6123008632659912 	 error= 21.500001430511475 percent
# error rate on test set = 52.924241622289024 percent
#
# epoch= 166 	 time= 27.331647360324858 min 	 lr= 0.07407407407407407 	 loss= 0.6230600929260254 	 error= 21.420001983642578 percent
# error rate on test set = 49.919191996256515 percent
#
# epoch= 167 	 time= 27.495675853888194 min 	 lr= 0.07407407407407407 	 loss= 0.6196236419677734 	 error= 21.620001792907715 percent
# error rate on test set = 49.570705493291214 percent
#
# epoch= 168 	 time= 27.663580298423767 min 	 lr= 0.07407407407407407 	 loss= 0.5892822873592377 	 error= 20.560002326965332 percent
# error rate on test set = 53.762624661127724 percent
#
# epoch= 169 	 time= 27.82864768107732 min 	 lr= 0.07407407407407407 	 loss= 0.601740425825119 	 error= 20.620002269744873 percent
# error rate on test set = 53.07575662930807 percent
#
# epoch= 170 	 time= 27.989813963572185 min 	 lr= 0.07407407407407407 	 loss= 0.6146472537517548 	 error= 22.1600022315979 percent
# error rate on test set = 51.085859537124634 percent
#
# epoch= 171 	 time= 28.156214356422424 min 	 lr= 0.07407407407407407 	 loss= 0.5924907815456391 	 error= 20.340002059936523 percent
# error rate on test set = 53.136362632115684 percent
#
# epoch= 172 	 time= 28.327485259373983 min 	 lr= 0.07407407407407407 	 loss= 0.5795073509216309 	 error= 20.04000210762024 percent
# error rate on test set = 52.010101079940796 percent
#
# epoch= 173 	 time= 28.49199335972468 min 	 lr= 0.07407407407407407 	 loss= 0.5561697673797608 	 error= 19.800002574920654 percent
# error rate on test set = 51.166667540868126 percent
#
# epoch= 174 	 time= 28.652279464403787 min 	 lr= 0.07407407407407407 	 loss= 0.5683351540565491 	 error= 19.360002040863037 percent
# error rate on test set = 47.999999920527145 percent
#
# epoch= 175 	 time= 28.815568327903748 min 	 lr= 0.07407407407407407 	 loss= 0.5670591926574707 	 error= 19.300002098083496 percent
# error rate on test set = 53.90403866767883 percent
#
# epoch= 176 	 time= 28.976440366109212 min 	 lr= 0.07407407407407407 	 loss= 0.5970349156856537 	 error= 19.920001745224 percent
# error rate on test set = 49.66161648432414 percent
#
# epoch= 177 	 time= 29.140170085430146 min 	 lr= 0.07407407407407407 	 loss= 0.564990930557251 	 error= 20.060001373291016 percent
# error rate on test set = 49.5101014773051 percent
#
# epoch= 178 	 time= 29.30481003522873 min 	 lr= 0.07407407407407407 	 loss= 0.5738470530509949 	 error= 20.400001525878906 percent
# error rate on test set = 57.09595878918966 percent
#
# epoch= 179 	 time= 29.471557831764223 min 	 lr= 0.07407407407407407 	 loss= 0.6057642269134521 	 error= 21.100001573562622 percent
# error rate on test set = 52.65656510988871 percent
#
# epoch= 180 	 time= 29.633470114072164 min 	 lr= 0.07407407407407407 	 loss= 0.5591923189163208 	 error= 19.120002031326294 percent
# error rate on test set = 48.47474694252014 percent
#
# epoch= 181 	 time= 29.798550764719646 min 	 lr= 0.07407407407407407 	 loss= 0.5405383253097534 	 error= 18.26000213623047 percent
# error rate on test set = 54.484848181406655 percent
#
# epoch= 182 	 time= 29.965824528535208 min 	 lr= 0.07407407407407407 	 loss= 0.5472151923179627 	 error= 18.4800021648407 percent
# error rate on test set = 50.91414054234823 percent
#
# epoch= 183 	 time= 30.131847564379374 min 	 lr= 0.07407407407407407 	 loss= 0.5436817085742951 	 error= 18.54000186920166 percent
# error rate on test set = 54.46969668070475 percent
#
# epoch= 184 	 time= 30.293159651756287 min 	 lr= 0.07407407407407407 	 loss= 0.570456532239914 	 error= 19.300002336502075 percent
# error rate on test set = 51.111110051472984 percent
#
# epoch= 185 	 time= 30.4568274974823 min 	 lr= 0.07407407407407407 	 loss= 0.5171202731132507 	 error= 17.9800021648407 percent
# error rate on test set = 48.15151492754619 percent
#
# epoch= 186 	 time= 30.625325667858124 min 	 lr= 0.07407407407407407 	 loss= 0.5285652256011963 	 error= 18.460001468658447 percent
# error rate on test set = 50.308080514272056 percent
#
# epoch= 187 	 time= 30.78796083132426 min 	 lr= 0.07407407407407407 	 loss= 0.5352977907657623 	 error= 18.26000189781189 percent
# error rate on test set = 48.39898943901062 percent
#
# epoch= 188 	 time= 30.953027808666228 min 	 lr= 0.07407407407407407 	 loss= 0.5529096782207489 	 error= 19.88000178337097 percent
# error rate on test set = 49.97979799906413 percent
#
# epoch= 189 	 time= 31.11078732808431 min 	 lr= 0.07407407407407407 	 loss= 0.5112158942222595 	 error= 17.520001888275146 percent
# error rate on test set = 51.742422580718994 percent
#
# epoch= 190 	 time= 31.272258079051973 min 	 lr= 0.07407407407407407 	 loss= 0.5274069917201996 	 error= 18.60000228881836 percent
# error rate on test set = 59.11111036936442 percent
#
# epoch= 191 	 time= 31.43364752928416 min 	 lr= 0.07407407407407407 	 loss= 0.562606201171875 	 error= 19.020002126693726 percent
# error rate on test set = 50.949496030807495 percent
#
# epoch= 192 	 time= 31.59270900885264 min 	 lr= 0.07407407407407407 	 loss= 0.5266510832309723 	 error= 17.98000192642212 percent
# error rate on test set = 48.489898443222046 percent
#
# epoch= 193 	 time= 31.751327474912006 min 	 lr= 0.07407407407407407 	 loss= 0.497103716135025 	 error= 16.920002222061157 percent
# error rate on test set = 47.4848469098409 percent
#
# epoch= 194 	 time= 31.911749271551766 min 	 lr= 0.07407407407407407 	 loss= 0.4680146920681 	 error= 16.240002155303955 percent
# error rate on test set = 50.2525250116984 percent
#
# epoch= 195 	 time= 32.07329692443212 min 	 lr= 0.07407407407407407 	 loss= 0.4913955461978912 	 error= 17.400001287460327 percent
# error rate on test set = 47.747474908828735 percent
#
# epoch= 196 	 time= 32.23675892750422 min 	 lr= 0.07407407407407407 	 loss= 0.49159247279167173 	 error= 17.08000159263611 percent
# error rate on test set = 50.318179527918495 percent
#
# epoch= 197 	 time= 32.40046283006668 min 	 lr= 0.07407407407407407 	 loss= 0.4985048294067383 	 error= 16.9800021648407 percent
# error rate on test set = 53.722222646077476 percent
#
# epoch= 198 	 time= 32.56689236561457 min 	 lr= 0.07407407407407407 	 loss= 0.5091383922100067 	 error= 17.680002212524414 percent
# error rate on test set = 46.424241860707596 percent
#
# epoch= 199 	 time= 32.72912569443385 min 	 lr= 0.07407407407407407 	 loss= 0.4865493261814117 	 error= 17.000001907348633 percent
# error rate on test set = 48.24242194493611 percent

# %%
torch.save(lenet5_v3.state_dict(), 'trained_models/emotion/lenet5_128_rotate_4x4_reducedLR.pt')

# %% [markdown]
# ## Load Model Weights and Predict

# %%
# Load model and weights
loaded_net=LeNet5_convnet()
loaded_net.load_state_dict(torch.load('trained_models/emotion/lenet5_128_rotate.pt'))
loaded_net.eval()
loaded_net.parameters()
# Out:
# <generator object Module.parameters at 0x7f8e698062d0>

# %%
# choose a picture at random
from random import randint

images, gts = list(iter(valid_dl))[randint(0, 3-1)]

idx=randint(0, images.size()[0]-1)
im = images[idx]
gt = gts[idx]

# diplay the picture
utils.show(im.squeeze(0))

# feed it to the net and display the confidence scores
scores =  loaded_net(im.view(-1, 1, 128, 128)) 
probs = torch.softmax(scores, dim=1)
print(f"True: {gt}, Predicted: {probs.argmax()}")
# Out:
# True: 4, Predicted: 1

# %% [markdown]
# ## Visualisation

# %% [markdown]
# ### Visualise Training Loss, Training Error, Test Error

# %%
def extract(fn):
    loss = []
    error = []
    test_error = []
    with open(fn) as f:
        lines = f.read().splitlines()
    for line in lines:
        if 'epoch=' in line:
            loss.append(float(line.split('loss=')[1].split()[0]))
            error.append(float(line.split('error=')[1].split()[0]))
        elif "error rate on test set =" in line:
            test_error.append(float(line.split("=")[1].split()[0]))

    return loss, error, test_error

# %%
import matplotlib.pyplot as plt
import os

dir = 'trained_models/emotion'
fns = [
       'lenet5_128_rotate',
       'lenet5_128_rotate_4x4',
       'lenet5_128_rotate_4x4_reducedLR',
]
test_error_dict = {}

for fn in fns:
  loss, error, test_error =  extract(os.path.join(dir, f'{fn}.txt'))
  test_error_dict.update({fn: test_error})

  plt.plot(error, '-.', label='training error')
  plt.plot(test_error, '-.', label='test error')
  plt.xlabel('epoch')
  plt.ylabel('training/test error')
  plt.title('error vs. No. of epochs')
  plt.legend()
  plt.savefig(f"{fn}_train_test_error.jpg", dpi=300)
  plt.figure().clear()

# %%
for m_name, test_error in test_error_dict.items():
  plt.plot(test_error, '-.', label=f'{m_name}_test error')
plt.xlabel('epoch')
plt.ylabel('test error')
plt.title('comparison between models')
plt.legend()
plt.savefig(f"comparison_test_error.jpg", dpi=300)

# %% [markdown]
# ### Visualise filter weights and feature maps in each layer

# %%
import matplotlib.pyplot as plt

# Visualize conv1 filter
kernels = loaded_net.conv1.weight.detach()
plt.figure()
for idx in range(kernels.size(0))[:5]:
    plt.subplot(151 + idx)
    plt.imshow(kernels[idx].squeeze(0).cpu(), cmap = 'Greys')
    # plt.imshow(kernels[idx].squeeze(), cmap = 'Greys')
    print(kernels[idx].shape, kernels[idx].squeeze().shape)
print(kernels.size())
# Out:
# torch.Size([1, 3, 3]) torch.Size([3, 3])
# torch.Size([1, 3, 3]) torch.Size([3, 3])
# torch.Size([1, 3, 3]) torch.Size([3, 3])
# torch.Size([1, 3, 3]) torch.Size([3, 3])
# torch.Size([1, 3, 3]) torch.Size([3, 3])
# torch.Size([50, 1, 3, 3])

# %%
# Visualize conv2 filter
kernels = loaded_net.conv2.weight.detach()
plt.figure()
count = 0
for idx0 in range(kernels.size(0))[:4]:
    for idx1 in range(kernels.size(1))[:2]:
        plt.subplot(241 + count)
        count += 1
        plt.imshow(kernels[idx0][idx1].squeeze().cpu(), cmap = 'Greys')
        print(kernels[idx0][idx1].shape, kernels[idx0][idx1].squeeze().shape)
print(kernels.size())
# Out:
# torch.Size([3, 3]) torch.Size([3, 3])
# torch.Size([3, 3]) torch.Size([3, 3])
# torch.Size([3, 3]) torch.Size([3, 3])
# torch.Size([3, 3]) torch.Size([3, 3])
# torch.Size([3, 3]) torch.Size([3, 3])
# torch.Size([3, 3]) torch.Size([3, 3])
# torch.Size([3, 3]) torch.Size([3, 3])
# torch.Size([3, 3]) torch.Size([3, 3])
# torch.Size([100, 50, 3, 3])

# %%
# Feature maps
fmaps = loaded_net.get_features()
len(fmaps)
# Out:
# 10

# %%
for j in range(len(fmaps))[:6]:
  ## Visualize fmap
  fmap = fmaps[j]
  fmap.squeeze().size(0)

  plt.figure()

  for i in range(fmap.squeeze().size(0))[:20]: # sample 20 from 50 chnnels
      plt.subplot(4, 5, i + 1)
      plt.imshow(fmap.squeeze()[i].detach().numpy(), cmap = 'Greys')
# Out:
# fmap: 0
# fmap: 1
# fmap: 2
# fmap: 3
# fmap: 4
# fmap: 5

# %% [markdown]
# # Model Development, Improvement & Evaluation
